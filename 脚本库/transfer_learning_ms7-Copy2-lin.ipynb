# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %matplotlib inline

# %% [markdown]
# Transfer Learning for Computer Vision Tutorial
# ==============================================
#
# These two major transfer learning scenarios look as follows:
#
# -  **Finetuning the convnet**: Instead of random initialization, we
#    initialize the network with a pretrained network, like the one that is
#    trained on imagenet 1000 dataset. Rest of the training looks as
#    usual.
# -  **ConvNet as fixed feature extractor**: Here, we will freeze the weights
#    for all of the network except that of the final fully connected
#    layer. This last fully connected layer is replaced with a new one
#    with random weights and only this layer is trained.

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# Load Data
# ---------
#
# We will use torchvision and torch.utils.data packages for loading the
# data.
#
# The problem we're going to solve today is to train a model to classify
# **ants** and **bees**. We have about 120 training images each for ants and bees.
# There are 75 validation images for each class. Usually, this is a very
# small dataset to generalize upon, if trained from scratch. Since we
# are using transfer learning, we should be able to generalize reasonably
# well.
#
# This dataset is a very small subset of imagenet.
#
# .. Note ::
#    Download the data from
#    `here <https://download.pytorch.org/tutorial/hymenoptera_data.zip>`_
#    and extract it to the current directory.

# %%
# Data augmentation and normalization for training
# Just normalization for validation
image_transforms  = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees = 45),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

dataset = 'E:\gmd_data\microsphere2_dataAugmented'
train_directory = os.path.join(dataset, 'train')
valid_directory = os.path.join(dataset, 'valid')

batch_size = 32
# num_classes = 173

data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),
    'valid': datasets.ImageFolder(root=valid_directory, transform=image_transforms['valid'])

}


train_data_size = len(data['train'])
valid_data_size = len(data['valid'])

train_data = DataLoader(data['train'], batch_size=batch_size, shuffle=True)
valid_data = DataLoader(data['valid'], batch_size=batch_size, shuffle=True)

print(train_data_size, valid_data_size)
# Out:
# 168537 42177

# %% [markdown]
# 迁移学习
# ---------
#
#
# 这里使用ResNet-50的预训练模型。

# %%
resnet50 = models.resnet50(pretrained=True)

for param in resnet50.parameters():
    param.requires_grad = True

fc_inputs = resnet50.fc.in_features
resnet50.fc = nn.Sequential(
    nn.Linear(fc_inputs, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(128, 64),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(64, 173),
    nn.LogSoftmax(dim = 1)


)
resnet50 = resnet50.to('cuda:0')
loss_func = nn.NLLLoss()
# optimizer = optim.AdamW(resnet50.parameters(),lr=1e-4)

# %% [markdown]
# Training the model
# ------------------
#
# Now, let's write a general function to train a model. Here, we will
# illustrate:
#
# -  Scheduling the learning rate
# -  Saving the best model
#
# In the following, parameter ``scheduler`` is an LR scheduler object from
# ``torch.optim.lr_scheduler``.

# %%
def train_and_valid(model, loss_function, epochs=25):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    history = []
    best_acc = 0.0
    best_epoch = 0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))

        model.train()

        train_loss = 0.0
        train_acc = 0.0
        valid_loss = 0.0
        valid_acc = 0.0
#         学习率递减
        if epoch <= 10:
            LR = 1e-4;
        elif epoch <= 20:
            LR = 1e-4*0.5;
        elif epoch <= 30:
            LR = 1e-4*0.5*0.5;
        elif epoch <= 40:
            LR = 1e-4*0.5*0.5*0.5;
        else:
            LR = 1e-4*0.5*0.5*0.5*0.5;
        optimizer = optim.AdamW(resnet50.parameters(),lr=LR)

        for i, (inputs, labels) in enumerate(train_data):
            inputs = inputs.to(device)
            labels = labels.to(device)

            #因为这里梯度是累加的，所以每次记得清零
            optimizer.zero_grad()

            outputs = model(inputs)

            loss = loss_function(outputs, labels)

            loss.backward()

            optimizer.step()

            train_loss += loss.item() * inputs.size(0)

            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))

            acc = torch.mean(correct_counts.type(torch.FloatTensor))

            train_acc += acc.item() * inputs.size(0)

        with torch.no_grad():
            model.eval()

            for j, (inputs, labels) in enumerate(valid_data):
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)

                loss = loss_function(outputs, labels)

                valid_loss += loss.item() * inputs.size(0)

                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                valid_acc += acc.item() * inputs.size(0)

        avg_train_loss = train_loss/train_data_size
        avg_train_acc = train_acc/train_data_size

        avg_valid_loss = valid_loss/valid_data_size
        avg_valid_acc = valid_acc/valid_data_size

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])

        if best_acc < avg_valid_acc:
            best_acc = avg_valid_acc
            best_epoch = epoch + 1

        epoch_end = time.time()

        print("Epoch: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation: Loss: {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(
            epoch+1, avg_valid_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start
        ))
        print("Best Accuracy for validation : {:.4f} at epoch {:03d}".format(best_acc, best_epoch))

        torch.save(model, dataset+'/models/'+'model_'+str(epoch+1)+'.pt')
    return model, history

# %%
num_epochs = 3000
trained_model, history = train_and_valid(resnet50, loss_func, num_epochs)
torch.save(history, 'models/'+dataset+'_history.pt')
# Out:
# Epoch: 1/3000
# Epoch: 1/3000
# Epoch: 001, Training: Loss: 2.7878, Accuracy: 4.7230%,
# 		Validation: Loss: 2.7878, Accuracy: 15.0414%, Time: 8412.3150s
# Best Accuracy for validation : 0.1504 at epoch 001
# Epoch: 001, Training: Loss: 2.7878, Accuracy: 4.7230%,
# 		Validation: Loss: 2.7878, Accuracy: 15.0414%, Time: 8412.3150s
# Best Accuracy for validation : 0.1504 at epoch 001
# Epoch: 2/3000
# Epoch: 2/3000
# Epoch: 002, Training: Loss: 2.2598, Accuracy: 13.3917%,
# 		Validation: Loss: 2.2598, Accuracy: 18.2991%, Time: 8981.4649s
# Best Accuracy for validation : 0.1830 at epoch 002
# Epoch: 002, Training: Loss: 2.2598, Accuracy: 13.3917%,
# 		Validation: Loss: 2.2598, Accuracy: 18.2991%, Time: 8981.4649s
# Best Accuracy for validation : 0.1830 at epoch 002
# Epoch: 3/3000
# Epoch: 3/3000
# Epoch: 003, Training: Loss: 1.6855, Accuracy: 20.6530%,
# 		Validation: Loss: 1.6855, Accuracy: 30.5095%, Time: 8811.8746s
# Best Accuracy for validation : 0.3051 at epoch 003
# Epoch: 003, Training: Loss: 1.6855, Accuracy: 20.6530%,
# 		Validation: Loss: 1.6855, Accuracy: 30.5095%, Time: 8811.8746s
# Best Accuracy for validation : 0.3051 at epoch 003
# Epoch: 4/3000
# Epoch: 4/3000
# Epoch: 004, Training: Loss: 1.4812, Accuracy: 25.9350%,
# 		Validation: Loss: 1.4812, Accuracy: 38.7130%, Time: 8745.2444s
# Best Accuracy for validation : 0.3871 at epoch 004
# Epoch: 004, Training: Loss: 1.4812, Accuracy: 25.9350%,
# 		Validation: Loss: 1.4812, Accuracy: 38.7130%, Time: 8745.2444s
# Best Accuracy for validation : 0.3871 at epoch 004
# Epoch: 5/3000
# Epoch: 5/3000
# Epoch: 005, Training: Loss: 1.4132, Accuracy: 30.1898%,
# 		Validation: Loss: 1.4132, Accuracy: 39.3508%, Time: 8281.2216s
# Best Accuracy for validation : 0.3935 at epoch 005
# Epoch: 005, Training: Loss: 1.4132, Accuracy: 30.1898%,
# 		Validation: Loss: 1.4132, Accuracy: 39.3508%, Time: 8281.2216s
# Best Accuracy for validation : 0.3935 at epoch 005
# Epoch: 6/3000
# Epoch: 6/3000
# Epoch: 006, Training: Loss: 1.2154, Accuracy: 33.7178%,
# 		Validation: Loss: 1.2154, Accuracy: 52.4504%, Time: 8314.4973s
# Best Accuracy for validation : 0.5245 at epoch 006
# Epoch: 006, Training: Loss: 1.2154, Accuracy: 33.7178%,
# 		Validation: Loss: 1.2154, Accuracy: 52.4504%, Time: 8314.4973s
# Best Accuracy for validation : 0.5245 at epoch 006
# Epoch: 7/3000
# Epoch: 7/3000
# Epoch: 007, Training: Loss: 1.2791, Accuracy: 36.6543%,
# 		Validation: Loss: 1.2791, Accuracy: 38.4878%, Time: 8344.1881s
# Best Accuracy for validation : 0.5245 at epoch 006
# Epoch: 007, Training: Loss: 1.2791, Accuracy: 36.6543%,
# 		Validation: Loss: 1.2791, Accuracy: 38.4878%, Time: 8344.1881s
# Best Accuracy for validation : 0.5245 at epoch 006
# Epoch: 8/3000
# Epoch: 8/3000
# Epoch: 008, Training: Loss: 1.1361, Accuracy: 39.1309%,
# 		Validation: Loss: 1.1361, Accuracy: 54.9209%, Time: 8384.6401s
# Best Accuracy for validation : 0.5492 at epoch 008
# Epoch: 008, Training: Loss: 1.1361, Accuracy: 39.1309%,
# 		Validation: Loss: 1.1361, Accuracy: 54.9209%, Time: 8384.6401s
# Best Accuracy for validation : 0.5492 at epoch 008
# Epoch: 9/3000
# Epoch: 9/3000
# Epoch: 009, Training: Loss: 1.1118, Accuracy: 41.6407%,
# 		Validation: Loss: 1.1118, Accuracy: 55.3382%, Time: 8316.5371s
# Best Accuracy for validation : 0.5534 at epoch 009
# Epoch: 009, Training: Loss: 1.1118, Accuracy: 41.6407%,
# 		Validation: Loss: 1.1118, Accuracy: 55.3382%, Time: 8316.5371s
# Best Accuracy for validation : 0.5534 at epoch 009
# Epoch: 10/3000
# Epoch: 10/3000
# Epoch: 010, Training: Loss: 1.0734, Accuracy: 43.8438%,
# 		Validation: Loss: 1.0734, Accuracy: 56.2653%, Time: 8220.6728s
# Best Accuracy for validation : 0.5627 at epoch 010
# Epoch: 010, Training: Loss: 1.0734, Accuracy: 43.8438%,
# 		Validation: Loss: 1.0734, Accuracy: 56.2653%, Time: 8220.6728s
# Best Accuracy for validation : 0.5627 at epoch 010
# Epoch: 11/3000
# Epoch: 11/3000
# Epoch: 011, Training: Loss: 1.0144, Accuracy: 46.0196%,
# 		Validation: Loss: 1.0144, Accuracy: 57.8989%, Time: 8424.0412s
# Best Accuracy for validation : 0.5790 at epoch 011
# Epoch: 011, Training: Loss: 1.0144, Accuracy: 46.0196%,
# 		Validation: Loss: 1.0144, Accuracy: 57.8989%, Time: 8424.0412s
# Best Accuracy for validation : 0.5790 at epoch 011
# Epoch: 12/3000
# Epoch: 12/3000
# Epoch: 012, Training: Loss: 0.9149, Accuracy: 50.7325%,
# 		Validation: Loss: 0.9149, Accuracy: 66.9180%, Time: 8320.9056s
# Best Accuracy for validation : 0.6692 at epoch 012
# Epoch: 012, Training: Loss: 0.9149, Accuracy: 50.7325%,
# 		Validation: Loss: 0.9149, Accuracy: 66.9180%, Time: 8320.9056s
# Best Accuracy for validation : 0.6692 at epoch 012
# Epoch: 13/3000
# Epoch: 13/3000
# Epoch: 013, Training: Loss: 0.9367, Accuracy: 52.6128%,
# 		Validation: Loss: 0.9367, Accuracy: 65.5215%, Time: 8354.1486s
# Best Accuracy for validation : 0.6692 at epoch 012
# Epoch: 013, Training: Loss: 0.9367, Accuracy: 52.6128%,
# 		Validation: Loss: 0.9367, Accuracy: 65.5215%, Time: 8354.1486s
# Best Accuracy for validation : 0.6692 at epoch 012
# Epoch: 14/3000
# Epoch: 14/3000
# Epoch: 014, Training: Loss: 0.8909, Accuracy: 54.4041%,
# 		Validation: Loss: 0.8909, Accuracy: 68.8954%, Time: 8224.3794s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 014, Training: Loss: 0.8909, Accuracy: 54.4041%,
# 		Validation: Loss: 0.8909, Accuracy: 68.8954%, Time: 8224.3794s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 15/3000
# Epoch: 15/3000
# Epoch: 015, Training: Loss: 0.9422, Accuracy: 55.6566%,
# 		Validation: Loss: 0.9422, Accuracy: 63.6058%, Time: 8413.3526s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 015, Training: Loss: 0.9422, Accuracy: 55.6566%,
# 		Validation: Loss: 0.9422, Accuracy: 63.6058%, Time: 8413.3526s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 16/3000
# Epoch: 16/3000
# Epoch: 016, Training: Loss: 0.8671, Accuracy: 57.3298%,
# 		Validation: Loss: 0.8671, Accuracy: 66.9038%, Time: 8420.2203s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 016, Training: Loss: 0.8671, Accuracy: 57.3298%,
# 		Validation: Loss: 0.8671, Accuracy: 66.9038%, Time: 8420.2203s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 17/3000
# Epoch: 17/3000
# Epoch: 017, Training: Loss: 0.8788, Accuracy: 58.5634%,
# 		Validation: Loss: 0.8788, Accuracy: 67.2570%, Time: 8518.8632s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 017, Training: Loss: 0.8788, Accuracy: 58.5634%,
# 		Validation: Loss: 0.8788, Accuracy: 67.2570%, Time: 8518.8632s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 18/3000
# Epoch: 18/3000
# Epoch: 018, Training: Loss: 0.9320, Accuracy: 60.0521%,
# 		Validation: Loss: 0.9320, Accuracy: 65.8297%, Time: 8307.3785s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 018, Training: Loss: 0.9320, Accuracy: 60.0521%,
# 		Validation: Loss: 0.9320, Accuracy: 65.8297%, Time: 8307.3785s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 19/3000
# Epoch: 19/3000
# Epoch: 019, Training: Loss: 0.7999, Accuracy: 61.4684%,
# 		Validation: Loss: 0.7999, Accuracy: 74.1257%, Time: 8234.7468s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 019, Training: Loss: 0.7999, Accuracy: 61.4684%,
# 		Validation: Loss: 0.7999, Accuracy: 74.1257%, Time: 8234.7468s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 20/3000
# Epoch: 20/3000
# Epoch: 020, Training: Loss: 0.9810, Accuracy: 63.0366%,
# 		Validation: Loss: 0.9810, Accuracy: 65.1089%, Time: 8319.6256s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 020, Training: Loss: 0.9810, Accuracy: 63.0366%,
# 		Validation: Loss: 0.9810, Accuracy: 65.1089%, Time: 8319.6256s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 21/3000
# Epoch: 21/3000
# Epoch: 021, Training: Loss: 0.8171, Accuracy: 64.6974%,
# 		Validation: Loss: 0.8171, Accuracy: 70.4483%, Time: 8010.4017s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 021, Training: Loss: 0.8171, Accuracy: 64.6974%,
# 		Validation: Loss: 0.8171, Accuracy: 70.4483%, Time: 8010.4017s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 22/3000
# Epoch: 22/3000
# Epoch: 022, Training: Loss: 0.7793, Accuracy: 67.8444%,
# 		Validation: Loss: 0.7793, Accuracy: 74.3320%, Time: 8313.0873s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 022, Training: Loss: 0.7793, Accuracy: 67.8444%,
# 		Validation: Loss: 0.7793, Accuracy: 74.3320%, Time: 8313.0873s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 23/3000
# Epoch: 23/3000
# Epoch: 023, Training: Loss: 0.8611, Accuracy: 69.0596%,
# 		Validation: Loss: 0.8611, Accuracy: 70.8965%, Time: 8408.0875s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 023, Training: Loss: 0.8611, Accuracy: 69.0596%,
# 		Validation: Loss: 0.8611, Accuracy: 70.8965%, Time: 8408.0875s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 24/3000
# Epoch: 24/3000
# Epoch: 024, Training: Loss: 0.8013, Accuracy: 70.2611%,
# 		Validation: Loss: 0.8013, Accuracy: 74.0901%, Time: 8365.3434s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 024, Training: Loss: 0.8013, Accuracy: 70.2611%,
# 		Validation: Loss: 0.8013, Accuracy: 74.0901%, Time: 8365.3434s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 25/3000
# Epoch: 25/3000
# Epoch: 025, Training: Loss: 0.7899, Accuracy: 71.2045%,
# 		Validation: Loss: 0.7899, Accuracy: 73.2058%, Time: 8423.8834s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 025, Training: Loss: 0.7899, Accuracy: 71.2045%,
# 		Validation: Loss: 0.7899, Accuracy: 73.2058%, Time: 8423.8834s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 26/3000
# Epoch: 26/3000
# Epoch: 026, Training: Loss: 0.7543, Accuracy: 72.1841%,
# 		Validation: Loss: 0.7543, Accuracy: 77.2056%, Time: 8404.9979s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 026, Training: Loss: 0.7543, Accuracy: 72.1841%,
# 		Validation: Loss: 0.7543, Accuracy: 77.2056%, Time: 8404.9979s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 27/3000
# Epoch: 27/3000
# Epoch: 027, Training: Loss: 0.7528, Accuracy: 72.9377%,
# 		Validation: Loss: 0.7528, Accuracy: 76.2193%, Time: 8352.7937s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 027, Training: Loss: 0.7528, Accuracy: 72.9377%,
# 		Validation: Loss: 0.7528, Accuracy: 76.2193%, Time: 8352.7937s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 28/3000
# Epoch: 28/3000
# Epoch: 028, Training: Loss: 0.8207, Accuracy: 74.1760%,
# 		Validation: Loss: 0.8207, Accuracy: 74.9176%, Time: 7747.7625s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 028, Training: Loss: 0.8207, Accuracy: 74.1760%,
# 		Validation: Loss: 0.8207, Accuracy: 74.9176%, Time: 7747.7625s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 29/3000
# Epoch: 29/3000
# Epoch: 029, Training: Loss: 0.7930, Accuracy: 74.9497%,
# 		Validation: Loss: 0.7930, Accuracy: 73.8673%, Time: 8316.0652s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 029, Training: Loss: 0.7930, Accuracy: 74.9497%,
# 		Validation: Loss: 0.7930, Accuracy: 73.8673%, Time: 8316.0652s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 30/3000
# Epoch: 30/3000
# Epoch: 030, Training: Loss: 0.7693, Accuracy: 75.8023%,
# 		Validation: Loss: 0.7693, Accuracy: 77.4948%, Time: 7185.3099s
# Best Accuracy for validation : 0.7749 at epoch 030
# Epoch: 030, Training: Loss: 0.7693, Accuracy: 75.8023%,
# 		Validation: Loss: 0.7693, Accuracy: 77.4948%, Time: 7185.3099s
# Best Accuracy for validation : 0.7749 at epoch 030
# Epoch: 31/3000
# Epoch: 31/3000
# Epoch: 031, Training: Loss: 0.7836, Accuracy: 76.7647%,
# 		Validation: Loss: 0.7836, Accuracy: 73.7274%, Time: 7208.2856s
# Best Accuracy for validation : 0.7749 at epoch 030
# Epoch: 031, Training: Loss: 0.7836, Accuracy: 76.7647%,
# 		Validation: Loss: 0.7836, Accuracy: 73.7274%, Time: 7208.2856s
# Best Accuracy for validation : 0.7749 at epoch 030
# Epoch: 32/3000
# Epoch: 32/3000
# Epoch: 032, Training: Loss: 0.6982, Accuracy: 78.4605%,
# 		Validation: Loss: 0.6982, Accuracy: 78.0473%, Time: 7740.8255s
# Best Accuracy for validation : 0.7805 at epoch 032
# Epoch: 032, Training: Loss: 0.6982, Accuracy: 78.4605%,
# 		Validation: Loss: 0.6982, Accuracy: 78.0473%, Time: 7740.8255s
# Best Accuracy for validation : 0.7805 at epoch 032
# Epoch: 33/3000
# Epoch: 33/3000
# Epoch: 033, Training: Loss: 0.7224, Accuracy: 79.1494%,
# 		Validation: Loss: 0.7224, Accuracy: 79.3347%, Time: 8396.1221s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 033, Training: Loss: 0.7224, Accuracy: 79.1494%,
# 		Validation: Loss: 0.7224, Accuracy: 79.3347%, Time: 8396.1221s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 34/3000
# Epoch: 34/3000
# Epoch: 034, Training: Loss: 0.7491, Accuracy: 79.7142%,
# 		Validation: Loss: 0.7491, Accuracy: 76.9709%, Time: 8522.5748s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 034, Training: Loss: 0.7491, Accuracy: 79.7142%,
# 		Validation: Loss: 0.7491, Accuracy: 76.9709%, Time: 8522.5748s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 35/3000
# Epoch: 35/3000
# Epoch: 035, Training: Loss: 0.7467, Accuracy: 80.2945%,
# 		Validation: Loss: 0.7467, Accuracy: 75.0196%, Time: 8487.4049s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 035, Training: Loss: 0.7467, Accuracy: 80.2945%,
# 		Validation: Loss: 0.7467, Accuracy: 75.0196%, Time: 8487.4049s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 36/3000
# Epoch: 36/3000
# Epoch: 036, Training: Loss: 0.6818, Accuracy: 80.6333%,
# 		Validation: Loss: 0.6818, Accuracy: 78.0828%, Time: 7266.3552s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 036, Training: Loss: 0.6818, Accuracy: 80.6333%,
# 		Validation: Loss: 0.6818, Accuracy: 78.0828%, Time: 7266.3552s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 37/3000
# Epoch: 37/3000
# Epoch: 037, Training: Loss: 0.6863, Accuracy: 80.9496%,
# 		Validation: Loss: 0.6863, Accuracy: 77.8647%, Time: 7297.9431s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 037, Training: Loss: 0.6863, Accuracy: 80.9496%,
# 		Validation: Loss: 0.6863, Accuracy: 77.8647%, Time: 7297.9431s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 38/3000
# Epoch: 38/3000
# Epoch: 038, Training: Loss: 0.6523, Accuracy: 81.5394%,
# 		Validation: Loss: 0.6523, Accuracy: 81.3216%, Time: 8380.9847s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 038, Training: Loss: 0.6523, Accuracy: 81.5394%,
# 		Validation: Loss: 0.6523, Accuracy: 81.3216%, Time: 8380.9847s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 39/3000
# Epoch: 39/3000
# Epoch: 039, Training: Loss: 0.6905, Accuracy: 81.8734%,
# 		Validation: Loss: 0.6905, Accuracy: 78.8344%, Time: 7177.0423s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 039, Training: Loss: 0.6905, Accuracy: 81.8734%,
# 		Validation: Loss: 0.6905, Accuracy: 78.8344%, Time: 7177.0423s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 40/3000
# Epoch: 40/3000
# Epoch: 040, Training: Loss: 0.6800, Accuracy: 82.3671%,
# 		Validation: Loss: 0.6800, Accuracy: 77.6584%, Time: 7165.4367s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 040, Training: Loss: 0.6800, Accuracy: 82.3671%,
# 		Validation: Loss: 0.6800, Accuracy: 77.6584%, Time: 7165.4367s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 41/3000
# Epoch: 41/3000
# Epoch: 041, Training: Loss: 0.6992, Accuracy: 82.5148%,
# 		Validation: Loss: 0.6992, Accuracy: 78.4409%, Time: 7180.0553s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 041, Training: Loss: 0.6992, Accuracy: 82.5148%,
# 		Validation: Loss: 0.6992, Accuracy: 78.4409%, Time: 7180.0553s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 42/3000
# Epoch: 42/3000
# Epoch: 042, Training: Loss: 0.7085, Accuracy: 83.4446%,
# 		Validation: Loss: 0.7085, Accuracy: 76.9424%, Time: 7202.8630s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 042, Training: Loss: 0.7085, Accuracy: 83.4446%,
# 		Validation: Loss: 0.7085, Accuracy: 76.9424%, Time: 7202.8630s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 43/3000
# Epoch: 43/3000
# Epoch: 043, Training: Loss: 0.6958, Accuracy: 83.9679%,
# 		Validation: Loss: 0.6958, Accuracy: 78.3436%, Time: 7203.8156s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 043, Training: Loss: 0.6958, Accuracy: 83.9679%,
# 		Validation: Loss: 0.6958, Accuracy: 78.3436%, Time: 7203.8156s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 44/3000
# Epoch: 44/3000
# Epoch: 044, Training: Loss: 0.6769, Accuracy: 84.0765%,
# 		Validation: Loss: 0.6769, Accuracy: 79.5647%, Time: 8085.1803s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 044, Training: Loss: 0.6769, Accuracy: 84.0765%,
# 		Validation: Loss: 0.6769, Accuracy: 79.5647%, Time: 8085.1803s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 45/3000
# Epoch: 45/3000
# Epoch: 045, Training: Loss: 0.7106, Accuracy: 84.2278%,
# 		Validation: Loss: 0.7106, Accuracy: 77.7556%, Time: 9233.5630s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 045, Training: Loss: 0.7106, Accuracy: 84.2278%,
# 		Validation: Loss: 0.7106, Accuracy: 77.7556%, Time: 9233.5630s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 46/3000
# Epoch: 46/3000
# Epoch: 046, Training: Loss: 0.6661, Accuracy: 84.3643%,
# 		Validation: Loss: 0.6661, Accuracy: 80.0507%, Time: 9920.7980s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 046, Training: Loss: 0.6661, Accuracy: 84.3643%,
# 		Validation: Loss: 0.6661, Accuracy: 80.0507%, Time: 9920.7980s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 47/3000
# Epoch: 47/3000
# Epoch: 047, Training: Loss: 0.6815, Accuracy: 84.6152%,
# 		Validation: Loss: 0.6815, Accuracy: 78.2701%, Time: 12759.4504s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 047, Training: Loss: 0.6815, Accuracy: 84.6152%,
# 		Validation: Loss: 0.6815, Accuracy: 78.2701%, Time: 12759.4504s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 48/3000
# Epoch: 48/3000
# Epoch: 048, Training: Loss: 0.6873, Accuracy: 84.7434%,
# 		Validation: Loss: 0.6873, Accuracy: 78.5570%, Time: 15494.5561s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 048, Training: Loss: 0.6873, Accuracy: 84.7434%,
# 		Validation: Loss: 0.6873, Accuracy: 78.5570%, Time: 15494.5561s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 49/3000
# Epoch: 49/3000
# Epoch: 049, Training: Loss: 0.7007, Accuracy: 85.1617%,
# 		Validation: Loss: 0.7007, Accuracy: 77.6015%, Time: 13535.1470s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 049, Training: Loss: 0.7007, Accuracy: 85.1617%,
# 		Validation: Loss: 0.7007, Accuracy: 77.6015%, Time: 13535.1470s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 50/3000
# Epoch: 50/3000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\NANOLA~1\AppData\Local\Temp/ipykernel_28536/2181074094.py in <module>
#       1 num_epochs = 3000
# ----> 2 trained_model, history = train_and_valid(resnet50, loss_func, num_epochs)
#       3 torch.save(history, 'models/'+dataset+'_history.pt')
#       4
#
# C:\Users\NANOLA~1\AppData\Local\Temp/ipykernel_28536/1225346874.py in train_and_valid(model, loss_function, epochs)
#      55             model.eval()
#      56
# ---> 57             for j, (inputs, labels) in enumerate(valid_data):
#      58                 inputs = inputs.to(device)
#      59                 labels = labels.to(device)
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     525
#     526     def __next__(self) -> Any:
# --> 527         with torch.autograd.profiler.record_function(self._profile_name):
#     528             if self._sampler_iter is None:
#     529                 self._reset()
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\autograd\profiler.py in __init__(self, name, args)
#     431         # Stores underlying RecordFunction as a tensor. TODO: move to custom
#     432         # class (https://github.com/pytorch/pytorch/issues/35026).
# --> 433         self.handle: torch.Tensor = torch.zeros(1)
#     434
#     435     def __enter__(self):
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\NANOLA~1\AppData\Local\Temp/ipykernel_28536/2181074094.py in <module>
#       1 num_epochs = 3000
# ----> 2 trained_model, history = train_and_valid(resnet50, loss_func, num_epochs)
#       3 torch.save(history, 'models/'+dataset+'_history.pt')
#       4
#
# C:\Users\NANOLA~1\AppData\Local\Temp/ipykernel_28536/1225346874.py in train_and_valid(model, loss_function, epochs)
#      55             model.eval()
#      56
# ---> 57             for j, (inputs, labels) in enumerate(valid_data):
#      58                 inputs = inputs.to(device)
#      59                 labels = labels.to(device)
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     525
#     526     def __next__(self) -> Any:
# --> 527         with torch.autograd.profiler.record_function(self._profile_name):
#     528             if self._sampler_iter is None:
#     529                 self._reset()
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\autograd\profiler.py in __init__(self, name, args)
#     431         # Stores underlying RecordFunction as a tensor. TODO: move to custom
#     432         # class (https://github.com/pytorch/pytorch/issues/35026).
# --> 433         self.handle: torch.Tensor = torch.zeros(1)
#     434
#     435     def __enter__(self):
#
# KeyboardInterrupt:

# %%
history = np.array(history)
plt.plot(history[:, 0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0, 1)
plt.savefig(dataset+'_loss_curve.png')
plt.show()

plt.plot(history[:, 2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.savefig(dataset+'_accuracy_curve.png')
plt.show()

# %% [markdown]
# 导入模型 将验证集和真值对比图画出来
# -------

# %%
# 导入模型 将验证集和真值对比图画出来
dataset = 'E:\gmd_data\microsphere2_dataAugmented'
model38 = torch.load( dataset+'/models/'+'model_38.pt')
for param in model38.parameters():
    param.requires_grad = False
model38 = model38.to('cuda:0')
loss_function = nn.NLLLoss()



device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
history = []
best_acc = 0.0
best_epoch = 0


valid_loss = 0.0
valid_acc = 0.0

predictions_all = torch.tensor([]).to(device)
labels_all = torch.tensor([]).to(device)

for j, (inputs, labels) in enumerate(valid_data):
    inputs = inputs.to(device)
    labels = labels.to(device)

    outputs = model38(inputs)

    loss = loss_function(outputs, labels)
    print("valid_data_j: {}".format(j))
    print("Outputs : ")
    print(outputs)
    print("labels ：")
    print(labels)
    print("loss ：")
    print(loss)

    valid_loss += loss.item() * inputs.size(0)

    ret, predictions = torch.max(outputs.data, 1)

    predictions_all = torch.cat((predictions_all,predictions),dim=0)
    labels_all = torch.cat((labels_all,labels),dim=0)

    correct_counts = predictions.eq(labels.data.view_as(predictions))

    acc = torch.mean(correct_counts.type(torch.FloatTensor))

    valid_acc += acc.item() * inputs.size(0)

avg_valid_loss = valid_loss/valid_data_size
avg_valid_acc = valid_acc/valid_data_size
# Out:
# valid_data_j: 0
# Outputs :
# tensor([[ -69.1495,  -77.6109,  -82.7359,  ...,  -46.7911,  -89.2195,
#           -82.0036],
#         [-102.1846, -162.8951, -153.9431,  ..., -128.4779, -179.4648,
#          -170.5566],
#         [ -65.8197, -116.6505, -124.2278,  ...,  -78.2411, -120.3080,
#          -115.6520],
#         ...,
#         [ -71.4501,  -88.7237,  -91.2105,  ...,  -63.3917, -103.4579,
#           -96.0553],
#         [ -69.4935,  -76.7429,  -85.2581,  ...,  -70.8396,  -89.1500,
#           -82.7354],
#         [ -48.0707,  -64.2343,  -52.9691,  ...,  -92.3972,  -74.4130,
#           -74.9439]], device='cuda:0')
# labels ：
# tensor([129, 136, 112,  48,  36,  59,  93, 108,  77,  19,  84, 169, 127,  39,
#          88, 123, 151,  69, 161,  27,  25,  15, 128,  77,  63, 140, 112, 146,
#           5, 130,  43, 150], device='cuda:0')
# loss ：
# tensor(0.5593, device='cuda:0')
# valid_data_j: 1
# Outputs :
# tensor([[ -39.9778,  -57.2762,  -54.4895,  ...,  -89.4097,  -67.5464,
#           -65.7382],
#         [ -95.1311,  -64.7334,  -67.9280,  ...,  -95.9190,  -51.9787,
#           -60.6870],
#         [-102.1846, -162.8951, -153.9431,  ..., -128.4779, -179.4648,
#          -170.5566],
#         ...,
#         [-107.9838,  -84.1671,  -86.3236,  ...,  -76.7537,  -82.0723,
#           -84.9909],
#         [ -74.9293,   -2.5950,   -0.6631,  ...,  -29.2785,  -10.1494,
#            -5.8538],
#         [ -45.7028, -116.1630, -108.9601,  ..., -134.7186, -126.6936,
#          -123.0462]], device='cuda:0')
# labels ：
# tensor([ 85, 100, 136, 105,  96, 111, 134,  79, 108, 104,  67, 106,  60,  43,
#          95,  26,  71, 129, 102, 154,  37, 123, 132, 149,  98, 112,  14,  87,
#          45,  29,   3,  58], device='cuda:0')
# loss ：
# tensor(0.5607, device='cuda:0')
# valid_data_j: 2
# Outputs :
# tensor([[-6.6704e+01, -1.6177e+01, -2.0621e+01,  ..., -2.2449e+01,
#          -8.3595e+00, -1.0822e+01],
#         [-5.5316e+01, -1.5624e+01, -9.3651e+00,  ..., -3.8038e+01,
#          -2.8200e+01, -2.3026e+01],
#         [-1.2835e+01, -4.9224e+01, -5.7915e+01,  ..., -5.2451e+01,
#          -6.8909e+01, -6.0148e+01],
#         ...,
#         [-6.2282e+01, -2.6854e+01, -3.4890e+01,  ..., -2.3799e-03,
#          -2.8301e+01, -2.3336e+01],
#         [-4.0000e+01, -4.5794e+01, -4.4151e+01,  ..., -6.7700e+01,
#          -5.2391e+01, -5.0966e+01],
#         [-7.9292e+01, -1.0569e+02, -9.9195e+01,  ..., -9.1842e+01,
#          -1.0706e+02, -1.0869e+02]], device='cuda:0')
# labels ：
# tensor([155,   4,  50,  97,  70,  50,  48, 128, 101,  24,  16, 127,  50,  56,
#          39,  34, 137, 162,  85, 154,  92,  41,  49, 151, 162,  30, 113,  86,
#          78, 170,  85,  95], device='cuda:0')
# loss ：
# tensor(0.7653, device='cuda:0')
# valid_data_j: 3
# Outputs :
# tensor([[-6.2282e+01, -2.6854e+01, -3.4890e+01,  ..., -2.3799e-03,
#          -2.8301e+01, -2.3336e+01],
#         [-9.9638e+01, -9.0508e+01, -9.6919e+01,  ..., -4.4731e+01,
#          -1.0305e+02, -9.4324e+01],
#         [-6.8981e+01, -4.7212e+01, -5.1958e+01,  ..., -3.2801e+01,
#          -4.6943e+01, -4.2864e+01],
#         ...,
#         [-2.9046e+01, -9.3450e+01, -9.1474e+01,  ..., -1.1430e+02,
#          -1.0843e+02, -1.0229e+02],
#         [-8.6257e+01, -5.0707e+01, -5.7343e+01,  ..., -2.3085e+01,
#          -3.9704e+01, -4.1207e+01],
#         [-2.9866e+01, -6.5812e+01, -6.8750e+01,  ..., -7.5480e+01,
#          -8.2735e+01, -7.7305e+01]], device='cuda:0')
# labels ：
# tensor([170, 127, 105,  40,  52,  78,  12, 156,  17,  66, 100,  35,  40,  90,
#          52, 121,  27,  33,  52, 158,  32, 133,  46,  86, 111,  87,  13, 146,
#         132,  56, 103,  82], device='cuda:0')
# loss ：
# tensor(1.1912, device='cuda:0')
# valid_data_j: 4
# Outputs :
# tensor([[ -56.4953,  -74.9557,  -71.0713,  ...,  -63.7577,  -74.7542,
#           -76.1673],
#         [-135.6729, -166.6198, -166.3738,  ..., -138.2876, -179.2037,
#          -171.8658],
#         [ -82.4245,   -3.8011,   -1.0639,  ...,  -32.9075,  -12.5023,
#            -7.7148],
#         ...,
#         [ -72.1102,  -78.4336,  -76.3521,  ...,  -86.8489,  -73.1189,
#           -77.7248],
#         [ -65.6859,   -3.9197,   -6.9595,  ...,  -23.0260,   -0.7564,
#            -0.7495],
#         [ -69.1752,  -98.5541,  -98.6519,  ...,  -78.7602, -101.1782,
#           -97.4848]], device='cuda:0')
# labels ：
# tensor([ 94, 132,   3,  67, 150, 103,  63, 140, 130, 125, 107,  50, 112,  55,
#          40, 135,  89,  78,   6, 149,   6, 147,  78,  75, 152,  82,  17, 138,
#          35,  35, 172, 109], device='cuda:0')
# loss ：
# tensor(0.7002, device='cuda:0')
# valid_data_j: 5
# Outputs :
# tensor([[ -14.6026,  -68.1918,  -59.0718,  ..., -117.1749,  -86.0212,
#           -84.7359],
#         [-124.0506,  -87.3542,  -93.8878,  ...,  -30.1531,  -93.7161,
#           -86.0316],
#         [ -96.6124,  -83.7967,  -86.6606,  ...,  -89.6263,  -68.9416,
#           -77.9623],
#         ...,
#         [ -74.4986,  -53.7028,  -54.7554,  ...,  -77.9901,  -47.0392,
#           -52.8847],
#         [ -67.4965,  -74.9894,  -83.2391,  ...,  -69.0751,  -86.9263,
#           -80.7762],
#         [ -47.4124,  -75.3467,  -74.9489,  ...,  -97.5963,  -72.9565,
#           -75.0256]], device='cuda:0')
# labels ：
# tensor([ 33, 121,  31, 132, 111,  11, 136,  44, 107,  17,  84, 130,  55,  36,
#          89,  99, 172,  31,   0,  20,  29,   9, 119, 167,   2,  11,  46, 136,
#         161,  89,  43,  64], device='cuda:0')
# loss ：
# tensor(0.4146, device='cuda:0')
# valid_data_j: 6
# Outputs :
# tensor([[ -61.7709, -111.2096,  -93.3338,  ..., -137.9122, -132.1203,
#          -129.6867],
#         [ -63.8837,  -80.9711,  -66.9416,  ..., -112.2333,  -93.0757,
#           -93.8616],
#         [ -62.4472,  -69.3818,  -74.3277,  ...,  -69.4483,  -52.8922,
#           -58.9359],
#         ...,
#         [ -73.4689,  -81.4337,  -83.8950,  ...,  -77.8000,  -92.2969,
#           -86.2384],
#         [ -98.5363,  -77.8035,  -80.4086,  ...,  -38.2031,  -87.9941,
#           -80.0582],
#         [ -55.9164,  -50.0629,  -44.7423,  ...,  -60.6218,  -76.4653,
#           -64.7924]], device='cuda:0')
# labels ：
# tensor([153, 149,  65,  35,   0, 155, 112, 105,  95,  33,  21,  82, 156, 169,
#          36,  56,  95,  75,  41,  33, 152, 164,  67, 168, 162, 159,  76,  23,
#         152,  41, 124,  13], device='cuda:0')
# loss ：
# tensor(0.5563, device='cuda:0')
# valid_data_j: 7
# Outputs :
# tensor([[ -99.7575,  -84.1257,  -81.9050,  ...,  -56.6461,  -80.0199,
#           -82.6751],
#         [ -31.0378,  -74.9120,  -81.3114,  ...,  -44.6358,  -94.8695,
#           -84.5517],
#         [-103.1077,  -65.4266,  -78.7959,  ...,  -81.3521,  -35.6254,
#           -47.8059],
#         ...,
#         [ -40.7225,  -81.2611,  -66.5675,  ..., -116.3760, -100.1006,
#           -98.5624],
#         [ -68.6661,  -78.6466,  -83.5601,  ...,  -31.1101,  -94.2977,
#           -84.0235],
#         [ -88.2223,  -37.0790,  -38.5482,  ...,  -31.2212,  -50.5374,
#           -41.6919]], device='cuda:0')
# labels ：
# tensor([ 97, 163,  69, 127, 109,  98, 112,  36, 133,  58,  84,  71,  56, 157,
#         144, 119, 117, 121,  84,  63,  53,  28,  53, 170, 165, 169,   4,  70,
#          78, 148, 165,  17], device='cuda:0')
# loss ：
# tensor(0.6348, device='cuda:0')
# valid_data_j: 8
# Outputs :
# tensor([[ -58.0706,  -64.1384,  -56.0677,  ...,  -81.3705,  -90.2901,
#           -80.4302],
#         [ -47.6356,  -52.7243,  -45.8784,  ...,  -68.8437,  -74.1915,
#           -66.3259],
#         [ -35.1950,  -74.8529,  -61.5797,  ..., -104.1382,  -89.6864,
#           -88.7099],
#         ...,
#         [ -23.2170,  -76.4651,  -76.4788,  ...,  -90.7611,  -89.5579,
#           -84.0612],
#         [ -77.4560, -102.0802, -109.1020,  ...,  -94.7519, -111.9975,
#          -105.8718],
#         [ -86.0466,  -78.8789,  -82.1114,  ...,  -81.6145,  -59.5801,
#           -68.8357]], device='cuda:0')
# labels ：
# tensor([ 12,  12, 147, 157,  51, 164, 161,  46, 171, 111,  86, 120, 124,  42,
#          37, 111, 121,  88, 161,  87,  16, 105,  71,  87, 172,  85,  77,  77,
#          73,  54,  42,  91], device='cuda:0')
# loss ：
# tensor(0.3301, device='cuda:0')
# valid_data_j: 9
# Outputs :
# tensor([[ -34.3598,  -94.8340,  -84.8110,  ..., -122.9947, -108.2637,
#          -105.9201],
#         [ -77.6492,   -8.7408,  -13.4490,  ...,  -32.2414,   -0.3112,
#            -2.3555],
#         [ -29.8659,  -65.8121,  -68.7496,  ...,  -75.4798,  -82.7350,
#           -77.3054],
#         ...,
#         [ -90.7193, -109.0044, -114.6612,  ..., -126.7436,  -94.3395,
#          -100.9526],
#         [ -75.8810,   -3.5530,   -5.7803,  ...,  -27.9720,   -0.8125,
#            -0.6550],
#         [ -50.8182,  -80.2470,  -78.5779,  ..., -100.5235,  -77.7113,
#           -79.1035]], device='cuda:0')
# labels ：
# tensor([ 60, 171,  82, 170, 133,  18,  24, 158,  98, 148, 106, 148,  55, 164,
#          67, 162, 116, 127,  48,   9,  60, 140,  28,  32,  28, 129,  84,  47,
#          20,  73,   1,  63], device='cuda:0')
# loss ：
# tensor(0.7433, device='cuda:0')
# valid_data_j: 10
# Outputs :
# tensor([[ -22.6143,  -61.8725,  -57.9273,  ..., -111.0134,  -74.1573,
#           -74.8600],
#         [ -68.6840,  -43.1110,  -51.1595,  ...,  -60.1694,  -28.8085,
#           -34.9538],
#         [ -29.5637,  -59.1819,  -58.6167,  ...,  -78.3550,  -71.7602,
#           -69.7702],
#         ...,
#         [ -27.6878,  -63.0161,  -62.2495,  ...,  -86.0757,  -76.9718,
#           -74.7759],
#         [ -85.1975, -130.4543, -124.5213,  ..., -140.9943, -138.6494,
#          -137.1998],
#         [ -65.7424,  -50.8810,  -57.1529,  ...,  -55.2481,  -67.7282,
#           -61.2152]], device='cuda:0')
# labels ：
# tensor([ 44,  71,  83, 131,  23, 115, 158, 125,  37, 134,  71, 172,  15, 156,
#         109,   6, 144,  33, 113, 140, 119,  13, 127, 100, 112, 171,  92, 157,
#         137,  83,  75,  21], device='cuda:0')
# loss ：
# tensor(0.6600, device='cuda:0')
# valid_data_j: 11
# Outputs :
# tensor([[  -3.9169,  -68.3088,  -59.7166,  ..., -109.7632,  -90.7132,
#           -86.4114],
#         [ -54.7548,  -27.2176,  -35.4960,  ...,  -43.2813,  -43.4972,
#           -36.0469],
#         [ -45.9299, -105.3630,  -95.4860,  ..., -142.2303, -121.4695,
#          -118.6621],
#         ...,
#         [ -66.2347,  -41.0763,  -49.8034,  ...,  -57.0710,  -25.9103,
#           -32.2266],
#         [ -86.4930,  -75.3011,  -83.6543,  ...,  -79.7740,  -50.1593,
#           -61.9607],
#         [-102.9590,  -66.6195,  -80.1764,  ...,  -81.7232,  -36.7719,
#           -49.0501]], device='cuda:0')
# labels ：
# tensor([ 11,  20,  61,  74, 152,  91,   7,  65,  53,  28,   0, 105, 116,  18,
#          63,  48,  37, 123,  71, 121, 152,   3,  37, 166,  47, 128, 171, 102,
#         109,  71,  67,  69], device='cuda:0')
# loss ：
# tensor(0.5423, device='cuda:0')
# valid_data_j: 12
# Outputs :
# tensor([[ -66.5217, -116.9537,  -97.6105,  ..., -141.9966, -138.7496,
#          -136.1653],
#         [ -89.5858, -100.6549, -102.3809,  ...,  -99.6617, -114.6876,
#          -107.0729],
#         [ -49.7619,  -99.2061,  -93.9401,  ..., -126.2859, -106.4140,
#          -105.6793],
#         ...,
#         [ -57.7888,  -50.3926,  -40.4775,  ...,  -64.8287,  -73.2331,
#           -64.7902],
#         [  -2.5616,  -60.4689,  -53.3858,  ...,  -99.6818,  -80.0863,
#           -76.2647],
#         [ -71.1778,  -33.7737,  -33.4980,  ...,  -53.6027,  -26.4390,
#           -31.0061]], device='cuda:0')
# labels ：
# tensor([153,  41,  62, 131,  11, 101, 172, 139, 171,  27,  79, 172, 118,  53,
#         157, 102, 110,  71,  49,   7,  37, 145,  13,  23, 145, 112, 145, 126,
#          74,  12,  88, 111], device='cuda:0')
# loss ：
# tensor(0.7372, device='cuda:0')
# valid_data_j: 13
# Outputs :
# tensor([[ -93.8944, -122.8335, -121.3431,  ...,  -62.6177, -138.5835,
#          -128.8136],
#         [ -62.8908,   -1.0431,   -0.6949,  ...,  -21.7582,   -7.1158,
#            -3.2292],
#         [ -75.5786,  -71.2677,  -70.7719,  ..., -100.9166,  -59.2435,
#           -66.1047],
#         ...,
#         [ -32.3649,  -63.3896,  -66.6712,  ...,  -68.9383,  -78.3963,
#           -73.4499],
#         [-116.3550,  -97.8139, -110.6039,  ...,  -19.0434,  -89.5401,
#           -87.4379],
#         [ -65.7424,  -50.8810,  -57.1529,  ...,  -55.2481,  -67.7282,
#           -61.2152]], device='cuda:0')
# labels ：
# tensor([160,   2,  90, 166,  79, 116,  86,  59,  46,  54,   3,  65, 171,  27,
#         128,  20,  64,  94, 166,  91,  26, 114, 134, 110, 160, 105,  24,  48,
#          91,  81, 118,  21], device='cuda:0')
# loss ：
# tensor(0.6165, device='cuda:0')
# valid_data_j: 14
# Outputs :
# tensor([[-116.3550,  -97.8139, -110.6039,  ...,  -19.0434,  -89.5401,
#           -87.4379],
#         [ -88.7439,   -2.8540,   -0.5611,  ...,  -35.4573,  -12.1157,
#            -6.8753],
#         [ -44.1388,  -37.6920,  -44.1576,  ...,   -9.9960,  -43.1245,
#           -38.1302],
#         ...,
#         [ -72.5273,  -48.9444,  -58.3794,  ...,  -58.3621,  -26.5206,
#           -35.7097],
#         [ -82.8923,  -24.8024,  -35.3386,  ...,  -49.4563,   -6.1872,
#           -13.6349],
#         [ -55.9164,  -50.0629,  -44.7423,  ...,  -60.6218,  -76.4653,
#           -64.7924]], device='cuda:0')
# labels ：
# tensor([118,   3, 168, 104, 134, 124,  13, 162, 151,  65,   4, 119, 108,  41,
#          41,  48, 127,  31,  50,  32,  12,  97,  95,  98,  43,  90,  96,  75,
#         125,  69, 155,  13], device='cuda:0')
# loss ：
# tensor(0.3608, device='cuda:0')
# valid_data_j: 15
# Outputs :
# tensor([[ -99.7575,  -84.1257,  -81.9050,  ...,  -56.6461,  -80.0199,
#           -82.6751],
#         [-108.7381,  -84.3814,  -88.4998,  ...,  -43.0523,  -95.5531,
#           -86.4988],
#         [-120.2324,  -94.4404, -106.8416,  ...,  -18.0211,  -85.2695,
#           -83.7410],
#         ...,
#         [ -46.0358,  -67.4922,  -68.2619,  ...,  -92.1486,  -64.4905,
#           -67.9569],
#         [ -79.3560,  -58.4023,  -64.2785,  ...,  -63.1930,  -36.7448,
#           -45.8201],
#         [ -43.3211,  -94.9327,  -88.0417,  ..., -125.1410, -104.8342,
#          -103.4733]], device='cuda:0')
# labels ：
# tensor([ 97, 123, 118, 157,  46, 159,  69, 147, 144,  19,  29, 106,  53,  64,
#         130,  80, 110, 136,  67,  67, 126,  97,  87, 160,  83,  39, 126, 151,
#         137,  64,  91,  61], device='cuda:0')
# loss ：
# tensor(0.3317, device='cuda:0')
# valid_data_j: 16
# Outputs :
# tensor([[ -75.8810,   -3.5530,   -5.7803,  ...,  -27.9720,   -0.8125,
#            -0.6550],
#         [ -57.3552,  -74.3664,  -75.9114,  ..., -126.8775,  -69.7765,
#           -77.4104],
#         [ -87.2368,  -76.6168,  -85.0147,  ...,  -81.1403,  -51.4933,
#           -63.3364],
#         ...,
#         [-129.2484,  -99.2465, -102.2741,  ...,  -78.9606,  -93.1160,
#           -97.0644],
#         [-113.9122,  -92.0834,  -95.8617,  ..., -102.4356,  -85.9060,
#           -92.3038],
#         [-102.1846, -162.8951, -153.9431,  ..., -128.4779, -179.4648,
#          -170.5566]], device='cuda:0')
# labels ：
# tensor([  1,  66,  67,  88,  42, 144,  78, 111, 116,  54,  42, 140, 159,  93,
#          31, 154, 114, 146,  99,  49,  49,  30,  74,  47, 125,  90,  70, 128,
#          81,  29,  30, 136], device='cuda:0')
# loss ：
# tensor(0.8139, device='cuda:0')
# valid_data_j: 17
# Outputs :
# tensor([[-7.0312e+01, -2.9974e+01, -3.8196e+01,  ..., -1.2664e-02,
#          -3.1567e+01, -2.6298e+01],
#         [-8.6412e+01, -8.2938e+01, -8.4021e+01,  ..., -4.9532e+01,
#          -9.5910e+01, -8.8204e+01],
#         [-7.3298e+01, -8.8299e+01, -9.1432e+01,  ..., -6.0770e+01,
#          -1.0201e+02, -9.4588e+01],
#         ...,
#         [-3.2365e+01, -6.3390e+01, -6.6671e+01,  ..., -6.8938e+01,
#          -7.8396e+01, -7.3450e+01],
#         [-7.2110e+01, -7.8434e+01, -7.6352e+01,  ..., -8.6849e+01,
#          -7.3119e+01, -7.7725e+01],
#         [-6.9323e+01, -7.1915e+01, -6.8588e+01,  ..., -8.0991e+01,
#          -6.6142e+01, -7.1807e+01]], device='cuda:0')
# labels ：
# tensor([170, 126, 130,  71, 163,  71, 100,  70, 171,  24,  95, 171,   1, 149,
#         171,  39,  66,  71, 137, 100,  45, 120,  69,  26, 140, 142, 135,  16,
#         133,  81,  35,  32], device='cuda:0')
# loss ：
# tensor(1.0038, device='cuda:0')
# valid_data_j: 18
# Outputs :
# tensor([[ -66.5217, -116.9537,  -97.6105,  ..., -141.9966, -138.7496,
#          -136.1653],
#         [ -48.0707,  -64.2343,  -52.9691,  ...,  -92.3972,  -74.4130,
#           -74.9439],
#         [ -83.6118, -115.9998, -114.9869,  ..., -125.4283, -111.9285,
#          -114.7492],
#         ...,
#         [-131.2520, -163.3001, -163.4418,  ..., -135.0128, -175.3355,
#          -168.0396],
#         [ -29.5944,  -60.3451,  -58.6935,  ...,  -87.6946,  -70.9463,
#           -69.6655],
#         [ -79.5359,  -31.9932,  -34.5166,  ...,  -39.0715,  -47.7095,
#           -38.7118]], device='cuda:0')
# labels ：
# tensor([153, 150,  74, 125, 124,  88, 167,  53,  91,  56,  75, 105, 149,  33,
#         107, 133, 115,  15, 121,   2,   2, 131,  53, 139,  59, 167,  43,  40,
#         169, 132,  84,  18], device='cuda:0')
# loss ：
# tensor(0.7229, device='cuda:0')
# valid_data_j: 19
# Outputs :
# tensor([[ -67.0226,  -19.5031,  -11.7115,  ...,  -47.5008,  -34.8072,
#           -28.6341],
#         [ -34.4175,  -60.2185,  -59.1176,  ..., -110.8927,  -68.0900,
#           -70.6680],
#         [ -69.1752,  -98.5541,  -98.6519,  ...,  -78.7602, -101.1782,
#           -97.4848],
#         ...,
#         [ -72.1641,  -68.3723,  -67.4961,  ...,  -97.8456,  -57.3622,
#           -63.8374],
#         [ -52.6342,  -90.2080,  -89.6841,  ...,  -79.6291,  -92.1882,
#           -88.9196],
#         [ -71.3856, -133.1443, -122.1814,  ..., -111.5913, -148.4214,
#          -141.7719]], device='cuda:0')
# labels ：
# tensor([  5,  44, 109,  99, 102, 151, 149, 166, 146, 151, 170,  16, 112, 101,
#          42, 107, 155,  29, 102,   5,  93,  85,  95, 105, 142, 157,  69,  39,
#         158,  90, 110, 138], device='cuda:0')
# loss ：
# tensor(0.4459, device='cuda:0')
# valid_data_j: 20
# Outputs :
# tensor([[ -99.3542, -109.9240, -113.9377,  ..., -115.0450, -103.6930,
#          -107.6740],
#         [ -89.2269,  -59.2750,  -61.8915,  ...,  -88.4007,  -47.2392,
#           -55.4032],
#         [  -0.9556,  -68.0978,  -64.3521,  ..., -109.7258,  -92.0063,
#           -84.5851],
#         ...,
#         [-101.0322, -135.0731, -130.9171,  ..., -119.9910, -145.4741,
#          -139.8462],
#         [ -72.7797,  -84.8659,  -75.6451,  ...,  -62.3321,  -95.8525,
#           -91.2270],
#         [-112.8527,  -77.9710,  -85.0997,  ...,  -25.2003,  -80.0056,
#           -74.7980]], device='cuda:0')
# labels ：
# tensor([ 39,  89,  88,   7, 141, 148, 126,  41,  31, 165, 166,  63, 130,  85,
#          18, 135,  11,  99, 118, 143,  35,  45,  40,  16, 108,  23,  10,  79,
#         145, 134, 158, 120], device='cuda:0')
# loss ：
# tensor(0.6251, device='cuda:0')
# valid_data_j: 21
# Outputs :
# tensor([[ -43.3211,  -94.9327,  -88.0417,  ..., -125.1410, -104.8342,
#          -103.4733],
#         [ -46.8346, -122.2308, -111.0115,  ..., -152.7496, -137.0178,
#          -134.1743],
#         [ -43.4717,  -36.4900,  -45.8648,  ...,  -53.1622,  -46.7926,
#           -44.1611],
#         ...,
#         [ -68.7770,  -85.3177,  -90.3802,  ...,  -84.5180,  -99.6956,
#           -94.5238],
#         [ -55.5302,  -55.0614,  -50.6511,  ...,  -66.9514,  -60.0550,
#           -59.2667],
#         [ -83.8366,  -15.0765,  -22.0832,  ...,  -37.1861,   -1.2545,
#            -5.5124]], device='cuda:0')
# labels ：
# tensor([ 61,  60,  23,  43, 159, 138, 131,   4, 109, 140, 114,  55,  22, 142,
#         123, 104,  87, 100,   5, 149,  71,  13, 160, 150,  64,  79,  70, 130,
#          27,  80,  36, 166], device='cuda:0')
# loss ：
# tensor(0.4810, device='cuda:0')
# valid_data_j: 22
# Outputs :
# tensor([[-106.6272,  -77.1291,  -82.2891,  ...,  -70.2872,  -83.9747,
#           -82.6414],
#         [ -16.0882,  -53.9221,  -48.5342,  ...,  -95.3941,  -65.0452,
#           -65.4048],
#         [ -55.7991,  -93.4729,  -78.2568,  ..., -119.3082, -112.9368,
#          -110.6372],
#         ...,
#         [ -54.5452,  -83.4894,  -93.5478,  ...,  -43.2607,  -85.8902,
#           -82.0222],
#         [ -72.5273,  -48.9444,  -58.3794,  ...,  -58.3621,  -26.5206,
#           -35.7097],
#         [ -56.4953,  -74.9557,  -71.0713,  ...,  -63.7577,  -74.7542,
#           -76.1673]], device='cuda:0')
# labels ：
# tensor([ 26,  33, 152, 122,  73, 133, 134, 112,   5, 133,  75, 128,  30, 128,
#          72,  10, 151,  39,  58,  37,  55, 160, 148, 140,  16, 148,  33, 158,
#         120, 113,  69,  94], device='cuda:0')
# loss ：
# tensor(0.3622, device='cuda:0')
# valid_data_j: 23
# Outputs :
# tensor([[-139.7357, -117.0720, -124.6288,  ...,  -73.3363,  -88.7220,
#          -100.1560],
#         [  -0.6509,  -60.6099,  -56.7970,  ...,  -95.9901,  -82.3678,
#           -75.8502],
#         [ -41.4005,  -78.2118,  -85.1861,  ...,  -41.4742,  -97.9506,
#           -87.1064],
#         ...,
#         [ -73.2976,  -88.2992,  -91.4319,  ...,  -60.7704, -102.0059,
#           -94.5878],
#         [ -45.7028, -116.1630, -108.9601,  ..., -134.7186, -126.6936,
#          -123.0462],
#         [ -20.0029,  -77.1638,  -68.3057,  ..., -112.0755,  -91.4465,
#           -88.5705]], device='cuda:0')
# labels ：
# tensor([ 99,  88, 164, 104,  96,   0, 125, 170,  69, 164,  88,  99,   7,  42,
#          14, 127, 164, 111,  80, 103, 124,  55, 164,  12,  95,  14,  46,  65,
#         122, 130,  58, 145], device='cuda:0')
# loss ：
# tensor(0.7245, device='cuda:0')
# valid_data_j: 24
# Outputs :
# tensor([[ -58.8508,  -62.8850,  -50.8015,  ...,  -84.6910,  -86.1779,
#           -79.0931],
#         [ -61.4872,  -76.4035,  -82.4577,  ...,  -70.7727,  -86.3235,
#           -80.6892],
#         [ -85.2286, -107.6582,  -95.1594,  ...,  -82.7444, -122.4125,
#          -116.8855],
#         ...,
#         [ -65.0063,  -58.2418,  -51.1044,  ...,  -67.6471,  -86.9770,
#           -74.5461],
#         [ -14.5065,  -45.0683,  -51.4351,  ...,  -46.4476,  -57.7913,
#           -51.7851],
#         [-118.9867,  -99.4947, -106.1961,  ...,  -60.9334,  -75.5171,
#           -85.0170]], device='cuda:0')
# labels ：
# tensor([ 10,  43, 159, 169, 101, 135,  56,  98, 126,  54, 118, 152, 145, 153,
#           0,  27, 147,  64, 104, 118,  24,  62,  57,  25, 123,  46,  84,  41,
#          96,  13,  48,  99], device='cuda:0')
# loss ：
# tensor(0.5315, device='cuda:0')
# valid_data_j: 25
# Outputs :
# tensor([[ -89.4304,  -79.1376,  -77.4398,  ...,  -45.9494,  -92.8817,
#           -84.3309],
#         [ -72.4911,  -55.3878,  -62.0412,  ...,  -61.0223,  -67.5299,
#           -63.3955],
#         [ -27.3646,  -64.7144,  -67.3538,  ...,  -74.7686,  -81.5672,
#           -76.1649],
#         ...,
#         [ -48.0832,  -60.8445,  -50.6681,  ...,  -76.4871,  -72.1619,
#           -71.1784],
#         [ -80.1436, -114.0799, -114.0573,  ...,  -90.1222, -116.8597,
#          -112.8742],
#         [ -86.4512,  -32.0219,  -35.0877,  ...,  -41.9656,  -48.1114,
#           -38.8657]], device='cuda:0')
# labels ：
# tensor([124,  25,  81,  58,  37,  24,  56, 137,  56, 154, 103, 170,  87, 125,
#         172,  42,  81, 134, 162,  73,  10,  81, 111, 161,  26, 147, 135,  43,
#          78, 151, 109,  18], device='cuda:0')
# loss ：
# tensor(0.5533, device='cuda:0')
# valid_data_j: 26
# Outputs :
# tensor([[ -59.7957,  -88.4763, -100.5984,  ...,  -44.3357,  -90.5412,
#           -86.5296],
#         [ -30.7699,  -90.0163,  -90.1759,  ...,  -68.9600, -109.3366,
#          -100.9253],
#         [  -2.5616,  -60.4689,  -53.3858,  ...,  -99.6818,  -80.0863,
#           -76.2647],
#         ...,
#         [-112.8527,  -77.9710,  -85.0997,  ...,  -25.2003,  -80.0056,
#           -74.7980],
#         [ -83.6377,  -59.8251,  -64.3745,  ...,  -54.8989,  -65.2554,
#           -64.0362],
#         [ -15.4299,  -73.5622,  -64.1544,  ..., -126.3285,  -92.8871,
#           -91.5010]], device='cuda:0')
# labels ：
# tensor([113, 162,  88, 127,  60,   9, 167,  91,  67, 158,   9,   3, 160,  94,
#          90,  94,  30,  70,  81, 139,  11, 119, 161,  97,  74, 159, 104,  27,
#          58, 120,  26,  33], device='cuda:0')
# loss ：
# tensor(0.5187, device='cuda:0')
# valid_data_j: 27
# Outputs :
# tensor([[-120.2324,  -94.4404, -106.8416,  ...,  -18.0211,  -85.2695,
#           -83.7410],
#         [ -66.3610,  -74.2035,  -82.5525,  ...,  -57.3911,  -92.8460,
#           -82.5803],
#         [ -66.3693, -142.1260, -137.8593,  ..., -102.3621, -168.8743,
#          -156.6765],
#         ...,
#         [ -60.9366,  -87.6930, -100.1573,  ...,  -41.8036,  -88.7910,
#           -85.1341],
#         [ -91.0841,  -38.8489,  -40.7185,  ...,  -32.7153,  -52.5706,
#           -43.5984],
#         [-121.8664,  -96.7382,  -99.6178,  ...,  -45.9525, -108.8810,
#           -99.3474]], device='cuda:0')
# labels ：
# tensor([118,  45, 161, 133,  74,   2,  51,  50, 130,   6,  54,  89,  98,  61,
#          14,  52,  98,  46, 147,  16, 160, 120,  47,  55,  77, 123,  79,  32,
#          51, 113,  17, 123], device='cuda:0')
# loss ：
# tensor(0.6839, device='cuda:0')
# valid_data_j: 28
# Outputs :
# tensor([[ -76.2714,  -72.2000,  -79.1375,  ...,  -45.3501,  -61.9483,
#           -61.9545],
#         [ -64.9086,  -36.8484,  -41.0531,  ...,  -54.2205,  -59.4020,
#           -49.0392],
#         [ -67.8657,  -41.8559,  -49.1382,  ...,  -59.0461,  -29.6329,
#           -35.0434],
#         ...,
#         [ -90.9847, -117.6689, -118.8503,  ..., -113.2701, -125.7713,
#          -121.8461],
#         [ -62.2696, -159.8622, -148.8658,  ..., -158.1538, -183.1043,
#          -173.6364],
#         [ -24.6757,  -52.7241,  -51.9019,  ...,  -71.3132,  -62.9899,
#           -61.7668]], device='cuda:0')
# labels ：
# tensor([106,  19,  71,  17, 141, 172,  11, 141, 132, 162,  37,  66, 159, 167,
#          11,  36,  15,  24,  87,  19,  20,  13, 164, 103, 164, 101, 126, 138,
#         165,  40, 139,  83], device='cuda:0')
# loss ：
# tensor(0.3200, device='cuda:0')
# valid_data_j: 29
# Outputs :
# tensor([[ -81.4671,  -73.9541,  -75.1526,  ...,  -79.8807,  -63.8729,
#           -70.7730],
#         [ -41.2512,  -70.3676,  -80.1370,  ...,  -66.1330,  -88.3121,
#           -78.4967],
#         [-106.1494,  -62.0336,  -54.7610,  ...,  -54.3964,  -85.9543,
#           -74.2610],
#         ...,
#         [-112.8527,  -77.9710,  -85.0997,  ...,  -25.2003,  -80.0056,
#           -74.7980],
#         [ -85.2286, -107.6582,  -95.1594,  ...,  -82.7444, -122.4125,
#          -116.8855],
#         [ -14.5065,  -45.0683,  -51.4351,  ...,  -46.4476,  -57.7913,
#           -51.7851]], device='cuda:0')
# labels ：
# tensor([ 31,  45,  15,  44,  69, 131,  99, 145,   6, 123,   1,  58, 169, 124,
#          63, 153,  17, 148,  23,   1,  64,  38,  64,  93,  45,  10,  97, 118,
#         123, 120, 159,  48], device='cuda:0')
# loss ：
# tensor(0.9365, device='cuda:0')
# valid_data_j: 30
# Outputs :
# tensor([[ -86.4116,  -82.9385,  -84.0205,  ...,  -49.5319,  -95.9101,
#           -88.2042],
#         [ -34.0937,  -75.5701,  -73.1742,  ..., -106.8020,  -86.5072,
#           -86.5775],
#         [  -2.5337,  -62.4431,  -57.5805,  ...,  -96.2447,  -84.4983,
#           -79.1710],
#         ...,
#         [ -61.6676, -160.4572, -149.3862,  ..., -159.1698, -184.1395,
#          -174.6089],
#         [ -51.1278,  -99.7134,  -94.7734,  ..., -125.1457, -105.5642,
#          -105.0705],
#         [-154.0924, -195.0385, -194.8960,  ..., -163.8496, -209.3271,
#          -200.9114]], device='cuda:0')
# labels ：
# tensor([126,  84,  11, 107,  50,  24,  45, 122, 137,  44, 143,  97,  67, 116,
#          70, 165, 153, 157,  52, 106, 114,  22,  46, 117, 167,  11, 109,  48,
#          31, 139,  62, 132], device='cuda:0')
# loss ：
# tensor(0.2448, device='cuda:0')
# valid_data_j: 31
# Outputs :
# tensor([[-63.8484, -82.5340, -89.0302,  ..., -32.4633, -99.4076, -88.3871],
#         [-72.1641, -68.3723, -67.4961,  ..., -97.8456, -57.3622, -63.8374],
#         [-13.5448, -50.0196, -56.0038,  ..., -55.7375, -61.2085, -56.6444],
#         ...,
#         [-86.4116, -82.9385, -84.0205,  ..., -49.5319, -95.9101, -88.2042],
#         [-58.8508, -62.8850, -50.8015,  ..., -84.6910, -86.1779, -79.0931],
#         [-54.7497, -67.4642, -56.5483,  ..., -83.8823, -79.5757, -78.5598]],
#        device='cuda:0')
# labels ：
# tensor([165,  90,  51,  91, 152,   5,  73,   5,  89,  22, 171,  12, 110,  31,
#          57, 153,  79, 135,  85, 120,  65,  92, 140,  36, 123,  83,  77, 140,
#         125, 126,  10, 151], device='cuda:0')
# loss ：
# tensor(0.3579, device='cuda:0')
# valid_data_j: 32
# Outputs :
# tensor([[ -88.2223,  -37.0790,  -38.5482,  ...,  -31.2212,  -50.5374,
#           -41.6919],
#         [ -97.3930, -105.1330, -106.5137,  ..., -109.2272, -106.4276,
#          -104.8624],
#         [ -99.1538,  -72.5896,  -81.5259,  ...,  -15.6392,  -64.7881,
#           -64.4580],
#         ...,
#         [  -9.5336,  -48.7370,  -55.4692,  ...,  -53.4519,  -66.5917,
#           -59.0327],
#         [ -48.0707,  -64.2343,  -52.9691,  ...,  -92.3972,  -74.4130,
#           -74.9439],
#         [ -12.8346,  -49.2243,  -57.9149,  ...,  -52.4513,  -68.9094,
#           -60.1479]], device='cuda:0')
# labels ：
# tensor([ 17,  38, 119, 125,  79, 152, 139,  86,  33, 166, 120,  39, 161, 132,
#          24, 156,  71,  90, 134, 170, 144, 102, 147, 115, 147,  71,  30,  10,
#          64,  51, 150,  50], device='cuda:0')
# loss ：
# tensor(0.4467, device='cuda:0')
# valid_data_j: 33
# Outputs :
# tensor([[-114.7870, -129.6118, -133.9813,  ..., -136.1346, -121.5336,
#          -126.4779],
#         [ -90.0837,  -82.2869,  -87.6017,  ...,  -41.4170,  -92.8866,
#           -85.3013],
#         [ -71.1556, -125.0588, -133.0542,  ...,  -83.9183, -129.1425,
#          -123.9192],
#         ...,
#         [ -44.1388,  -37.6920,  -44.1576,  ...,   -9.9960,  -43.1245,
#           -38.1302],
#         [  -9.8513,  -58.6595,  -58.8907,  ...,  -76.6145,  -78.1656,
#           -72.6661],
#         [ -62.1480,  -64.7393,  -63.3248,  ...,  -71.3465,  -58.8432,
#           -63.6790]], device='cuda:0')
# labels ：
# tensor([ 39, 127, 112, 112,   8, 138,  97, 156, 118,   7, 165, 108,   6, 105,
#          97, 138,   0,  82,  33, 102, 126, 160, 133,   7,  27,  21,  48, 145,
#          38, 168,  22,  34], device='cuda:0')
# loss ：
# tensor(0.5814, device='cuda:0')
# valid_data_j: 34
# Outputs :
# tensor([[ -70.1197,  -51.5222,  -55.9344,  ...,  -56.5222,  -34.5828,
#           -41.4196],
#         [ -38.0336,  -54.2646,  -45.2228,  ...,  -81.1449,  -64.0835,
#           -64.1341],
#         [ -93.8829,  -87.7427,  -84.0704,  ...,  -69.9754, -106.5194,
#           -97.3424],
#         ...,
#         [ -77.2855,  -88.4486,  -97.2648,  ...,  -25.9478,  -88.0998,
#           -83.8570],
#         [-106.3059,  -82.7823,  -92.4057,  ...,  -43.0143,  -59.1123,
#           -67.1275],
#         [  -0.5956,  -68.1152,  -63.1718,  ..., -106.5596,  -92.7657,
#           -86.0825]], device='cuda:0')
# labels ：
# tensor([ 68, 150, 125, 125,  46,  76,  88,  26,  43, 125,  33, 162,  82,  55,
#          36,  27,  64, 157,   6,  83,  24,  99,  83,  95,  60, 155, 128, 168,
#          22, 116, 102,   0], device='cuda:0')
# loss ：
# tensor(0.1446, device='cuda:0')
# valid_data_j: 35
# Outputs :
# tensor([[ -68.3290,  -73.2840,  -78.8608,  ...,  -77.3959,  -55.1957,
#           -62.7998],
#         [ -30.6493, -115.3755, -104.2436,  ..., -144.4263, -137.1618,
#          -131.1337],
#         [ -54.7548,  -27.2176,  -35.4960,  ...,  -43.2813,  -43.4972,
#           -36.0469],
#         ...,
#         [ -90.0887,  -91.3005,  -99.3304,  ...,  -59.4770,  -79.2241,
#           -79.1570],
#         [ -83.6118, -115.9998, -114.9869,  ..., -125.4283, -111.9285,
#          -114.7492],
#         [ -61.4872,  -76.4035,  -82.4577,  ...,  -70.7727,  -86.3235,
#           -80.6892]], device='cuda:0')
# labels ：
# tensor([ 65, 141,  20,  29,  32, 135,  78,  56, 128,  53,  33,  57, 152,  59,
#          20, 141, 145,  83, 101,  80, 122, 170,   2,  78, 156,  70,  47, 133,
#          34, 106,  74,  43], device='cuda:0')
# loss ：
# tensor(1.1565, device='cuda:0')
# valid_data_j: 36
# Outputs :
# tensor([[ -92.2148, -117.5936, -107.3365,  ...,  -78.8053, -131.8835,
#          -125.3024],
#         [ -46.5003,  -41.0323,  -51.5767,  ...,  -57.2375,  -57.9885,
#           -51.7450],
#         [ -95.8099,   -4.8513,   -1.3311,  ...,  -38.5624,  -15.5502,
#            -9.7861],
#         ...,
#         [ -16.0882,  -53.9221,  -48.5342,  ...,  -95.3941,  -65.0452,
#           -65.4048],
#         [ -28.8132,  -93.1203,  -93.7327,  ..., -108.1124, -108.2338,
#          -101.8116],
#         [ -95.8099,   -4.8513,   -1.3311,  ...,  -38.5624,  -15.5502,
#            -9.7861]], device='cuda:0')
# labels ：
# tensor([159,  21,   3,  58, 130, 100,  16, 171,  99, 133,  91,  51,  80, 168,
#         108,  10, 100, 166,  41, 101, 155, 154, 101,  38,  58, 128, 164, 150,
#          92,  33,  56,   3], device='cuda:0')
# loss ：
# tensor(0.4187, device='cuda:0')
# valid_data_j: 37
# Outputs :
# tensor([[ -61.7709, -111.2096,  -93.3338,  ..., -137.9122, -132.1203,
#          -129.6867],
#         [-102.4774,  -86.0152,  -88.4639,  ...,  -95.9048,  -81.9663,
#           -87.2985],
#         [ -25.2670,  -54.9126,  -63.3045,  ...,  -56.9501,  -68.3536,
#           -61.5720],
#         ...,
#         [ -88.4930, -155.9048, -134.2333,  ..., -167.8820, -181.4735,
#          -177.1142],
#         [ -92.8006, -137.3395, -131.6394,  ..., -146.5894, -145.4011,
#          -143.9087],
#         [-102.0423,  -85.1209,  -87.2988,  ...,  -88.5129,  -80.6599,
#           -85.5788]], device='cuda:0')
# labels ：
# tensor([153,  30,  50,  26,  97,  21,  41, 163, 112, 136, 105, 125,  23, 146,
#          11,  26, 160,  33,  43,  72, 121,   2, 127, 151, 136,  18,   0,  60,
#           6, 154,  75,  30], device='cuda:0')
# loss ：
# tensor(0.5957, device='cuda:0')
# valid_data_j: 38
# Outputs :
# tensor([[-107.3330, -149.9087, -142.6591,  ..., -124.0831, -164.8395,
#          -156.9094],
#         [ -88.4017,  -77.3248,  -79.3611,  ...,  -84.0961,  -65.9937,
#           -73.5432],
#         [ -76.1180, -105.0139,  -98.3406,  ...,  -92.6497, -107.0298,
#          -108.5069],
#         ...,
#         [ -68.7770,  -85.3177,  -90.3802,  ...,  -84.5180,  -99.6956,
#           -94.5238],
#         [ -41.7353,  -37.9064,  -32.4388,  ...,  -50.0676,  -56.7249,
#           -49.1304],
#         [  -0.6635,  -64.8744,  -61.7702,  ..., -101.5697,  -88.5285,
#           -81.1525]], device='cuda:0')
# labels ：
# tensor([135,  31,  95, 117,  91,  81,  17, 152,  73, 164, 165,  49, 136, 116,
#         112, 121, 113,  54,  43, 113,  88,  33, 117, 144,  77, 148,  57,  73,
#         158,  80,  13,   0], device='cuda:0')
# loss ：
# tensor(0.5305, device='cuda:0')
# valid_data_j: 39
# Outputs :
# tensor([[ -65.1937,  -13.1113,  -19.2909,  ...,  -23.1147,   -4.8162,
#            -7.4841],
#         [ -90.9847, -117.6689, -118.8503,  ..., -113.2701, -125.7713,
#          -121.8461],
#         [ -85.0643,  -32.5109,  -35.0546,  ...,  -42.9492,  -49.7888,
#           -40.0839],
#         ...,
#         [ -80.8760,  -92.6675,  -93.3264,  ...,  -94.9414,  -96.5572,
#           -94.1814],
#         [ -56.3830,  -75.9664,  -71.3660,  ..., -124.9826,  -77.2449,
#           -81.5826],
#         [ -71.9540,  -69.3362,  -53.8280,  ...,  -91.9781,  -95.8262,
#           -88.2691]], device='cuda:0')
# labels ：
# tensor([166,  40,  18, 124, 152,  82,   9, 125,  24, 156,  18,  45,  12, 161,
#         160, 149, 151,  29, 106,  82,  36,  75,  46, 114,  97, 150, 167,  93,
#          48,  40,  86,  10], device='cuda:0')
# loss ：
# tensor(0.7429, device='cuda:0')
# valid_data_j: 40
# Outputs :
# tensor([[ -88.9923,  -47.4286,  -42.0025,  ...,  -43.2595,  -66.2897,
#           -56.8304],
#         [ -41.4005,  -78.2118,  -85.1861,  ...,  -41.4742,  -97.9506,
#           -87.1064],
#         [ -47.3895,  -79.3575,  -65.9445,  ..., -101.7382,  -95.4206,
#           -93.7524],
#         ...,
#         [ -16.0882,  -53.9221,  -48.5342,  ...,  -95.3941,  -65.0452,
#           -65.4048],
#         [ -35.6407,  -37.2408,  -43.4427,  ...,  -60.6783,  -39.9215,
#           -41.8169],
#         [ -46.9056,  -44.5122,  -46.3734,  ...,  -83.3107,  -39.8686,
#           -45.4119]], device='cuda:0')
# labels ：
# tensor([ 16, 164, 152, 107, 105, 120,  75, 134, 156,  94,  56,  49, 125,  93,
#         152, 100, 112,  90,  34,  48,  76, 147,  55, 164,  81,  66,  42,  51,
#          95,  33,  55,  77], device='cuda:0')
# loss ：
# tensor(0.8998, device='cuda:0')
# valid_data_j: 41
# Outputs :
# tensor([[ -59.1981, -101.8204, -111.2911,  ...,  -51.7508, -127.9951,
#          -113.3781],
#         [ -88.6668, -162.2637, -151.9162,  ..., -132.2285, -182.0572,
#          -171.8447],
#         [ -47.4132, -126.4713, -113.8608,  ..., -135.2547, -144.8205,
#          -139.3356],
#         ...,
#         [-118.7567,  -93.6992,  -97.7476,  ...,  -48.5162, -106.6403,
#           -96.5438],
#         [ -20.0029,  -77.1638,  -68.3057,  ..., -112.0755,  -91.4465,
#           -88.5705],
#         [ -68.7234, -152.3043, -146.7242,  ..., -113.7809, -181.6583,
#          -168.5908]], device='cuda:0')
# labels ：
# tensor([164, 138, 140, 111,  32,  11,   7,  78, 114, 161,  16, 125,  89,  52,
#          10,  70, 137,  77, 130, 157, 153,  44,  64, 115,  61,  60, 120, 147,
#          13, 123, 145, 161], device='cuda:0')
# loss ：
# tensor(0.8566, device='cuda:0')
# valid_data_j: 42
# Outputs :
# tensor([[ -58.8818,  -70.1463,  -72.5076,  ..., -120.1059,  -63.8213,
#           -71.6935],
#         [ -81.4671,  -73.9541,  -75.1526,  ...,  -79.8807,  -63.8729,
#           -70.7730],
#         [ -59.4031,  -56.2561,  -58.7106,  ..., -101.2697,  -50.7481,
#           -57.4649],
#         ...,
#         [ -65.6859,   -3.9197,   -6.9595,  ...,  -23.0260,   -0.7564,
#            -0.7495],
#         [ -88.3640, -114.3408, -104.6302,  ...,  -76.4362, -128.4352,
#          -121.9006],
#         [ -32.3649,  -63.3896,  -66.6712,  ...,  -68.9383,  -78.3963,
#           -73.4499]], device='cuda:0')
# labels ：
# tensor([ 66,  31,  77, 100, 112, 101,  92,  84, 121, 132,  28, 136, 139, 144,
#         137, 127,  65, 164,  40,  88, 161,  67,  48,  55,  29, 113, 111,  34,
#          47, 172, 159,  81], device='cuda:0')
# loss ：
# tensor(0.7514, device='cuda:0')
# valid_data_j: 43
# Outputs :
# tensor([[ -86.0466,  -78.8789,  -82.1114,  ...,  -81.6145,  -59.5801,
#           -68.8357],
#         [ -53.6060,  -59.1705,  -55.2226,  ...,  -38.0380,  -60.6112,
#           -60.2875],
#         [  -9.8513,  -58.6595,  -58.8907,  ...,  -76.6145,  -78.1656,
#           -72.6661],
#         ...,
#         [ -72.5387,  -99.0479, -112.2882,  ...,  -44.7140, -109.1585,
#          -100.1652],
#         [ -45.6298,  -58.8939,  -48.9375,  ...,  -76.6011,  -69.6650,
#           -68.9168],
#         [ -98.5363,  -77.8035,  -80.4086,  ...,  -38.2031,  -87.9941,
#           -80.0582]], device='cuda:0')
# labels ：
# tensor([ 91,  96,  22,   5,  11, 112, 118,  32,  51,  66,  19,  31,  78,  73,
#          57, 137,  63,  27,  84, 110, 154, 122,  49,  52,  63,   5, 147, 149,
#          89, 114, 151, 124], device='cuda:0')
# loss ：
# tensor(0.6827, device='cuda:0')
# valid_data_j: 44
# Outputs :
# tensor([[ -57.1246,  -72.4979,  -60.5117,  ...,  -72.2194,  -87.8315,
#           -83.5610],
#         [ -47.3745,  -85.5704,  -69.9293,  ..., -120.6615, -104.3574,
#          -103.0329],
#         [ -71.9540,  -69.3362,  -53.8280,  ...,  -91.9781,  -95.8262,
#           -88.2691],
#         ...,
#         [ -39.0106,  -75.9855,  -62.2828,  ..., -108.6508,  -93.1935,
#           -91.8863],
#         [ -33.1413,  -54.1050,  -53.7299,  ..., -102.5056,  -58.2186,
#           -61.9384],
#         [ -65.5693,  -67.4664,  -63.6391,  ...,  -73.7634,  -63.7410,
#           -68.3932]], device='cuda:0')
# labels ：
# tensor([157, 148,  10,  81,  91, 154,  47,  52,  93,  31,  84,  33,  58, 108,
#          19,  64,  32,  74,  11, 132, 112, 150, 163, 132,  23, 137,  39, 109,
#         126, 148,  55,  32], device='cuda:0')
# loss ：
# tensor(0.6386, device='cuda:0')
# valid_data_j: 45
# Outputs :
# tensor([[ -25.0192,  -85.2483,  -74.5887,  ..., -121.8550,  -99.8659,
#           -97.2809],
#         [ -24.6757,  -52.7241,  -51.9019,  ...,  -71.3132,  -62.9899,
#           -61.7668],
#         [ -22.8075,  -62.7485,  -65.7412,  ...,  -72.7902,  -81.0281,
#           -74.8743],
#         ...,
#         [ -68.7770,  -85.3177,  -90.3802,  ...,  -84.5180,  -99.6956,
#           -94.5238],
#         [ -59.2957,  -64.2367,  -72.9447,  ...,  -19.6524,  -67.4319,
#           -62.3790],
#         [ -68.3290,  -73.2840,  -78.8608,  ...,  -77.3959,  -55.1957,
#           -62.7998]], device='cuda:0')
# labels ：
# tensor([145,  83,  82, 101, 139, 134, 112,  94,  11, 106,   4,  76,   8,  30,
#          57,  32, 138, 136,  31, 172,  96,  70,  82,  31,  43,  42, 106, 102,
#          94,  80, 116,  65], device='cuda:0')
# loss ：
# tensor(0.6269, device='cuda:0')
# valid_data_j: 46
# Outputs :
# tensor([[ -62.8206,  -76.9503,  -72.9445,  ..., -122.5285,  -75.1989,
#           -80.4983],
#         [ -79.4968,  -21.0335,  -25.2989,  ...,  -28.1665,  -11.1931,
#           -14.6814],
#         [  -9.5336,  -48.7370,  -55.4692,  ...,  -53.4519,  -66.5917,
#           -59.0327],
#         ...,
#         [ -39.9778,  -57.2762,  -54.4895,  ...,  -89.4097,  -67.5464,
#           -65.7382],
#         [ -33.9786,  -89.0603,  -88.6024,  ..., -101.8250, -100.0152,
#           -94.8826],
#         [ -65.1061,  -48.1163,  -52.3769,  ...,  -52.4457,  -32.1908,
#           -38.6331]], device='cuda:0')
# labels ：
# tensor([ 86, 144,  51,  70,  54,  17,  10,  21,  22,  18,   5, 115,  79,  13,
#         155,   8,  94, 168, 125,  77,  15,  82, 120,  73, 134,   5, 147,  85,
#         156,  85,  53,  68], device='cuda:0')
# loss ：
# tensor(0.8737, device='cuda:0')
# valid_data_j: 47
# Outputs :
# tensor([[ -57.1246,  -72.4979,  -60.5117,  ...,  -72.2194,  -87.8315,
#           -83.5610],
#         [ -62.5321,  -44.4315,  -31.2271,  ...,  -73.0370,  -65.0567,
#           -59.1030],
#         [ -70.5706, -115.9765, -113.1444,  ..., -104.0501, -132.8494,
#          -125.9967],
#         ...,
#         [ -73.8729,  -60.2139,  -67.7056,  ...,  -66.6304,  -80.7028,
#           -72.8618],
#         [ -72.4911,  -55.3878,  -62.0412,  ...,  -61.0223,  -67.5299,
#           -63.3955],
#         [ -55.3157,  -15.6242,   -9.3651,  ...,  -38.0382,  -28.2000,
#           -23.0258]], device='cuda:0')
# labels ：
# tensor([157,   7, 131,  67,  15, 138, 168, 156,  66, 145,   9, 121, 103,  33,
#          82, 161, 129,  83,  31, 127,  63, 161,   0,  42, 108,  87,  40, 128,
#          69,  23,  25,   4], device='cuda:0')
# loss ：
# tensor(0.3263, device='cuda:0')
# valid_data_j: 48
# Outputs :
# tensor([[-107.3330, -149.9087, -142.6591,  ..., -124.0831, -164.8395,
#          -156.9094],
#         [ -10.1234,  -66.5815,  -70.2989,  ...,  -78.6611,  -87.5201,
#           -79.1226],
#         [ -83.6118, -115.9998, -114.9869,  ..., -125.4283, -111.9285,
#          -114.7492],
#         ...,
#         [-104.2583, -142.8659, -135.2153,  ..., -117.6110, -158.4552,
#          -150.5410],
#         [ -65.4952,  -49.2782,  -52.8702,  ...,  -54.1135,  -34.1609,
#           -40.3802],
#         [  -2.5337,  -62.4431,  -57.5805,  ...,  -96.2447,  -84.4983,
#           -79.1710]], device='cuda:0')
# labels ：
# tensor([135,  52,  74, 101,  85,  45,  43,  52,  41, 164,  16, 168,  93, 154,
#          47,  32, 169,  33,  53,  92,  31, 139,  53,  50,  83,  43,  16,  98,
#           4, 135,  68,  11], device='cuda:0')
# loss ：
# tensor(1.0020, device='cuda:0')
# valid_data_j: 49
# Outputs :
# tensor([[ -46.8346, -122.2308, -111.0115,  ..., -152.7496, -137.0178,
#          -134.1743],
#         [ -54.8739,  -94.8092, -103.9481,  ...,  -48.9784, -119.7381,
#          -105.9490],
#         [ -19.6285,  -78.1242,  -79.5638,  ...,  -93.3064,  -94.8952,
#           -88.2519],
#         ...,
#         [ -65.6859,   -3.9197,   -6.9595,  ...,  -23.0260,   -0.7564,
#            -0.7495],
#         [-113.5460, -110.8323, -112.2923,  ...,  -61.8143, -125.5084,
#          -116.2112],
#         [ -49.2219,  -23.0302,  -29.9416,  ...,  -38.4724,  -37.5877,
#           -30.8529]], device='cuda:0')
# labels ：
# tensor([ 60, 164,  52,  38,  75, 157, 137,  28,  46, 126, 153,  81,  73, 131,
#          41,  29,  58, 107,   3, 113, 104,  30,  61,  52, 128,  56,  67,  10,
#          78, 172, 126,  20], device='cuda:0')
# loss ：
# tensor(0.3464, device='cuda:0')
# valid_data_j: 50
# Outputs :
# tensor([[ -57.1548,  -52.7777,  -38.8380,  ...,  -79.8336,  -73.0133,
#           -68.1384],
#         [ -94.5532, -136.2916, -131.1508,  ..., -144.4193, -143.4648,
#          -142.2783],
#         [ -88.6668, -162.2637, -151.9162,  ..., -132.2285, -182.0572,
#          -171.8447],
#         ...,
#         [ -74.2566,  -89.0805,  -70.7983,  ..., -118.5973, -117.1652,
#          -110.2572],
#         [ -92.0600, -160.9117, -149.3996,  ..., -129.3197, -180.2719,
#          -170.5732],
#         [ -49.8254,  -83.9563,  -69.8192,  ..., -107.9135,  -97.6519,
#           -96.6268]], device='cuda:0')
# labels ：
# tensor([  9,  75, 138, 104, 168, 121, 156,  19, 129,  10, 142, 122,  87, 133,
#         150, 125, 139,   8,   5, 163,  78,  56, 156,   9,  84,  83, 114, 129,
#         139,   9, 137, 147], device='cuda:0')
# loss ：
# tensor(0.8830, device='cuda:0')
# valid_data_j: 51
# Outputs :
# tensor([[ -93.8829,  -87.7427,  -84.0704,  ...,  -69.9754, -106.5194,
#           -97.3424],
#         [ -67.3529,  -45.1270,  -50.3530,  ...,  -31.3434,  -42.7225,
#           -39.4721],
#         [ -61.2049,  -20.0924,  -29.3937,  ...,  -40.3323,   -6.6456,
#           -12.4046],
#         ...,
#         [ -77.4560, -102.0802, -109.1020,  ...,  -94.7519, -111.9975,
#          -105.8718],
#         [ -28.3235,  -68.7757,  -71.6510,  ...,  -79.3828,  -86.9934,
#           -80.9800],
#         [ -68.7770,  -85.3177,  -90.3802,  ...,  -84.5180,  -99.6956,
#           -94.5238]], device='cuda:0')
# labels ：
# tensor([125, 105, 155,  39,  95, 102,  79,  54, 100,  12, 171,  40, 125, 129,
#          32, 123,  26,  94, 151,  53,  52,   3, 155,   4,  31, 102, 153, 158,
#          51,  42,  82,  80], device='cuda:0')
# loss ：
# tensor(0.9798, device='cuda:0')
# valid_data_j: 52
# Outputs :
# tensor([[ -34.9939,  -99.1763,  -88.5857,  ..., -129.1736, -113.5000,
#          -111.0824],
#         [ -69.3231,  -71.9149,  -68.5884,  ...,  -80.9909,  -66.1419,
#           -71.8071],
#         [ -82.7500, -116.7546, -124.9256,  ..., -110.2343, -126.8598,
#          -120.3109],
#         ...,
#         [  -2.5616,  -60.4689,  -53.3858,  ...,  -99.6818,  -80.0863,
#           -76.2647],
#         [-121.8664,  -96.7382,  -99.6178,  ...,  -45.9525, -108.8810,
#           -99.3474],
#         [-120.2324,  -94.4404, -106.8416,  ...,  -18.0211,  -85.2695,
#           -83.7410]], device='cuda:0')
# labels ：
# tensor([ 60,  32,  42, 161, 101,  23,  86,  28, 165,   8,  38, 153,  57, 146,
#         163,  77, 155,  90,  26,  73,  61, 156,  62,  80, 115,  94,  46,  37,
#         108,  88, 123, 118], device='cuda:0')
# loss ：
# tensor(0.3500, device='cuda:0')
# valid_data_j: 53
# Outputs :
# tensor([[ -47.4124,  -75.3467,  -74.9489,  ...,  -97.5963,  -72.9565,
#           -75.0256],
#         [ -87.7326,  -19.6345,  -24.6839,  ...,  -25.9934,  -11.5715,
#           -13.8986],
#         [ -89.2269,  -59.2750,  -61.8915,  ...,  -88.4007,  -47.2392,
#           -55.4032],
#         ...,
#         [ -73.9114, -136.9569, -125.6388,  ..., -115.4451, -153.6946,
#          -146.5192],
#         [ -73.4689,  -81.4337,  -83.8950,  ...,  -77.8000,  -92.2969,
#           -86.2384],
#         [-112.0955,  -80.6672,  -87.3554,  ...,  -76.7963,  -88.1807,
#           -86.8886]], device='cuda:0')
# labels ：
# tensor([ 64, 144,  89, 160,  91, 101,  47,  77,   9, 168,  14,  18, 104,  80,
#          21, 128,  52,   0,  61,   9, 157, 114, 119, 168,  38,  61, 121, 114,
#         101, 137,  41,  26], device='cuda:0')
# loss ：
# tensor(0.6231, device='cuda:0')
# valid_data_j: 54
# Outputs :
# tensor([[-107.9838,  -84.1671,  -86.3236,  ...,  -76.7537,  -82.0723,
#           -84.9909],
#         [-112.2911,  -93.8848, -100.7820,  ...,  -53.8226,  -71.3418,
#           -80.1599],
#         [ -88.5578,  -98.5239, -113.1745,  ...,  -33.2213, -105.6226,
#           -96.5244],
#         ...,
#         [ -34.0742,  -63.5450,  -62.1430,  ..., -116.3315,  -72.6557,
#           -75.0634],
#         [ -54.5452,  -83.4894,  -93.5478,  ...,  -43.2607,  -85.8902,
#           -82.0222],
#         [-125.0179, -199.9818, -189.7990,  ..., -154.4381, -219.3786,
#          -208.7563]], device='cuda:0')
# labels ：
# tensor([ 29,  99, 115,   4, 133,  66, 150,  45, 105, 146,  33, 106,  46,  55,
#         143,  87,  34, 131,  87, 139, 167,  83,  11,  64,  63,  62, 101,  76,
#          98,  44, 113, 136], device='cuda:0')
# loss ：
# tensor(0.9146, device='cuda:0')
# valid_data_j: 55
# Outputs :
# tensor([[-103.8690, -134.1494, -133.2589,  ..., -114.2690, -145.2567,
#          -139.2119],
#         [ -98.8817,  -93.9287,  -90.3183,  ...,  -71.3785, -112.4097,
#          -103.1810],
#         [ -41.2512,  -70.3676,  -80.1370,  ...,  -66.1330,  -88.3121,
#           -78.4967],
#         ...,
#         [ -80.8760,  -92.6675,  -93.3264,  ...,  -94.9414,  -96.5572,
#           -94.1814],
#         [ -68.3290,  -73.2840,  -78.8608,  ...,  -77.3959,  -55.1957,
#           -62.7998],
#         [ -23.3807,  -86.8643,  -77.5250,  ..., -127.2842, -102.9895,
#           -99.6096]], device='cuda:0')
# labels ：
# tensor([134, 125,  45, 141,  20,  28,  22, 127,  89, 169,  35,  72, 102, 140,
#          87,  27, 114, 103, 163, 142, 143,  24,  57,  48,  77, 124,  73,  24,
#         116,  40,  65, 145], device='cuda:0')
# loss ：
# ...
#           -60.2566],
#         [ -41.7757, -126.5856, -112.3143,  ..., -150.1182, -145.6923,
#          -141.3746],
#         ...,
#         [ -48.0707,  -64.2343,  -52.9691,  ...,  -92.3972,  -74.4130,
#           -74.9439],
#         [ -38.1823,  -75.2196,  -61.5694,  ..., -108.0105,  -92.4974,
#           -91.1339],
#         [ -96.0660,  -81.1186,  -87.3156,  ...,  -22.9537,  -91.4188,
#           -82.9136]], device='cuda:0')
# labels ：
# tensor([ 23, 168, 141,   1,  45,  92, 131,  21,  16, 117, 138, 132,  75,   1,
#          88, 120, 121, 111,  55,  43, 152,   6,  83,  99,  50, 164,  76, 172,
#          33, 150, 148, 167], device='cuda:0')
# loss ：
# tensor(1.0114, device='cuda:0')
# valid_data_j: 1303
# Outputs :
# tensor([[ -75.6582,  -80.4404,  -80.1789,  ...,  -90.0679,  -72.6358,
#           -78.1399],
#         [ -65.4952,  -49.2782,  -52.8702,  ...,  -54.1135,  -34.1609,
#           -40.3802],
#         [ -26.8759,  -73.4315,  -70.2199,  ...,  -86.7330,  -82.2142,
#           -78.0452],
#         ...,
#         [ -38.0336,  -54.2646,  -45.2228,  ...,  -81.1449,  -64.0835,
#           -64.1341],
#         [ -14.6026,  -68.1918,  -59.0718,  ..., -117.1749,  -86.0212,
#           -84.7359],
#         [-111.8833, -102.7591, -110.4031,  ...,  -49.8849, -116.8443,
#          -106.8943]], device='cuda:0')
# labels ：
# tensor([ 35,  68,  57,  42, 143,  47,  61,  86,  15,   2,  65,  49,  62, 133,
#         107,  43, 108, 139,  86,  74,  15, 118,  67,  13, 138, 100,  23,  84,
#          71, 150,  33, 127], device='cuda:0')
# loss ：
# tensor(0.7991, device='cuda:0')
# valid_data_j: 1304
# Outputs :
# tensor([[ -14.6026,  -68.1918,  -59.0718,  ..., -117.1749,  -86.0212,
#           -84.7359],
#         [ -68.3751,  -51.0413,  -56.3703,  ...,  -55.1287,  -62.3168,
#           -58.2521],
#         [ -74.9293,   -2.5950,   -0.6631,  ...,  -29.2785,  -10.1494,
#            -5.8538],
#         ...,
#         [ -88.6668, -162.2637, -151.9162,  ..., -132.2285, -182.0572,
#          -171.8447],
#         [ -72.1102,  -78.4336,  -76.3521,  ...,  -86.8489,  -73.1189,
#           -77.7248],
#         [-102.0423,  -85.1209,  -87.2988,  ...,  -88.5129,  -80.6599,
#           -85.5788]], device='cuda:0')
# labels ：
# tensor([ 33,  25,   3,  36,  84, 164, 129,  22, 169,  73,  99, 167,  57, 158,
#          98, 124,  37,  75,  22, 139,  71,  50, 172,  81, 111,  11, 123,  92,
#         166, 138,  35,  30], device='cuda:0')
# loss ：
# tensor(0.6015, device='cuda:0')
# valid_data_j: 1305
# Outputs :
# tensor([[-101.6187,  -67.1398,  -76.5129,  ...,  -14.8742,  -61.5255,
#           -60.1715],
#         [ -19.6285,  -78.1242,  -79.5638,  ...,  -93.3064,  -94.8952,
#           -88.2519],
#         [ -93.4817,  -10.5371,  -15.7974,  ...,  -41.2007,   -0.1279,
#            -2.7557],
#         ...,
#         [ -63.9956,  -65.9173,  -63.1201,  ...,  -78.5246,  -57.8898,
#           -64.4350],
#         [ -11.4007,  -76.6486,  -81.5522,  ...,  -88.6312, -101.3093,
#           -91.3071],
#         [ -60.7870,  -63.1421,  -47.5548,  ...,  -92.1710,  -84.8836,
#           -80.1039]], device='cuda:0')
# labels ：
# tensor([119,  52, 171,  14,  97,  99, 143,  86, 130,  54, 123, 115, 138,  29,
#          43,  43,  56,  99,  23, 147,  96,  95, 109, 170,  80,  37,  50,  39,
#         171,  34,  52,   8], device='cuda:0')
# loss ：
# tensor(0.6411, device='cuda:0')
# valid_data_j: 1306
# Outputs :
# tensor([[ -60.2163,   -0.6461,   -1.4552,  ...,  -18.8923,   -4.7298,
#            -1.5630],
#         [ -65.0743,  -42.0845,  -49.5687,  ...,  -59.2082,  -27.8184,
#           -34.1217],
#         [-120.8501,  -86.8355,  -93.9951,  ...,  -29.9631,  -91.6868,
#           -84.6871],
#         ...,
#         [ -53.6380, -116.6342, -102.1519,  ..., -118.6365, -138.7200,
#          -132.9163],
#         [-102.4701, -142.1602, -135.0347,  ..., -118.8173, -156.8072,
#          -149.1587],
#         [ -88.6668, -162.2637, -151.9162,  ..., -132.2285, -182.0572,
#          -171.8447]], device='cuda:0')
# labels ：
# tensor([  1,  72, 121,  71,  52, 102, 106,  34, 122, 157,  14,  61,  10,  42,
#         157,  79,  17, 151,  25,  74,  34, 147, 102, 117,  59,  22,  90, 124,
#           8, 156, 135, 138], device='cuda:0')
# loss ：
# tensor(0.5748, device='cuda:0')
# valid_data_j: 1307
# Outputs :
# tensor([[  -3.9169,  -68.3088,  -59.7166,  ..., -109.7632,  -90.7132,
#           -86.4114],
#         [ -69.1495,  -77.6109,  -82.7359,  ...,  -46.7911,  -89.2195,
#           -82.0036],
#         [ -86.5947,  -77.0119,  -84.8878,  ...,  -81.4749,  -52.8768,
#           -64.3918],
#         ...,
#         [ -45.7028, -116.1630, -108.9601,  ..., -134.7186, -126.6936,
#          -123.0462],
#         [ -51.5749,  -63.2679,  -64.9628,  ..., -110.4184,  -58.4768,
#           -65.4304],
#         [ -68.7770,  -85.3177,  -90.3802,  ...,  -84.5180,  -99.6956,
#           -94.5238]], device='cuda:0')
# labels ：
# tensor([ 11, 129,  67,  12, 130, 114, 121,  84,   1, 163, 144, 138,  69,   0,
#          85, 145,   8, 163, 114, 145,  38,  82, 140, 153, 150,  48, 160,  51,
#           6,  58,  66,  80], device='cuda:0')
# loss ：
# tensor(0.4840, device='cuda:0')
# valid_data_j: 1308
# Outputs :
# tensor([[-4.7684e+01, -6.1537e+01, -5.1352e+01,  ..., -7.7581e+01,
#          -7.3071e+01, -7.2026e+01],
#         [-1.2972e+02, -1.2762e+02, -1.2921e+02,  ..., -7.1468e+01,
#          -1.4442e+02, -1.3383e+02],
#         [-4.9262e+01, -3.8242e+01, -4.6485e+01,  ..., -5.0636e+01,
#          -4.6684e+01, -4.4552e+01],
#         ...,
#         [-2.9866e+01, -6.5812e+01, -6.8750e+01,  ..., -7.5480e+01,
#          -8.2735e+01, -7.7305e+01],
#         [-7.0312e+01, -2.9974e+01, -3.8196e+01,  ..., -1.2664e-02,
#          -3.1567e+01, -2.6298e+01],
#         [-2.8813e+01, -9.3120e+01, -9.3733e+01,  ..., -1.0811e+02,
#          -1.0823e+02, -1.0181e+02]], device='cuda:0')
# labels ：
# tensor([152, 126,  24, 117, 137,   9,   5,  61,   6, 104,  79,   1,  21,  50,
#          68,  45,  66, 166, 100, 129, 152,  86,  15,  38,  74, 169,  79, 103,
#         153,  82, 170,  56], device='cuda:0')
# loss ：
# tensor(0.7920, device='cuda:0')
# valid_data_j: 1309
# Outputs :
# tensor([[-5.8533e+01, -1.3000e+02, -1.2651e+02,  ..., -9.4156e+01,
#          -1.5414e+02, -1.4328e+02],
#         [-7.7649e+01, -8.7408e+00, -1.3449e+01,  ..., -3.2241e+01,
#          -3.1120e-01, -2.3555e+00],
#         [-7.5072e+01, -9.1739e+01, -9.4683e+01,  ..., -6.4243e+01,
#          -1.0624e+02, -9.8714e+01],
#         ...,
#         [-7.0312e+01, -2.9974e+01, -3.8196e+01,  ..., -1.2664e-02,
#          -3.1567e+01, -2.6298e+01],
#         [-7.8267e+01, -8.0618e+01, -7.6925e+01,  ..., -8.8869e+01,
#          -7.4533e+01, -8.0581e+01],
#         [-2.9565e+01, -8.7367e+01, -8.7785e+01,  ..., -6.7169e+01,
#          -1.0649e+02, -9.8137e+01]], device='cuda:0')
# labels ：
# tensor([161, 171, 130,  62,  57,  99,  22, 113, 145,  86,  35, 170, 165, 126,
#          40,  26,  26,  98,  62,  21, 126,  50, 107,  62,  71, 158,  66,  92,
#         140, 170,  32, 162], device='cuda:0')
# loss ：
# tensor(0.6319, device='cuda:0')
# valid_data_j: 1310
# Outputs :
# tensor([[ -80.4027,  -61.0511,  -62.6083,  ...,  -67.7962,  -62.3573,
#           -60.4995],
#         [  -2.5616,  -60.4689,  -53.3858,  ...,  -99.6818,  -80.0863,
#           -76.2647],
#         [ -20.0029,  -77.1638,  -68.3057,  ..., -112.0755,  -91.4465,
#           -88.5705],
#         ...,
#         [ -80.8760,  -92.6675,  -93.3264,  ...,  -94.9414,  -96.5572,
#           -94.1814],
#         [-129.6849, -127.4383, -128.6687,  ...,  -73.2925, -143.9100,
#          -133.7055],
#         [  -3.4697,  -61.5770,  -55.5684,  ...,  -95.3227,  -82.2592,
#           -77.7070]], device='cuda:0')
# labels ：
# tensor([ 37,  88, 145, 133,  32,  33, 144,  93,  56,  59,  55,  68,  47,  57,
#          19,  55,  39, 120,  22,  44,   9,  12, 162, 102, 133, 137, 170,  17,
#          76,  40, 126,  22], device='cuda:0')
# loss ：
# tensor(0.9078, device='cuda:0')
# valid_data_j: 1311
# Outputs :
# tensor([[ -25.2670,  -54.9126,  -63.3045,  ...,  -56.9501,  -68.3536,
#           -61.5720],
#         [ -62.8206,  -76.9503,  -72.9445,  ..., -122.5285,  -75.1989,
#           -80.4983],
#         [ -72.2596,  -71.9664,  -78.0832,  ...,  -77.2714,  -51.9900,
#           -61.6536],
#         ...,
#         [ -68.4002,  -97.3142,  -92.5748,  ...,  -87.3867,  -95.9110,
#           -98.5748],
#         [ -66.1487,  -27.4092,  -22.6263,  ...,  -30.2767,  -39.0224,
#           -33.5661],
#         [ -13.5448,  -50.0196,  -56.0038,  ...,  -55.7375,  -61.2085,
#           -56.6444]], device='cuda:0')
# labels ：
# tensor([ 50,  86,  67,  68,  67, 124,  13, 129, 162,  49, 144,  28, 162, 125,
#          23, 128, 142,  67, 144,  32, 125,  55,  72,  58,  16, 162,  90,  71,
#         163,  94,  15,  51], device='cuda:0')
# loss ：
# tensor(0.8488, device='cuda:0')
# valid_data_j: 1312
# Outputs :
# tensor([[ -33.1413,  -54.1050,  -53.7299,  ..., -102.5056,  -58.2186,
#           -61.9384],
#         [-112.8527,  -77.9710,  -85.0997,  ...,  -25.2003,  -80.0056,
#           -74.7980],
#         [ -68.3290,  -73.2840,  -78.8608,  ...,  -77.3959,  -55.1957,
#           -62.7998],
#         ...,
#         [ -24.8692, -106.8396, -106.8483,  ..., -131.7115, -130.1709,
#          -121.3505],
#         [ -82.4145,  -14.7152,  -21.4957,  ...,  -32.4211,   -2.0164,
#            -5.9844],
#         [ -88.4017,  -77.3248,  -79.3611,  ...,  -84.0961,  -65.9937,
#           -73.5432]], device='cuda:0')
# labels ：
# tensor([ 55, 120,  65, 168, 155, 161, 111,  35,   8,  13,  15,  46,  29, 154,
#          39,  50,  28, 100,  80,  75,  28, 155, 105,  28, 159,   3,  31,  67,
#          80,  53, 166,  31], device='cuda:0')
# loss ：
# tensor(0.6191, device='cuda:0')
# valid_data_j: 1313
# Outputs :
# tensor([[ -65.1271, -131.3945, -124.7261,  ..., -149.0075, -141.2088,
#          -138.9466],
#         [ -14.6026,  -68.1918,  -59.0718,  ..., -117.1749,  -86.0212,
#           -84.7359],
#         [ -77.6492,   -8.7408,  -13.4490,  ...,  -32.2414,   -0.3112,
#            -2.3555],
#         ...,
#         [ -32.3649,  -63.3896,  -66.6712,  ...,  -68.9383,  -78.3963,
#           -73.4499],
#         [ -37.3423,  -89.4971,  -89.6221,  ...,  -99.7599,  -99.3905,
#           -94.1992],
#         [ -68.0591, -101.7481,  -99.8267,  ...,  -88.2550, -117.3739,
#          -110.8855]], device='cuda:0')
# labels ：
# tensor([ 59,  33, 171,  48, 149,  99, 147,  14,  80,  85, 166,  75,  42, 130,
#         147,   5, 144, 108, 133,  82, 123, 155, 132, 140, 170, 103, 169, 153,
#          52,  81,  54, 131], device='cuda:0')
# loss ：
# tensor(0.4940, device='cuda:0')
# valid_data_j: 1314
# Outputs :
# tensor([[ -75.2481, -136.8672, -118.1313,  ..., -149.3251, -158.8978,
#          -155.3116],
#         [ -55.1773,  -85.9627,  -73.1356,  ...,  -82.2150, -102.6957,
#           -98.0359],
#         [-102.0423,  -85.1209,  -87.2988,  ...,  -88.5129,  -80.6599,
#           -85.5788],
#         ...,
#         [  -0.5542,  -62.9312,  -58.7051,  ...,  -98.4890,  -85.6980,
#           -79.0456],
#         [ -97.8140,  -13.7957,   -7.1129,  ...,  -48.7704,  -28.8175,
#           -21.9002],
#         [ -69.1495,  -77.6109,  -82.7359,  ...,  -46.7911,  -89.2195,
#           -82.0036]], device='cuda:0')
# labels ：
# tensor([154, 158,  30,  99, 106,  36, 133, 112,  77, 122,  54, 140,  39, 118,
#         164, 111, 116,  66,  53, 168,  61,   2, 108,  71, 172,  39, 101, 170,
#         101,   0,   4, 129], device='cuda:0')
# loss ：
# tensor(0.6045, device='cuda:0')
# valid_data_j: 1315
# Outputs :
# tensor([[ -55.8849, -114.5365, -108.8270,  ..., -132.1977, -123.1550,
#          -121.3311],
#         [ -68.6840,  -43.1110,  -51.1595,  ...,  -60.1694,  -28.8085,
#           -34.9538],
#         [-101.6187,  -67.1398,  -76.5129,  ...,  -14.8742,  -61.5255,
#           -60.1715],
#         ...,
#         [-107.3330, -149.9087, -142.6591,  ..., -124.0831, -164.8395,
#          -156.9094],
#         [ -61.7709, -111.2096,  -93.3338,  ..., -137.9122, -132.1203,
#          -129.6867],
#         [ -61.7709, -111.2096,  -93.3338,  ..., -137.9122, -132.1203,
#          -129.6867]], device='cuda:0')
# labels ：
# tensor([ 59,  71, 119,  75,  78,  41,  18, 118,  98, 168,  16, 171,  66,  63,
#          35,   5,  71,  92, 126,  47, 172,  67,  41,  87, 134, 116, 171, 138,
#         110, 135, 153, 153], device='cuda:0')
# loss ：
# tensor(0.7377, device='cuda:0')
# valid_data_j: 1316
# Outputs :
# tensor([[ -79.3560,  -58.4023,  -64.2785,  ...,  -63.1930,  -36.7448,
#           -45.8201],
#         [ -32.9351,  -73.6761,  -84.2586,  ...,  -77.7323,  -97.1106,
#           -86.0137],
#         [  -0.5956,  -68.1152,  -63.1718,  ..., -106.5596,  -92.7657,
#           -86.0825],
#         ...,
#         [ -92.0600, -160.9117, -149.3996,  ..., -129.3197, -180.2719,
#          -170.5732],
#         [ -57.7888,  -50.3926,  -40.4775,  ...,  -64.8287,  -73.2331,
#           -64.7902],
#         [-102.4701, -142.1602, -135.0347,  ..., -118.8173, -156.8072,
#          -149.1587]], device='cuda:0')
# labels ：
# tensor([ 91,  48,   0,  39, 158, 109, 127,  14, 137,   5,  29,  71,  87,  74,
#         165, 149,  36,   7,  88, 141, 125, 103, 150,  30,  10,  12,  94,  66,
#          49, 137,  12, 135], device='cuda:0')
# loss ：
# tensor(0.6708, device='cuda:0')
# valid_data_j: 1317
# Outputs :
# tensor([[ -72.2596,  -71.9664,  -78.0832,  ...,  -77.2714,  -51.9900,
#           -61.6536],
#         [ -13.5448,  -50.0196,  -56.0038,  ...,  -55.7375,  -61.2085,
#           -56.6444],
#         [ -91.4730,  -78.2992,  -76.5586,  ...,  -46.6835,  -93.5715,
#           -84.5122],
#         ...,
#         [ -71.5576,  -87.5575,  -89.0019,  ...,  -83.4258,  -94.9571,
#           -93.2524],
#         [ -91.0841,  -38.8489,  -40.7185,  ...,  -32.7153,  -52.5706,
#           -43.5984],
#         [ -82.8552,  -95.6041, -105.3037,  ...,  -27.5309,  -94.3434,
#           -90.2241]], device='cuda:0')
# labels ：
# tensor([ 67,  51, 124, 157, 107,  82,  18,  68, 167,   6,  37,  58, 115,  38,
#          88,  34,  96,  34, 115,  67, 105, 121,  50,   7,  14,  21,  16,  21,
#          92,  79,  17, 116], device='cuda:0')
# loss ：
# tensor(0.5977, device='cuda:0')
# valid_data_j: 1318
# Outputs :
# tensor([[ -27.0523,  -78.6135,  -67.6979,  -62.8585,  -53.1700,  -52.8143,
#           -46.7314,  -42.6785,  -38.0865,  -31.1505,  -39.4560,  -24.2176,
#           -48.1159,  -58.8136,  -73.7783,  -81.4454,  -81.9966,  -95.3118,
#           -93.6513,  -91.0800,  -93.9078,  -83.0965,  -39.3803,  -79.4069,
#           -76.5256,  -85.6686,  -94.9104,  -98.1201,  -87.2593,  -96.6491,
#           -80.5376,  -81.2346,  -63.7146,  -34.9365,  -46.2030,  -46.1529,
#           -44.4791,  -49.8165,  -48.4998,  -49.9507,  -54.5456,  -69.8228,
#           -83.4075,  -88.2491,  -51.8764,  -83.0644,  -69.2952,  -69.3042,
#           -65.0690,  -61.6056,  -63.0608,  -65.2254,  -55.9621,  -51.1522,
#           -50.3689,  -63.2043,  -52.1708,  -42.1007,  -39.4536,  -37.5767,
#           -18.4968,  -17.9733,  -26.8195,  -33.4993,  -43.0837,  -49.1740,
#           -49.9853,  -58.5020,  -60.1187,  -72.8839,  -73.0426,  -59.8701,
#           -41.2164,  -47.4266,  -36.8693,  -29.4191,  -45.5870,  -63.2817,
#           -31.1060,  -46.3962,  -44.7704,  -37.1613,  -38.6291,  -25.9980,
#           -27.5170,  -36.3438,  -30.5861,  -28.4060,  -25.7160,  -76.6153,
#           -42.7162,  -53.8959,  -58.0484,  -44.0338,  -55.9482,  -62.3862,
#           -83.2927,  -90.5793, -110.7694, -106.7315,  -78.8979,  -87.6905,
#           -94.0321,  -95.9499,  -85.0430,  -69.5696,  -74.7436,  -68.3496,
#           -62.7798,  -72.0877,  -65.3604,  -85.5822,  -80.7349,  -82.1845,
#           -93.5889, -105.5502, -102.4823, -110.0886, -131.4836, -123.4103,
#          -106.4670,  -95.0122,  -88.0363,  -84.3983,  -76.0312,  -85.3205,
#          -103.0339,  -94.1852,  -89.1740,  -69.0656,  -61.5762,  -51.3778,
#           -61.1523,  -99.4797,  -62.1209,  -60.1926,  -53.7353,  -43.4553,
#           -34.9004,  -26.5827,  -16.6313,  -10.0933,   -3.4648,   -0.9192,
#           -98.3780,   -0.7618,   -2.2734,  -10.2925,  -20.5866,  -32.5401,
#           -36.6365,  -42.0402,  -28.0003,  -26.5894,  -34.3961,  -93.3872,
#           -30.2021,  -44.3685,  -56.5896,  -58.7111,  -73.9630,  -57.9067,
#           -61.0530,  -64.3302,  -70.1768,  -77.0591, -101.0686,  -90.7778,
#           -88.1273, -102.6040, -106.9819,  -89.5509,  -87.9556]],
#        device='cuda:0')
# labels ：
# tensor([146], device='cuda:0')
# loss ：
# tensor(2.2734, device='cuda:0')

# %% [markdown]
# 验证集 结果：准确率、误差图像
# -

# %%
history.append([avg_valid_loss, avg_valid_acc])

print("Validation: Loss: {:.4f}, Accuracy: {:.4f}%".format(
    avg_valid_loss, avg_valid_acc*100
))
# print("Validation: MSE: {:.4f}".format( ))

diff = predictions_all - labels_all
conc_all = torch.cat((labels_all,predictions_all,diff),dim=0)

plt.scatter(labels_all[0:50000].cpu(),diff[0:50000].cpu(),s=5)
# plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('labels')
plt.ylabel('diff')
# plt.ylim(0, 1)
# plt.savefig("C:\\Users\\nanolab115\Desktop\\"+"diff1.png")
plt.show()

plt.scatter(labels_all[0:50000].cpu(),predictions_all[0:50000].cpu(),s=5)
# plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('labels')
plt.ylabel('predictions')
# plt.ylim(0, 1)
# plt.savefig("C:\\Users\\nanolab115\Desktop\\"+"diff1.png")
plt.show()
# Out:
# Validation: Loss: 0.6523, Accuracy: 81.3216%

# %% [markdown]
# 测试组：用未训练的 0104-2组 进行测试
# -

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

cudnn.benchmark = True
plt.ion()   # interactive mode

# Data augmentation and normalization for training
# Just normalization for validation
image_transforms  = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees = 45),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# dataset = 'E:\gmd_data\microsphere2_dataAugmented'
# dataset = 'E:\gmd_data\GMD_0104_2_DATA' # 测试集 0104-2
# dataset = 'E:\gmd_data\GMD_0104_3_DATA' # 测试集 0104-3
dataset = 'E:\gmd_data\\fangdai_MixTest' # 防呆测试 0104-2-3混合
# dataset = 'E:\gmd_data\GMD_0104_2_DATA_TEST' # 测试集 0104-2 50-8650 照明测试

# train_directory = os.path.join(dataset, 'train')
valid_directory = os.path.join(dataset, 'valid')

batch_size = 32
# num_classes = 173
class Datset():
    def __getitem(self,index):
        
        return image_torch
    def __len__(self):
        pass

data = {
    # 'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),
    'valid':Datset(root=valid_directory, transform=image_transforms['valid'])

}


# train_data_size = len(data['train'])
valid_data_size = len(data['valid'])

# train_data = DataLoader(data['train'], batch_size=batch_size, shuffle=True)
valid_data = DataLoader(data['valid'], batch_size=batch_size, shuffle=True)

print("Validation: valid_data_size: {:.4f}".format(
    valid_data_size
))


# 导入模型 将验证集和真值对比图画出来
dataset = 'E:\gmd_data\microsphere2_dataAugmented'
model38 = torch.load( dataset+'/models/'+'model_38.pt')
for param in model38.parameters():
    param.requires_grad = False
model38 = model38.to('cuda:0')
loss_function = nn.NLLLoss()



device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
history = []
best_acc = 0.0
best_epoch = 0


valid_loss = 0.0
valid_acc = 0.0

predictions_all = torch.tensor([]).to(device)
labels_all = torch.tensor([]).to(device)

with torch.no_grad():
    model38.eval()
    for j, (inputs, labels) in enumerate(valid_data):
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model38(inputs)

        loss = loss_function(outputs, labels)
        # print("valid_data_j: {}".format(j))
        # print("Outputs : ")
        # print(outputs)
        # print("labels ：")
        # print(labels)
        # print("loss ：")
        # print(loss)

        valid_loss += loss.item() * inputs.size(0)

        ret, predictions = torch.max(outputs.data, 1)

        predictions_all = torch.cat((predictions_all,predictions),dim=0)
        labels_all = torch.cat((labels_all,labels),dim=0)

        correct_counts = predictions.eq(labels.data.view_as(predictions))

        acc = torch.mean(correct_counts.type(torch.FloatTensor))

        valid_acc += acc.item() * inputs.size(0)

avg_valid_loss = valid_loss/valid_data_size
avg_valid_acc = valid_acc/valid_data_size

avg_valid_loss = valid_loss/valid_data_size
avg_valid_acc = valid_acc/valid_data_size

# plot
history.append([avg_valid_loss, avg_valid_acc])

print("Validation: Loss: {:.4f}, Accuracy: {:.4f}%".format(
    avg_valid_loss, avg_valid_acc*100
))
# print("Validation: MSE: {:.4f}".format( ))

diff = predictions_all - labels_all
conc_all = torch.cat((labels_all,predictions_all,diff),dim=0)

plt.scatter(labels_all[0:50000].cpu(),diff[0:50000].cpu(),s=5)
# plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('labels')
plt.ylabel('diff')
# plt.ylim(0, 1)
# plt.savefig("C:\\Users\\nanolab115\Desktop\\"+"diff1.png")
plt.show()

plt.scatter(labels_all.cpu(),predictions_all.cpu(),s=5)
# plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('labels')
plt.ylabel('predictions')
# plt.ylim(0, 1)
# plt.savefig("C:\\Users\\nanolab115\Desktop\\"+"diff1.png")
plt.show()
# Out:
# Validation: valid_data_size: 3060.0000
# Validation: Loss: 539.8091, Accuracy: 0.3268%

# %% [markdown]
# Test Command
# ------

# %%
value,num = torch.max(outputs, 1)
print("num:",num,"value:",value)
# Out:
# num: tensor([168], device='cuda:0') value: tensor([-0.0022], device='cuda:0')

# %%
print("outputs:",outputs)

outputs1 = torch.cat((outputs,outputs),dim=0)
print("outputs1:",outputs1)

value,num = torch.max(outputs1, 1)
print("num:",num,"value:",value)
# Out:
# outputs: tensor([[-4.9504e+01, -5.5556e+01, -6.4833e+01, -7.4970e+01, -8.5962e+01,
#          -8.8016e+01, -9.6433e+01, -1.0100e+02, -9.9389e+01, -1.0482e+02,
#          -1.0389e+02, -4.7640e+01, -8.3659e+01, -7.6490e+01, -6.6539e+01,
#          -6.6105e+01, -6.2998e+01, -6.6530e+01, -6.1330e+01, -5.6204e+01,
#          -3.3516e+01, -3.4015e+01, -2.9832e+01, -5.1219e+01, -5.1118e+01,
#          -7.7792e+01, -8.0729e+01, -8.7210e+01, -7.7605e+01, -1.0523e+02,
#          -9.8735e+01, -1.0985e+02, -1.2003e+02, -4.8393e+01, -1.2292e+02,
#          -1.2874e+02, -1.2656e+02, -1.1117e+02, -1.1285e+02, -1.0200e+02,
#          -9.0714e+01, -8.9426e+01, -7.5569e+01, -6.9013e+01, -4.4566e+01,
#          -5.4173e+01, -5.0531e+01, -4.3763e+01, -4.0917e+01, -4.7471e+01,
#          -4.0777e+01, -4.0884e+01, -4.5677e+01, -6.0832e+01, -6.6128e+01,
#          -3.3768e+01, -6.3326e+01, -8.3918e+01, -8.3963e+01, -7.3704e+01,
#          -1.0347e+02, -9.3055e+01, -1.0524e+02, -1.1130e+02, -1.0509e+02,
#          -1.0142e+02, -6.6610e+01, -9.6827e+01, -1.1382e+02, -9.0097e+01,
#          -5.1047e+01, -7.6856e+01, -1.0575e+02, -9.4665e+01, -8.4263e+01,
#          -6.5992e+01, -5.3295e+01, -5.8472e+01, -4.7509e+01, -5.7496e+01,
#          -6.0891e+01, -5.0808e+01, -4.7159e+01, -7.8419e+01, -9.5157e+01,
#          -8.1005e+01, -1.1044e+02, -1.1190e+02, -5.0850e+01, -6.7190e+01,
#          -1.0783e+02, -9.9765e+01, -1.1036e+02, -9.6552e+01, -9.4117e+01,
#          -8.4111e+01, -4.7208e+01, -7.0809e+01, -6.8591e+01, -8.7595e+01,
#          -6.0792e+01, -9.9449e+01, -9.7951e+01, -7.4775e+01, -6.9963e+01,
#          -4.8413e+01, -7.7606e+01, -7.7363e+01, -7.3048e+01, -4.8639e+01,
#          -6.4123e+01, -5.2178e+01, -4.1367e+01, -3.3251e+01, -2.3735e+01,
#          -1.9802e+01, -2.2401e+01, -2.5856e+01, -2.5576e+01, -3.4785e+01,
#          -5.1293e+01, -5.6569e+01, -5.0932e+01, -5.8218e+01, -6.9542e+01,
#          -6.0571e+01, -3.3236e+01, -2.5751e+01, -1.8430e+01, -1.7330e+01,
#          -1.9362e+01, -3.0725e+01, -3.9755e+01, -4.5791e+01, -5.9570e+01,
#          -7.3055e+01, -7.3024e+01, -8.0604e+01, -9.8530e+01, -8.8274e+01,
#          -9.9293e+01, -9.9565e+01, -1.2586e+02, -1.1402e+02, -3.7030e+01,
#          -1.1206e+02, -1.1050e+02, -1.0881e+02, -9.7738e+01, -9.6298e+01,
#          -8.9559e+01, -9.1399e+01, -1.0981e+02, -1.0503e+02, -8.0258e+01,
#          -4.4443e+01, -7.4228e+01, -6.5347e+01, -4.7284e+01, -4.2370e+01,
#          -2.8603e+01, -3.6405e+01, -2.7950e+01, -1.4470e+01, -1.5340e+01,
#          -1.3862e+01, -5.4725e+01, -1.0313e+01, -2.2178e-03, -6.1282e+00,
#          -1.9063e+01, -6.4408e+01, -5.7527e+01]], device='cuda:0')
# outputs1: tensor([[-4.9504e+01, -5.5556e+01, -6.4833e+01, -7.4970e+01, -8.5962e+01,
#          -8.8016e+01, -9.6433e+01, -1.0100e+02, -9.9389e+01, -1.0482e+02,
#          -1.0389e+02, -4.7640e+01, -8.3659e+01, -7.6490e+01, -6.6539e+01,
#          -6.6105e+01, -6.2998e+01, -6.6530e+01, -6.1330e+01, -5.6204e+01,
#          -3.3516e+01, -3.4015e+01, -2.9832e+01, -5.1219e+01, -5.1118e+01,
#          -7.7792e+01, -8.0729e+01, -8.7210e+01, -7.7605e+01, -1.0523e+02,
#          -9.8735e+01, -1.0985e+02, -1.2003e+02, -4.8393e+01, -1.2292e+02,
#          -1.2874e+02, -1.2656e+02, -1.1117e+02, -1.1285e+02, -1.0200e+02,
#          -9.0714e+01, -8.9426e+01, -7.5569e+01, -6.9013e+01, -4.4566e+01,
#          -5.4173e+01, -5.0531e+01, -4.3763e+01, -4.0917e+01, -4.7471e+01,
#          -4.0777e+01, -4.0884e+01, -4.5677e+01, -6.0832e+01, -6.6128e+01,
#          -3.3768e+01, -6.3326e+01, -8.3918e+01, -8.3963e+01, -7.3704e+01,
#          -1.0347e+02, -9.3055e+01, -1.0524e+02, -1.1130e+02, -1.0509e+02,
#          -1.0142e+02, -6.6610e+01, -9.6827e+01, -1.1382e+02, -9.0097e+01,
#          -5.1047e+01, -7.6856e+01, -1.0575e+02, -9.4665e+01, -8.4263e+01,
#          -6.5992e+01, -5.3295e+01, -5.8472e+01, -4.7509e+01, -5.7496e+01,
#          -6.0891e+01, -5.0808e+01, -4.7159e+01, -7.8419e+01, -9.5157e+01,
#          -8.1005e+01, -1.1044e+02, -1.1190e+02, -5.0850e+01, -6.7190e+01,
#          -1.0783e+02, -9.9765e+01, -1.1036e+02, -9.6552e+01, -9.4117e+01,
#          -8.4111e+01, -4.7208e+01, -7.0809e+01, -6.8591e+01, -8.7595e+01,
#          -6.0792e+01, -9.9449e+01, -9.7951e+01, -7.4775e+01, -6.9963e+01,
#          -4.8413e+01, -7.7606e+01, -7.7363e+01, -7.3048e+01, -4.8639e+01,
#          -6.4123e+01, -5.2178e+01, -4.1367e+01, -3.3251e+01, -2.3735e+01,
#          -1.9802e+01, -2.2401e+01, -2.5856e+01, -2.5576e+01, -3.4785e+01,
#          -5.1293e+01, -5.6569e+01, -5.0932e+01, -5.8218e+01, -6.9542e+01,
#          -6.0571e+01, -3.3236e+01, -2.5751e+01, -1.8430e+01, -1.7330e+01,
#          -1.9362e+01, -3.0725e+01, -3.9755e+01, -4.5791e+01, -5.9570e+01,
#          -7.3055e+01, -7.3024e+01, -8.0604e+01, -9.8530e+01, -8.8274e+01,
#          -9.9293e+01, -9.9565e+01, -1.2586e+02, -1.1402e+02, -3.7030e+01,
#          -1.1206e+02, -1.1050e+02, -1.0881e+02, -9.7738e+01, -9.6298e+01,
#          -8.9559e+01, -9.1399e+01, -1.0981e+02, -1.0503e+02, -8.0258e+01,
#          -4.4443e+01, -7.4228e+01, -6.5347e+01, -4.7284e+01, -4.2370e+01,
#          -2.8603e+01, -3.6405e+01, -2.7950e+01, -1.4470e+01, -1.5340e+01,
#          -1.3862e+01, -5.4725e+01, -1.0313e+01, -2.2178e-03, -6.1282e+00,
#          -1.9063e+01, -6.4408e+01, -5.7527e+01],
#         [-4.9504e+01, -5.5556e+01, -6.4833e+01, -7.4970e+01, -8.5962e+01,
#          -8.8016e+01, -9.6433e+01, -1.0100e+02, -9.9389e+01, -1.0482e+02,
#          -1.0389e+02, -4.7640e+01, -8.3659e+01, -7.6490e+01, -6.6539e+01,
#          -6.6105e+01, -6.2998e+01, -6.6530e+01, -6.1330e+01, -5.6204e+01,
#          -3.3516e+01, -3.4015e+01, -2.9832e+01, -5.1219e+01, -5.1118e+01,
#          -7.7792e+01, -8.0729e+01, -8.7210e+01, -7.7605e+01, -1.0523e+02,
#          -9.8735e+01, -1.0985e+02, -1.2003e+02, -4.8393e+01, -1.2292e+02,
#          -1.2874e+02, -1.2656e+02, -1.1117e+02, -1.1285e+02, -1.0200e+02,
#          -9.0714e+01, -8.9426e+01, -7.5569e+01, -6.9013e+01, -4.4566e+01,
#          -5.4173e+01, -5.0531e+01, -4.3763e+01, -4.0917e+01, -4.7471e+01,
#          -4.0777e+01, -4.0884e+01, -4.5677e+01, -6.0832e+01, -6.6128e+01,
#          -3.3768e+01, -6.3326e+01, -8.3918e+01, -8.3963e+01, -7.3704e+01,
#          -1.0347e+02, -9.3055e+01, -1.0524e+02, -1.1130e+02, -1.0509e+02,
#          -1.0142e+02, -6.6610e+01, -9.6827e+01, -1.1382e+02, -9.0097e+01,
#          -5.1047e+01, -7.6856e+01, -1.0575e+02, -9.4665e+01, -8.4263e+01,
#          -6.5992e+01, -5.3295e+01, -5.8472e+01, -4.7509e+01, -5.7496e+01,
#          -6.0891e+01, -5.0808e+01, -4.7159e+01, -7.8419e+01, -9.5157e+01,
#          -8.1005e+01, -1.1044e+02, -1.1190e+02, -5.0850e+01, -6.7190e+01,
#          -1.0783e+02, -9.9765e+01, -1.1036e+02, -9.6552e+01, -9.4117e+01,
#          -8.4111e+01, -4.7208e+01, -7.0809e+01, -6.8591e+01, -8.7595e+01,
#          -6.0792e+01, -9.9449e+01, -9.7951e+01, -7.4775e+01, -6.9963e+01,
#          -4.8413e+01, -7.7606e+01, -7.7363e+01, -7.3048e+01, -4.8639e+01,
#          -6.4123e+01, -5.2178e+01, -4.1367e+01, -3.3251e+01, -2.3735e+01,
#          -1.9802e+01, -2.2401e+01, -2.5856e+01, -2.5576e+01, -3.4785e+01,
#          -5.1293e+01, -5.6569e+01, -5.0932e+01, -5.8218e+01, -6.9542e+01,
#          -6.0571e+01, -3.3236e+01, -2.5751e+01, -1.8430e+01, -1.7330e+01,
#          -1.9362e+01, -3.0725e+01, -3.9755e+01, -4.5791e+01, -5.9570e+01,
#          -7.3055e+01, -7.3024e+01, -8.0604e+01, -9.8530e+01, -8.8274e+01,
#          -9.9293e+01, -9.9565e+01, -1.2586e+02, -1.1402e+02, -3.7030e+01,
#          -1.1206e+02, -1.1050e+02, -1.0881e+02, -9.7738e+01, -9.6298e+01,
#          -8.9559e+01, -9.1399e+01, -1.0981e+02, -1.0503e+02, -8.0258e+01,
#          -4.4443e+01, -7.4228e+01, -6.5347e+01, -4.7284e+01, -4.2370e+01,
#          -2.8603e+01, -3.6405e+01, -2.7950e+01, -1.4470e+01, -1.5340e+01,
#          -1.3862e+01, -5.4725e+01, -1.0313e+01, -2.2178e-03, -6.1282e+00,
#          -1.9063e+01, -6.4408e+01, -5.7527e+01]], device='cuda:0')
# num: tensor([168, 168], device='cuda:0') value: tensor([-0.0022, -0.0022], device='cuda:0')

# %%
num2 = torch.tensor([]).to(device)
num1 = torch.cat((num2,num),dim=0)

# %%
print('C:\\Users\\nanolab115\Desktop\\'+'diff1.png')
# Out:
# C:\Users\nanolab115\Desktop\diff1.png
