# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %matplotlib inline

# %% [markdown]
# Transfer Learning for Computer Vision Tutorial
# ==============================================
#
# These two major transfer learning scenarios look as follows:
#
# -  **Finetuning the convnet**: Instead of random initialization, we
#    initialize the network with a pretrained network, like the one that is
#    trained on imagenet 1000 dataset. Rest of the training looks as
#    usual.
# -  **ConvNet as fixed feature extractor**: Here, we will freeze the weights
#    for all of the network except that of the final fully connected
#    layer. This last fully connected layer is replaced with a new one
#    with random weights and only this layer is trained.

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# Load Data
# ---------
#
# We will use torchvision and torch.utils.data packages for loading the
# data.
#
# The problem we're going to solve today is to train a model to classify
# **ants** and **bees**. We have about 120 training images each for ants and bees.
# There are 75 validation images for each class. Usually, this is a very
# small dataset to generalize upon, if trained from scratch. Since we
# are using transfer learning, we should be able to generalize reasonably
# well.
#
# This dataset is a very small subset of imagenet.
#
# .. Note ::
#    Download the data from
#    `here <https://download.pytorch.org/tutorial/hymenoptera_data.zip>`_
#    and extract it to the current directory.

# %%
# Data augmentation and normalization for training
# Just normalization for validation
image_transforms  = {
    'train': transforms.Compose([
        # transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        # transforms.RandomRotation(degrees = 45),
        # transforms.RandomHorizontalFlip(),
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# dataset = 'E:\gmd_data\microsphere2_dataAugmented'
dataset = 'E:\gmd_data\\2022_05_17_05_3_1_16DataSet'
train_directory = os.path.join(dataset, 'train')
valid_directory = os.path.join(dataset, 'valid')

batch_size = 32
# num_classes = 173

data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),
    'valid': datasets.ImageFolder(root=valid_directory, transform=image_transforms['valid'])

}


train_data_size = len(data['train'])
valid_data_size = len(data['valid'])

train_data = DataLoader(data['train'], batch_size=batch_size, shuffle=True)
valid_data = DataLoader(data['valid'], batch_size=batch_size, shuffle=True)

print(train_data_size, valid_data_size)
# Out:
# 18780 6260

# %% [markdown]
# 迁移学习
# ---------
#
#
# 这里使用ResNet-50的预训练模型。

# %%
resnet50 = models.resnet50(pretrained=True)

for param in resnet50.parameters():
    param.requires_grad = True

fc_inputs = resnet50.fc.in_features
resnet50.fc = nn.Sequential(
    nn.Linear(fc_inputs, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256, 626),
    nn.LogSoftmax(dim = 1)


)
resnet50 = resnet50.to('cuda:0')
loss_func = nn.NLLLoss()
# optimizer = optim.AdamW(resnet50.parameters(),lr=1e-4)

# %% [markdown]
# Training the model
# ------------------
#
# Now, let's write a general function to train a model. Here, we will
# illustrate:
#
# -  Scheduling the learning rate
# -  Saving the best model
#
# In the following, parameter ``scheduler`` is an LR scheduler object from
# ``torch.optim.lr_scheduler``.

# %%
model = resnet50
loss_function = loss_func
epochs = 3000
# LR_value = 1e-4
LR_value = 1e-4
# trained_model, history = train_and_valid(resnet50, loss_func, num_epochs)
# torch.save(history, 'models/'+dataset+'_history.pt')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
history = []
best_acc = 0.0
best_epoch = 0

for epoch in range(epochs):
    epoch_start = time.time()
    print("Epoch: {}/{}".format(epoch+1, epochs))

    model.train()

    train_loss = 0.0
    train_acc = 0.0
    valid_loss = 0.0
    valid_acc = 0.0
#         学习率递减
    if epoch <= 10:
        LR = LR_value;
    elif epoch <= 20:
        LR = LR_value*0.5;
    elif epoch <= 30:
        LR = LR_value*0.5*0.5;
    elif epoch <= 40:
        LR = LR_value*0.5*0.5*0.5;
    else:
        LR = LR_value*0.5*0.5*0.5*0.5;
    optimizer = optim.AdamW(resnet50.parameters(),lr=LR)

    for i, (inputs, labels) in enumerate(train_data):
        inputs = inputs.to(device)
        labels = labels.to(device)

        #因为这里梯度是累加的，所以每次记得清零
        optimizer.zero_grad()

        outputs = model(inputs)

        loss = loss_function(outputs, labels)

        loss.backward()

        optimizer.step()

        train_loss += loss.item() * inputs.size(0)

        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))

        acc = torch.mean(correct_counts.type(torch.FloatTensor))

        train_acc += acc.item() * inputs.size(0)

    with torch.no_grad():
        model.eval()

        for j, (inputs, labels) in enumerate(valid_data):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)

            loss = loss_function(outputs, labels)

            valid_loss += loss.item() * inputs.size(0)

            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))

            acc = torch.mean(correct_counts.type(torch.FloatTensor))

            valid_acc += acc.item() * inputs.size(0)

    avg_train_loss = train_loss/train_data_size
    avg_train_acc = train_acc/train_data_size

    avg_valid_loss = valid_loss/valid_data_size
    avg_valid_acc = valid_acc/valid_data_size

    history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])

    if best_acc < avg_valid_acc:
        best_acc = avg_valid_acc
        best_epoch = epoch + 1

    epoch_end = time.time()

    print("Epoch: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation: Loss: {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(
        epoch+1, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start
    ))
    print("Best Accuracy for validation : {:.4f} at epoch {:03d}".format(best_acc, best_epoch))

    torch.save(model, dataset+'/models/'+'model_'+str(epoch+1)+'.pt')
# Out:
# Epoch: 1/3000
# Epoch: 001, Training: Loss: 6.2800, Accuracy: 0.3142%,
# 		Validation: Loss: 6.6780, Accuracy: 0.2396%, Time: 2764.3408s
# Best Accuracy for validation : 0.0024 at epoch 001
# Epoch: 2/3000
# Epoch: 002, Training: Loss: 5.6788, Accuracy: 0.7508%,
# 		Validation: Loss: 7.5355, Accuracy: 0.1757%, Time: 1340.9193s
# Best Accuracy for validation : 0.0024 at epoch 001
# Epoch: 3/3000
# Epoch: 003, Training: Loss: 5.2737, Accuracy: 0.8892%,
# 		Validation: Loss: 8.1906, Accuracy: 0.1597%, Time: 1192.6666s
# Best Accuracy for validation : 0.0024 at epoch 001
# Epoch: 4/3000
# Epoch: 004, Training: Loss: 5.0296, Accuracy: 1.2247%,
# 		Validation: Loss: 8.4644, Accuracy: 0.2236%, Time: 1384.7709s
# Best Accuracy for validation : 0.0024 at epoch 001
# Epoch: 5/3000
# Epoch: 005, Training: Loss: 4.8398, Accuracy: 1.4696%,
# 		Validation: Loss: 8.1475, Accuracy: 0.2396%, Time: 1757.5041s
# Best Accuracy for validation : 0.0024 at epoch 001
# Epoch: 6/3000
# Epoch: 006, Training: Loss: 4.6909, Accuracy: 1.7572%,
# 		Validation: Loss: 8.0010, Accuracy: 0.1597%, Time: 1046.3525s
# Best Accuracy for validation : 0.0024 at epoch 001
# Epoch: 7/3000
# Epoch: 007, Training: Loss: 4.5479, Accuracy: 1.9223%,
# 		Validation: Loss: 8.9112, Accuracy: 0.2396%, Time: 1026.4706s
# Best Accuracy for validation : 0.0024 at epoch 007
# Epoch: 8/3000
# Epoch: 008, Training: Loss: 4.4220, Accuracy: 2.3855%,
# 		Validation: Loss: 10.0738, Accuracy: 0.2556%, Time: 919.7919s
# Best Accuracy for validation : 0.0026 at epoch 008
# Epoch: 9/3000
# Epoch: 009, Training: Loss: 4.3083, Accuracy: 2.7370%,
# 		Validation: Loss: 9.4422, Accuracy: 0.1278%, Time: 937.6949s
# Best Accuracy for validation : 0.0026 at epoch 008
# Epoch: 10/3000
# Epoch: 010, Training: Loss: 4.2088, Accuracy: 3.0405%,
# 		Validation: Loss: 11.4202, Accuracy: 0.1118%, Time: 1195.2914s
# Best Accuracy for validation : 0.0026 at epoch 008
# Epoch: 11/3000
# Epoch: 011, Training: Loss: 4.0970, Accuracy: 4.1374%,
# 		Validation: Loss: 11.3117, Accuracy: 0.1597%, Time: 2042.8945s
# Best Accuracy for validation : 0.0026 at epoch 008
# Epoch: 12/3000
# Epoch: 012, Training: Loss: 3.9171, Accuracy: 4.9521%,
# 		Validation: Loss: 12.6597, Accuracy: 0.2875%, Time: 1447.6035s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 13/3000
# Epoch: 013, Training: Loss: 3.7755, Accuracy: 6.2833%,
# 		Validation: Loss: 12.3801, Accuracy: 0.1278%, Time: 1086.4563s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 14/3000
# Epoch: 014, Training: Loss: 3.6443, Accuracy: 8.5729%,
# 		Validation: Loss: 12.1963, Accuracy: 0.1438%, Time: 977.7903s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 15/3000
# Epoch: 015, Training: Loss: 3.4919, Accuracy: 10.5964%,
# 		Validation: Loss: 13.5827, Accuracy: 0.2396%, Time: 809.7417s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 16/3000
# Epoch: 016, Training: Loss: 3.3341, Accuracy: 13.2375%,
# 		Validation: Loss: 14.8275, Accuracy: 0.1438%, Time: 836.0367s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 17/3000
# Epoch: 017, Training: Loss: 3.1746, Accuracy: 15.3994%,
# 		Validation: Loss: 14.2337, Accuracy: 0.2236%, Time: 1094.4841s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 18/3000
# Epoch: 018, Training: Loss: 3.0415, Accuracy: 18.1470%,
# 		Validation: Loss: 15.6706, Accuracy: 0.2077%, Time: 1835.3848s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 19/3000
# Epoch: 019, Training: Loss: 2.8769, Accuracy: 21.4909%,
# 		Validation: Loss: 16.8397, Accuracy: 0.1757%, Time: 1058.1671s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 20/3000
# Epoch: 020, Training: Loss: 2.7270, Accuracy: 23.8818%,
# 		Validation: Loss: 18.4376, Accuracy: 0.2236%, Time: 949.2123s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 21/3000
# Epoch: 021, Training: Loss: 2.5843, Accuracy: 26.7146%,
# 		Validation: Loss: 15.9984, Accuracy: 0.1917%, Time: 1016.0856s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 22/3000
# Epoch: 022, Training: Loss: 2.3924, Accuracy: 31.3419%,
# 		Validation: Loss: 18.6523, Accuracy: 0.1757%, Time: 1125.9563s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 23/3000
# Epoch: 023, Training: Loss: 2.2474, Accuracy: 35.3248%,
# 		Validation: Loss: 18.5184, Accuracy: 0.1597%, Time: 1801.0965s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 24/3000
# Epoch: 024, Training: Loss: 2.1191, Accuracy: 38.0405%,
# 		Validation: Loss: 19.3320, Accuracy: 0.1438%, Time: 1154.4825s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 25/3000
# Epoch: 025, Training: Loss: 2.0224, Accuracy: 40.6976%,
# 		Validation: Loss: 19.8368, Accuracy: 0.1278%, Time: 1071.6463s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 26/3000
# Epoch: 026, Training: Loss: 1.9460, Accuracy: 42.6411%,
# 		Validation: Loss: 20.0284, Accuracy: 0.1917%, Time: 893.9607s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 27/3000
# Epoch: 027, Training: Loss: 1.8833, Accuracy: 43.9989%,
# 		Validation: Loss: 21.2554, Accuracy: 0.1597%, Time: 727.3750s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 28/3000
# Epoch: 028, Training: Loss: 1.8012, Accuracy: 46.4111%,
# 		Validation: Loss: 22.9526, Accuracy: 0.0958%, Time: 563.4313s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 29/3000
# Epoch: 029, Training: Loss: 1.7392, Accuracy: 48.0564%,
# 		Validation: Loss: 23.4722, Accuracy: 0.1438%, Time: 500.3201s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 30/3000
# Epoch: 030, Training: Loss: 1.6693, Accuracy: 50.3994%,
# 		Validation: Loss: 23.0097, Accuracy: 0.1438%, Time: 595.8821s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 31/3000
# Epoch: 031, Training: Loss: 1.6118, Accuracy: 51.8424%,
# 		Validation: Loss: 21.9042, Accuracy: 0.1597%, Time: 255.3549s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 32/3000
# Epoch: 032, Training: Loss: 1.5336, Accuracy: 54.3504%,
# 		Validation: Loss: 22.8899, Accuracy: 0.1917%, Time: 223.9441s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 33/3000
# Epoch: 033, Training: Loss: 1.4571, Accuracy: 56.3845%,
# 		Validation: Loss: 24.2459, Accuracy: 0.2396%, Time: 235.4969s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 34/3000
# Epoch: 034, Training: Loss: 1.3937, Accuracy: 58.5676%,
# 		Validation: Loss: 24.6596, Accuracy: 0.2077%, Time: 255.5386s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 35/3000
# Epoch: 035, Training: Loss: 1.3411, Accuracy: 59.9734%,
# 		Validation: Loss: 22.6537, Accuracy: 0.1757%, Time: 285.5960s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 36/3000
# Epoch: 036, Training: Loss: 1.3187, Accuracy: 60.5538%,
# 		Validation: Loss: 23.5543, Accuracy: 0.0799%, Time: 288.1951s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 37/3000
# Epoch: 037, Training: Loss: 1.2746, Accuracy: 62.4175%,
# 		Validation: Loss: 23.7571, Accuracy: 0.1118%, Time: 233.1248s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 38/3000
# Epoch: 038, Training: Loss: 1.2590, Accuracy: 61.9276%,
# 		Validation: Loss: 24.0928, Accuracy: 0.1438%, Time: 242.2846s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 39/3000
# Epoch: 039, Training: Loss: 1.2234, Accuracy: 63.3759%,
# 		Validation: Loss: 25.0762, Accuracy: 0.2077%, Time: 262.9028s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 40/3000
# Epoch: 040, Training: Loss: 1.1855, Accuracy: 64.7870%,
# 		Validation: Loss: 24.3269, Accuracy: 0.1278%, Time: 361.4299s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 41/3000
# Epoch: 041, Training: Loss: 1.1605, Accuracy: 65.3834%,
# 		Validation: Loss: 24.4910, Accuracy: 0.1118%, Time: 578.4944s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 42/3000
# Epoch: 042, Training: Loss: 1.1262, Accuracy: 66.7306%,
# 		Validation: Loss: 25.5345, Accuracy: 0.1757%, Time: 869.0847s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 43/3000
# Epoch: 043, Training: Loss: 1.0914, Accuracy: 67.7636%,
# 		Validation: Loss: 25.7237, Accuracy: 0.1757%, Time: 881.1407s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 44/3000
# Epoch: 044, Training: Loss: 1.0532, Accuracy: 68.7433%,
# 		Validation: Loss: 27.0653, Accuracy: 0.0799%, Time: 1514.0949s
# Best Accuracy for validation : 0.0029 at epoch 012
# Epoch: 45/3000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\NANOLA~1\AppData\Local\Temp/ipykernel_21380/2095494127.py in <module>
#      61         model.eval()
#      62
# ---> 63         for j, (inputs, labels) in enumerate(valid_data):
#      64             inputs = inputs.to(device)
#      65             labels = labels.to(device)
#
# d:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# d:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     568     def _next_data(self):
#     569         index = self._next_index()  # may raise StopIteration
# --> 570         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571         if self._pin_memory:
#     572             data = _utils.pin_memory.pin_memory(data)
#
# d:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# d:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# d:\anacondagmd\envs\d2l\lib\site-packages\torchvision\datasets\folder.py in __getitem__(self, index)
#     228         """
#     229         path, target = self.samples[index]
# --> 230         sample = self.loader(path)
#     231         if self.transform is not None:
#     232             sample = self.transform(sample)
#
# d:\anacondagmd\envs\d2l\lib\site-packages\torchvision\datasets\folder.py in default_loader(path)
#     267         return accimage_loader(path)
#     268     else:
# --> 269         return pil_loader(path)
#     270
#     271
#
# d:\anacondagmd\envs\d2l\lib\site-packages\torchvision\datasets\folder.py in pil_loader(path)
#     246     # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
#     247     with open(path, "rb") as f:
# --> 248         img = Image.open(f)
#     249         return img.convert("RGB")
#     250
#
# d:\anacondagmd\envs\d2l\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2992         return None
#    2993
# -> 2994     im = _open_core(fp, filename, prefix, formats)
#    2995
#    2996     if im is None:
#
# d:\anacondagmd\envs\d2l\lib\site-packages\PIL\Image.py in _open_core(fp, filename, prefix, formats)
#    2978                 elif result:
#    2979                     fp.seek(0)
# -> 2980                     im = factory(fp, filename)
#    2981                     _decompression_bomb_check(im.size)
#    2982                     return im
#
# d:\anacondagmd\envs\d2l\lib\site-packages\PIL\ImageFile.py in __init__(self, fp, filename)
#     110         try:
#     111             try:
# --> 112                 self._open()
#     113             except (
#     114                 IndexError,  # end of data
#
# d:\anacondagmd\envs\d2l\lib\site-packages\PIL\PngImagePlugin.py in _open(self)
#     689             # get next chunk
#     690
# --> 691             cid, pos, length = self.png.read()
#     692
#     693             try:
#
# d:\anacondagmd\envs\d2l\lib\site-packages\PIL\PngImagePlugin.py in read(self)
#     159             s = self.fp.read(8)
#     160             cid = s[4:]
# --> 161             pos = self.fp.tell()
#     162             length = i32(s)
#     163
#
# KeyboardInterrupt:

# %%
history = np.array(history)
plt.plot(history[:, 0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0, 1)
plt.savefig(dataset+'_loss_curve.png')
plt.show()

plt.plot(history[:, 2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.savefig(dataset+'_accuracy_curve.png')
plt.show()

# %% [markdown]
# 导入模型 将验证集和真值对比图画出来
# -------

# %%
# 导入模型 将验证集和真值对比图画出来
dataset = 'E:\gmd_data\microsphere2_dataAugmented'
model38 = torch.load( dataset+'/models/'+'model_38.pt')
for param in model38.parameters():
    param.requires_grad = False
model38 = model38.to('cuda:0')
loss_function = nn.NLLLoss()



device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
history = []
best_acc = 0.0
best_epoch = 0


valid_loss = 0.0
valid_acc = 0.0

predictions_all = torch.tensor([]).to(device)
labels_all = torch.tensor([]).to(device)

for j, (inputs, labels) in enumerate(valid_data):
    inputs = inputs.to(device)
    labels = labels.to(device)

    outputs = model38(inputs)

    loss = loss_function(outputs, labels)
    print("valid_data_j: {}".format(j))
    print("Outputs : ")
    print(outputs)
    print("labels ：")
    print(labels)
    print("loss ：")
    print(loss)

    valid_loss += loss.item() * inputs.size(0)

    ret, predictions = torch.max(outputs.data, 1)

    predictions_all = torch.cat((predictions_all,predictions),dim=0)
    labels_all = torch.cat((labels_all,labels),dim=0)

    correct_counts = predictions.eq(labels.data.view_as(predictions))

    acc = torch.mean(correct_counts.type(torch.FloatTensor))

    valid_acc += acc.item() * inputs.size(0)

avg_valid_loss = valid_loss/valid_data_size
avg_valid_acc = valid_acc/valid_data_size
# Out:
# valid_data_j: 0
# Outputs :
# tensor([[ -71.6474,  -85.5358,  -67.7171,  ..., -112.9882, -112.7489,
#          -105.8901],
#         [ -47.7619,  -81.4070,  -78.9563,  ..., -101.9786,  -81.4818,
#           -82.3252],
#         [ -50.6899,  -22.3298,  -29.0709,  ...,  -39.6067,  -36.7736,
#           -30.1902],
#         ...,
#         [ -77.5089,  -97.1848,  -94.1852,  ...,  -86.9137,  -91.0399,
#           -95.5534],
#         [ -68.3249,  -73.2819,  -78.8579,  ...,  -77.3939,  -55.1940,
#           -62.7980],
#         [ -37.8472,  -68.9902,  -79.2437,  ...,  -68.9639,  -82.6208,
#           -74.8766]], device='cuda:0')
# labels ：
# tensor([  9,  63,  20,  42,  28, 123,  69, 141, 121, 109,  55, 118, 144, 153,
#         170,  68, 172, 121, 168,  49, 129, 110,  64, 123,  69,  55,  35,  57,
#         126,  95,  65,  49], device='cuda:0')
# loss ：
# tensor(0.2459, device='cuda:0')
# valid_data_j: 1
# Outputs :
# tensor([[ -25.0170,  -85.2443,  -74.5843,  ..., -121.8500,  -99.8626,
#           -97.2783],
#         [ -62.8287,  -56.8734,  -56.6157,  ...,  -62.2501,  -55.3413,
#           -55.9833],
#         [ -85.6648,  -85.8049,  -90.0124,  ...,  -46.5146,  -96.7327,
#           -89.3648],
#         ...,
#         [ -61.6668, -160.4633, -149.3917,  ..., -159.1853, -184.1473,
#          -174.6170],
#         [-103.8814, -134.1675, -133.2776,  ..., -114.2848, -145.2755,
#          -139.2286],
#         [ -62.9836,  -44.3159,  -45.4498,  ...,  -77.8147,  -37.3478,
#           -43.4100]], device='cuda:0')
# labels ：
# tensor([145,  37, 127, 168, 148,  85,  29, 157, 148,  42,  28,  49, 133, 134,
#         143,   9, 102,  67, 159,  77, 110,  64,  51, 169, 164,   5,  83, 146,
#         162, 139, 134,  89], device='cuda:0')
# loss ：
# tensor(0.6236, device='cuda:0')
# valid_data_j: 2
# Outputs :
# tensor([[-120.2294,  -94.4522, -106.8580,  ...,  -18.0218,  -85.2823,
#           -83.7522],
#         [ -46.8325, -122.2212, -111.0037,  ..., -152.7352, -137.0033,
#          -134.1603],
#         [ -50.0016,  -52.1349,  -60.9700,  ...,  -17.0647,  -60.0077,
#           -53.5390],
#         ...,
#         [ -51.8903, -100.3254,  -87.3465,  ..., -125.1146, -112.0752,
#          -110.3157],
#         [ -60.3541,  -72.2371,  -69.3346,  ..., -101.0210,  -66.8878,
#           -73.6918],
#         [ -55.8094,  -93.4827,  -78.2669,  ..., -119.3276, -112.9539,
#          -110.6517]], device='cuda:0')
# labels ：
# tensor([118,  60, 168, 139,  80,   0,  38,   0, 149, 172, 134, 121,  87,  38,
#          40, 145, 107,  38,  30,  98,  57,  99,  78, 149,  89,  70, 112, 107,
#          34, 146,  87, 152], device='cuda:0')
# loss ：
# tensor(0.7738, device='cuda:0')
# valid_data_j: 3
# Outputs :
# tensor([[  -4.0191,  -60.5700,  -52.8821,  ...,  -98.2427,  -80.3709,
#           -76.6694],
#         [ -61.7299,  -43.5901,  -49.5260,  ...,  -25.0117,  -36.0537,
#           -36.1310],
#         [ -57.1193,  -72.4948,  -60.5099,  ...,  -72.2162,  -87.8258,
#           -83.5561],
#         ...,
#         [  -9.5314,  -48.7433,  -55.4773,  ...,  -53.4486,  -66.5942,
#           -59.0362],
#         [ -28.4517,  -80.7023,  -84.4633,  ...,  -55.0171, -101.1141,
#           -91.1889],
#         [ -73.6286,  -91.0544,  -89.8086,  ...,  -83.8087,  -82.4760,
#           -87.8171]], device='cuda:0')
# labels ：
# tensor([ 11, 104, 157, 127,  34, 104, 139, 122,  95,  54,  40, 112,   8,  62,
#         132,  24,  60, 158, 131, 108,  59,  77,  99,  78,  10, 156,  25,  31,
#          35,  51, 163,  92], device='cuda:0')
# loss ：
# tensor(0.6624, device='cuda:0')
# valid_data_j: 4
# Outputs :
# tensor([[ -61.7702, -111.2168,  -93.3411,  ..., -137.9260, -132.1303,
#          -129.6965],
#         [ -96.0672,  -81.1086,  -87.3087,  ...,  -22.9483,  -91.4034,
#           -82.9000],
#         [ -71.1625,  -33.7637,  -33.4858,  ...,  -53.5995,  -26.4316,
#           -30.9983],
#         ...,
#         [  -0.6636,  -64.8753,  -61.7718,  ..., -101.5698,  -88.5305,
#           -81.1535],
#         [ -29.0464,  -93.4509,  -91.4764,  ..., -114.3008, -108.4361,
#          -102.2942],
#         [ -66.2402,  -41.0838,  -49.8104,  ...,  -57.0808,  -25.9186,
#           -32.2352]], device='cuda:0')
# labels ：
# tensor([153, 167, 111, 156,  31,  26,  18,  63, 106,  52, 107,  67, 125, 116,
#         101,  44, 120, 158, 122,  63, 152,  39, 153,  51, 122,  51, 154, 159,
#          74,   0,  56,  71], device='cuda:0')
# loss ：
# tensor(0.6383, device='cuda:0')
# valid_data_j: 5
# Outputs :
# tensor([[ -23.2150,  -76.4605,  -76.4752,  ...,  -90.7504,  -89.5532,
#           -84.0573],
#         [ -76.1221, -105.0092,  -98.3372,  ...,  -92.6419, -107.0251,
#          -108.5025],
#         [ -73.3972,  -23.3615,  -33.5728,  ...,  -46.4915,   -7.2637,
#           -14.0726],
#         ...,
#         [  -2.5335,  -62.4378,  -57.5767,  ...,  -96.2406,  -84.4910,
#           -79.1645],
#         [ -75.3036,  -99.6693,  -91.2655,  ...,  -67.4012, -112.2130,
#          -106.4875],
#         [  -0.6636,  -64.8753,  -61.7718,  ..., -101.5698,  -88.5305,
#           -81.1535]], device='cuda:0')
# labels ：
# tensor([ 54,  95, 155, 115,  20, 151,  73, 172, 140,  35, 119, 100, 168, 149,
#          40, 144,  22,  60,  96, 104, 169,  10, 120,  41,  28, 165,  16,   1,
#          89,  11, 159,   0], device='cuda:0')
# loss ：
# tensor(0.5022, device='cuda:0')
# valid_data_j: 6
# Outputs :
# tensor([[ -66.6880,  -16.1735,  -20.6155,  ...,  -22.4375,   -8.3621,
#           -10.8222],
#         [ -20.0028,  -77.1528,  -68.2963,  ..., -112.0543,  -91.4334,
#           -88.5562],
#         [ -37.8472,  -68.9902,  -79.2437,  ...,  -68.9639,  -82.6208,
#           -74.8766],
#         ...,
#         [ -62.8287,  -56.8734,  -56.6157,  ...,  -62.2501,  -55.3413,
#           -55.9833],
#         [ -63.7692,  -82.0899,  -80.8429,  ...,  -73.1414,  -75.5625,
#           -79.8313],
#         [ -49.5462,  -76.7521,  -85.9716,  ...,  -67.5146,  -98.7789,
#           -86.3849]], device='cuda:0')
# labels ：
# tensor([155, 145,  49,  59,  95, 135, 163, 120, 133, 170,  94, 166, 141, 122,
#         148,  63, 104, 110, 150,   0, 132,  22,  63,  40,  77,  79,  74,   5,
#         123,  37,  94,  47], device='cuda:0')
# loss ：
# tensor(0.4037, device='cuda:0')
# valid_data_j: 7
# Outputs :
# tensor([[ -77.0129,  -83.1320,  -82.3347,  ...,  -93.5430,  -75.5538,
#           -81.1669],
#         [ -60.2624,  -79.6261,  -78.7634,  ...,  -81.7280,  -85.9880,
#           -85.1487],
#         [ -20.0028,  -77.1528,  -68.2963,  ..., -112.0543,  -91.4334,
#           -88.5562],
#         ...,
#         [ -83.5989, -115.9729, -114.9635,  ..., -125.4042, -111.8941,
#          -114.7183],
#         [ -58.8575,  -62.8936,  -50.8087,  ...,  -84.6912,  -86.1904,
#           -79.1033],
#         [ -95.7194,  -69.6702,  -74.4549,  ...,  -25.2418,  -75.2853,
#           -69.0573]], device='cuda:0')
# labels ：
# tensor([ 35,  76, 145, 110, 103, 110, 134, 104, 104, 109,  51, 130, 104,  39,
#         164,  34,  18, 125,  97,  77, 166,  20, 172, 144, 148,  23,   7, 104,
#         172,  74,  10, 121], device='cuda:0')
# loss ：
# tensor(0.3501, device='cuda:0')
# valid_data_j: 8
# Outputs :
# tensor([[ -89.3567,  -48.0500,  -57.2725,  ...,   -6.5546,  -51.9391,
#           -45.6831],
#         [ -61.7702, -111.2168,  -93.3411,  ..., -137.9260, -132.1303,
#          -129.6965],
#         [ -56.4836,  -74.9341,  -71.0526,  ...,  -63.7379,  -74.7267,
#           -76.1415],
#         ...,
#         [ -73.6286,  -91.0544,  -89.8086,  ...,  -83.8087,  -82.4760,
#           -87.8171],
#         [ -58.5226, -129.9764, -126.4949,  ...,  -94.1385, -154.1114,
#          -143.2542],
#         [ -72.2646,  -71.9674,  -78.0839,  ...,  -77.2766,  -51.9920,
#           -61.6562]], device='cuda:0')
# labels ：
# tensor([169, 153,  94, 101, 151, 104,  90,  15,   1, 158,  30, 131, 158, 139,
#          48, 116, 168,  38, 123, 127,  24, 140,  56, 159, 131, 149, 158,  43,
#          76,  92, 161,  67], device='cuda:0')
# loss ：
# tensor(0.6890, device='cuda:0')
# valid_data_j: 9
# Outputs :
# tensor([[-103.1038,  -65.4286,  -78.7985,  ...,  -81.3511,  -35.6284,
#           -47.8081],
#         [ -64.6957,  -61.4831,  -60.9133,  ...,  -87.1351,  -50.0989,
#           -56.6082],
#         [ -65.5838,  -67.4842,  -63.6542,  ...,  -73.7909,  -63.7525,
#           -68.4103],
#         ...,
#         [ -93.7506, -109.4490, -112.0529,  ..., -108.6359, -109.1802,
#          -108.7126],
#         [ -92.0593, -160.9066, -149.3945,  ..., -129.3118, -180.2630,
#          -170.5658],
#         [ -65.1967,  -13.1138,  -19.2919,  ...,  -23.1065,   -4.8221,
#            -7.4888]], device='cuda:0')
# labels ：
# tensor([ 69,  90,  32,  21, 150,   9,  18, 150, 141,  68, 101, 128,   0, 148,
#          77, 133,   7, 142, 139, 170,  24, 135, 169,  70,   5,  13,  98, 124,
#         105,  38, 137, 166], device='cuda:0')
# loss ：
# tensor(0.6110, device='cuda:0')
# valid_data_j: 10
# Outputs :
# tensor([[-120.8472,  -86.8298,  -93.9885,  ...,  -29.9634,  -91.6808,
#           -84.6824],
#         [-111.8904, -102.7649, -110.4087,  ...,  -49.8857, -116.8504,
#          -106.9005],
#         [ -61.4880,  -76.4049,  -82.4591,  ...,  -70.7739,  -86.3248,
#           -80.6906],
#         ...,
#         [ -59.7573,  -37.0530,  -25.8082,  ...,  -63.4959,  -55.7186,
#           -49.8903],
#         [ -74.9231,   -0.7092,   -0.9980,  ...,  -24.2410,   -6.1453,
#            -2.2775],
#         [ -44.3297,  -73.8975,  -83.9722,  ...,  -71.9814,  -82.4744,
#           -76.8706]], device='cuda:0')
# labels ：
# tensor([121, 127,  43, 162, 151,  13, 163,  18, 143,  93, 128, 159,   5,  84,
#          29, 125,  17, 118,  95,  51, 123,  26, 167, 154, 124, 119,  63,  53,
#         131,   6,   2,  46], device='cuda:0')
# loss ：
# tensor(0.8323, device='cuda:0')
# valid_data_j: 11
# Outputs :
# tensor([[ -66.9886,  -60.2040,  -59.2154,  ...,  -37.7047,  -57.4914,
#           -58.8152],
#         [ -29.6014,  -60.3484,  -58.6970,  ...,  -87.7011,  -70.9492,
#           -69.6684],
#         [ -64.6957,  -61.4831,  -60.9133,  ...,  -87.1351,  -50.0989,
#           -56.6082],
#         ...,
#         [ -62.2499, -100.4803, -113.9890,  ...,  -93.4281, -108.9767,
#          -102.6896],
#         [ -77.6514,   -8.7454,  -13.4549,  ...,  -32.2478,   -0.3113,
#            -2.3575],
#         [  -0.5954,  -68.1197,  -63.1767,  ..., -106.5656,  -92.7719,
#           -86.0871]], device='cuda:0')
# labels ：
# tensor([ 97,  84,  90, 115,  66, 160,  94,  23,  37,  44,  16,  21,  42,  57,
#           0,  42,  40, 125,  34, 120,  56, 110, 168, 133, 110,  75, 153,  93,
#          84,  46, 171,   0], device='cuda:0')
# loss ：
# tensor(0.6534, device='cuda:0')
# valid_data_j: 12
# Outputs :
# tensor([[ -43.4904,  -74.4556,  -61.0691,  ...,  -95.7051,  -87.1679,
#           -86.1533],
#         [ -74.5033,  -53.7026,  -54.7562,  ...,  -77.9928,  -47.0378,
#           -52.8836],
#         [ -71.3914, -133.1602, -122.1967,  ..., -111.6098, -148.4393,
#          -141.7897],
#         ...,
#         [ -48.5194,  -72.5344,  -73.0504,  ...,  -98.4957,  -69.7189,
#           -73.3080],
#         [ -45.7081, -116.1668, -108.9646,  ..., -134.7198, -126.6974,
#          -123.0486],
#         [ -58.7353,  -74.8472,  -76.0756,  ...,  -74.9324,  -79.9374,
#           -79.8911]], device='cuda:0')
# labels ：
# tensor([147,  89, 138, 148, 150,  43,   8, 127,  34,  52,  75,  59,  33, 101,
#         146,  80,  43, 158,  55, 170,  34,  37, 170,  15,   8, 144,  16, 130,
#         105,  64,  58,  78], device='cuda:0')
# loss ：
# tensor(0.6308, device='cuda:0')
# valid_data_j: 13
# Outputs :
# tensor([[ -51.9668, -109.4480,  -95.1322,  ..., -112.9099, -131.1209,
#          -125.5343],
#         [ -66.8517, -121.6127, -101.9377,  ..., -147.7974, -144.1100,
#          -141.3636],
#         [-154.0973, -195.0374, -194.8944,  ..., -163.8504, -209.3309,
#          -200.9132],
#         ...,
#         [ -93.7506, -109.4490, -112.0529,  ..., -108.6359, -109.1802,
#          -108.7126],
#         [ -80.4898,  -80.3902,  -90.7347,  ...,  -20.4386,  -74.3189,
#           -72.3661],
#         [ -90.7514,  -49.4816,  -43.6920,  ...,  -45.0892,  -69.0696,
#           -59.3495]], device='cuda:0')
# labels ：
# tensor([156, 153, 132, 145,  67, 145,  62,  84,  38,  52, 145,  55, 167, 146,
#          76,  59,  22,   5,  78,  91,  50, 140,  22,   6, 137,  53,  85,   9,
#         138,  38, 117,  15], device='cuda:0')
# loss ：
# tensor(0.7748, device='cuda:0')
# valid_data_j: 14
# Outputs :
# tensor([[-113.6646,  -98.7198, -106.4961,  ...,  -61.8468,  -72.1825,
#           -82.9526],
#         [ -27.9266,  -60.2265,  -58.9137,  ...,  -83.7387,  -69.4248,
#           -69.0467],
#         [ -12.8368,  -49.2365,  -57.9279,  ...,  -52.4568,  -68.9241,
#           -60.1612],
#         ...,
#         [ -55.1779,  -85.9644,  -73.1376,  ...,  -82.2156, -102.6970,
#           -98.0365],
#         [-100.2993,  -94.9253,  -97.5864,  ...,  -93.6845,  -74.6806,
#           -84.9527],
#         [ -43.4043,  -70.2240,  -80.0754,  ...,  -67.8026,  -80.9796,
#           -74.0737]], device='cuda:0')
# labels ：
# tensor([101,  84,  50,   4, 159, 168,  95,  68,  27,  36,  96, 137,  23,  98,
#          50, 102,  39,  58,  46, 113,  48, 158,  78,  28, 134, 108, 101,  56,
#          45, 158,  92,  47], device='cuda:0')
# loss ：
# tensor(1.1607, device='cuda:0')
# valid_data_j: 15
# Outputs :
# tensor([[ -83.1013, -107.3223, -112.5333,  ...,  -76.8677,  -95.5579,
#           -97.5161],
#         [ -57.9757,  -40.4409,  -34.1774,  ...,  -44.1828,  -60.5469,
#           -51.5456],
#         [ -41.8348, -117.9371, -111.9911,  ..., -139.9580, -131.8157,
#          -125.5375],
#         ...,
#         [ -67.2331,  -97.2341,  -99.6117,  ...,  -94.9105,  -94.0484,
#           -92.3551],
#         [ -59.4025,  -56.2527,  -58.7059,  ..., -101.2669,  -50.7484,
#           -57.4640],
#         [ -60.2106,   -0.6464,   -1.4575,  ...,  -18.8872,   -4.7237,
#            -1.5594]], device='cuda:0')
# labels ：
# tensor([107,  14,  57,  48, 139,  83, 148,  70,  59,  72, 133,  98, 152, 150,
#          81, 152, 141,   8, 150, 136,  65, 146, 168, 104,  72,   4, 120,  62,
#         104, 108,  77,   1], device='cuda:0')
# loss ：
# tensor(0.4305, device='cuda:0')
# valid_data_j: 16
# Outputs :
# tensor([[ -93.0282,  -31.9636,  -33.5359,  ...,  -30.3025,  -25.8014,
#           -28.4090],
#         [ -54.0192,  -72.1837,  -83.4295,  ...,  -35.1905,  -70.5580,
#           -68.6019],
#         [ -29.0464,  -93.4509,  -91.4764,  ..., -114.3008, -108.4361,
#          -102.2942],
#         ...,
#         [ -49.7801,  -99.2553,  -93.9861,  ..., -126.3430, -106.4683,
#          -105.7354],
#         [ -83.9484,  -37.7052,  -38.5785,  ...,  -55.9982,  -24.5678,
#           -31.3763],
#         [ -28.4517,  -80.7023,  -84.4633,  ...,  -55.0171, -101.1141,
#           -91.1889]], device='cuda:0')
# labels ：
# tensor([133, 113,  56,  17, 169,  29,  11, 120,  20,  82, 136, 118,  74, 172,
#          23, 110, 117,  46, 118,  49,  56,   8,  94,  28, 171,  30,  71, 137,
#          97,  62, 122, 163], device='cuda:0')
# loss ：
# tensor(0.4981, device='cuda:0')
# valid_data_j: 17
# Outputs :
# tensor([[ -65.0686,  -42.0747,  -49.5600,  ...,  -59.1999,  -27.8105,
#           -34.1120],
#         [ -61.7299,  -43.5901,  -49.5260,  ...,  -25.0117,  -36.0537,
#           -36.1310],
#         [ -68.6975,  -85.6960,  -88.9137,  ...,  -98.7836,  -76.2388,
#           -81.0248],
#         ...,
#         [ -90.0861,  -82.2911,  -87.6050,  ...,  -41.4204,  -92.8906,
#           -85.3060],
#         [ -82.8603,  -95.6058, -105.3053,  ...,  -27.5327,  -94.3463,
#           -90.2268],
#         [ -73.1928,  -54.1565,  -60.9837,  ...,  -59.0622,  -64.2016,
#           -61.1046]], device='cuda:0')
# labels ：
# tensor([ 72, 104,  73,   2,   7,  94,  61,  45,  52, 172,  39, 163,  80,  13,
#         137,  20, 119,  70, 143,  28,  94, 127, 143, 107,  99, 109, 135,  40,
#         103, 127, 116,  25], device='cuda:0')
# loss ：
# tensor(1.0517, device='cuda:0')
# valid_data_j: 18
# Outputs :
# tensor([[ -82.4144,  -14.7157,  -21.4961,  ...,  -32.4207,   -2.0171,
#            -5.9851],
#         [  -0.6636,  -64.8753,  -61.7718,  ..., -101.5698,  -88.5305,
#           -81.1535],
#         [ -62.9836,  -44.3159,  -45.4498,  ...,  -77.8147,  -37.3478,
#           -43.4100],
#         ...,
#         [-112.7091,  -81.7581,  -87.4316,  ...,  -75.0425,  -88.1995,
#           -87.4246],
#         [ -60.9367,  -87.6930, -100.1573,  ...,  -41.8037,  -88.7910,
#           -85.1340],
#         [ -58.4466,  -45.9015,  -33.1722,  ...,  -71.9088,  -65.4565,
#           -60.0510]], device='cuda:0')
# labels ：
# tensor([166,   0,  89,  36,  45, 118,  57,  88,  24, 116,  69, 117, 164, 163,
#         135,  24,  42, 103,  38, 115,  29, 171, 151, 111,  69,  88,  77,  16,
#         123,  27, 113,   7], device='cuda:0')
# loss ：
# tensor(0.6664, device='cuda:0')
# valid_data_j: 19
# Outputs :
# tensor([[-102.4502,  -85.9995,  -88.4498,  ...,  -95.8852,  -81.9429,
#           -87.2771],
#         [ -14.5018,  -45.0681,  -51.4332,  ...,  -46.4453,  -57.7867,
#           -51.7833],
#         [ -67.2331,  -97.2341,  -99.6117,  ...,  -94.9105,  -94.0484,
#           -92.3551],
#         ...,
#         [ -85.6648,  -85.8049,  -90.0124,  ...,  -46.5146,  -96.7327,
#           -89.3648],
#         [-125.5160, -108.2794, -118.2617,  ...,  -72.6831,  -75.8019,
#           -88.9630],
#         [ -51.8232,  -66.6487,  -67.5062,  ...,  -59.5180,  -63.4512,
#           -64.6899]], device='cuda:0')
# labels ：
# tensor([ 30,  48, 108, 162,  63,   2, 172, 116, 139,  22,   2,  92, 170,  67,
#          24,  91, 134, 116, 109,  79, 100, 138, 115, 171, 163, 125, 104, 157,
#         108, 127, 101,  93], device='cuda:0')
# loss ：
# tensor(0.7295, device='cuda:0')
# valid_data_j: 20
# Outputs :
# tensor([[ -82.4144,  -14.7157,  -21.4961,  ...,  -32.4207,   -2.0171,
#            -5.9851],
#         [ -55.9248,  -50.0763,  -44.7533,  ...,  -60.6468,  -76.4838,
#           -64.8113],
#         [ -49.5462,  -76.7521,  -85.9716,  ...,  -67.5146,  -98.7789,
#           -86.3849],
#         ...,
#         [ -47.7619,  -81.4070,  -78.9563,  ..., -101.9786,  -81.4818,
#           -82.3252],
#         [ -82.1626,  -68.4030,  -76.0769,  ...,  -72.3569,  -89.8576,
#           -81.7229],
#         [ -73.4689,  -81.4337,  -83.8950,  ...,  -77.8000,  -92.2969,
#           -86.2384]], device='cuda:0')
# labels ：
# tensor([166,  13,  47, 113,  58, 154, 171,  43,  17, 125, 150,  38,  94,  33,
#          59,  93, 113,  17,  90,  53, 156,  56,  14, 133,  97, 135,  50,   5,
#           9,  63,  23,  41], device='cuda:0')
# loss ：
# tensor(0.5909, device='cuda:0')
# valid_data_j: 21
# Outputs :
# tensor([[ -52.6501,  -90.2406,  -89.7154,  ...,  -79.6667,  -92.2234,
#           -88.9529],
#         [-100.5874, -128.1784, -124.2033,  ...,  -68.9229, -144.9413,
#          -135.0478],
#         [ -78.9717,  -58.7450,  -65.6091,  ...,  -31.8122,  -48.9604,
#           -48.9815],
#         ...,
#         [ -51.4101, -100.6698,  -95.7277,  ..., -127.3664, -106.7304,
#          -106.3514],
#         [ -59.0917, -100.3739,  -86.8954,  ...,  -91.7738, -117.7558,
#          -112.9285],
#         [ -44.4105, -125.6926, -109.8225,  ..., -152.6058, -144.2589,
#          -140.6763]], device='cuda:0')
# labels ：
# tensor([110, 160, 104,  25,   1, 164,  48, 122,  64, 122, 137, 112,  98,  21,
#          34,  15,  76, 112, 118, 167,  61,  28, 136,  14,   4, 116,  39,  37,
#         132,  62, 157, 142], device='cuda:0')
# loss ：
# tensor(0.7520, device='cuda:0')
# valid_data_j: 22
# Outputs :
# tensor([[ -49.7801,  -99.2553,  -93.9861,  ..., -126.3430, -106.4683,
#          -105.7354],
#         [ -86.4917,  -75.2973,  -83.6504,  ...,  -79.7640,  -50.1565,
#           -61.9571],
#         [ -62.8788,   -1.0433,   -0.6948,  ...,  -21.7587,   -7.1150,
#            -3.2290],
#         ...,
#         [ -62.4464,  -69.3804,  -74.3253,  ...,  -69.4398,  -52.8925,
#           -58.9354],
#         [ -68.3249,  -73.2819,  -78.8579,  ...,  -77.3939,  -55.1940,
#           -62.7980],
#         [ -36.6562,  -73.5157,  -69.4429,  ..., -109.8476,  -82.6901,
#           -83.8253]], device='cuda:0')
# labels ：
# tensor([ 62,  67,   2,  73,  38,  31, 162,  31, 117, 139, 122, 133,  97,  79,
#         172,  43,  53, 125, 128,   8, 123, 156, 145,  25, 162,  15, 139, 160,
#          22,  65,  65,  87], device='cuda:0')
# loss ：
# tensor(0.5684, device='cuda:0')
# valid_data_j: 23
# Outputs :
# tensor([[-111.8904, -102.7649, -110.4087,  ...,  -49.8857, -116.8504,
#          -106.9005],
#         [ -50.2109,  -17.0200,  -19.0026,  ...,  -26.4328,  -13.1484,
#           -14.9849],
#         [ -61.4880,  -76.4049,  -82.4591,  ...,  -70.7739,  -86.3248,
#           -80.6906],
#         ...,
#         [-110.9658,  -86.8348,  -97.6326,  ...,  -53.9081,  -59.4944,
#           -68.9146],
#         [ -77.0098,  -20.4465,  -12.0512,  ...,  -51.4108,  -36.7458,
#           -29.9985],
#         [  -9.8519,  -58.6669,  -58.8972,  ...,  -76.6224,  -78.1754,
#           -72.6753]], device='cuda:0')
# labels ：
# tensor([127, 122,  43,  41,  17,  68, 147,  22, 117,  78,  93, 155,  90, 162,
#          90,  28,  43,  87,  93, 153, 154,  35, 151,  74, 146, 127, 110, 165,
#          22, 102,   5,  22], device='cuda:0')
# loss ：
# tensor(0.8358, device='cuda:0')
# valid_data_j: 24
# Outputs :
# tensor([[ -57.1548,  -52.7777,  -38.8380,  ...,  -79.8336,  -73.0133,
#           -68.1384],
#         [ -69.9263,  -73.0800,  -75.4609,  ..., -102.4472,  -61.9024,
#           -68.9419],
#         [ -65.5008,  -49.2859,  -52.8791,  ...,  -54.1205,  -34.1668,
#           -40.3868],
#         ...,
#         [ -47.4120,  -75.3458,  -74.9480,  ...,  -97.5958,  -72.9556,
#           -75.0247],
#         [ -86.2592,  -50.7058,  -57.3410,  ...,  -23.0811,  -39.7026,
#           -41.2058],
#         [ -24.8690,  -98.1776,  -87.6593,  ..., -142.5403, -116.1603,
#          -112.1784]], device='cuda:0')
# labels ：
# tensor([  9,  72,  68, 150, 169,  31,  60,  45, 133,  18, 165,  51, 166, 144,
#         119,  12,  20,  83, 156, 100, 121,  64, 130, 113,  15, 126,  61, 131,
#          53,  64, 103, 143], device='cuda:0')
# loss ：
# tensor(0.6422, device='cuda:0')
# valid_data_j: 25
# Outputs :
# tensor([[ -91.3772,  -87.3418,  -95.5534,  ...,  -58.0965,  -76.3728,
#           -75.3611],
#         [ -89.2409,  -59.2882,  -61.9048,  ...,  -88.4204,  -47.2513,
#           -55.4167],
#         [ -82.1626,  -68.4030,  -76.0769,  ...,  -72.3569,  -89.8576,
#           -81.7229],
#         ...,
#         [ -53.6411, -116.6511, -102.1682,  ..., -118.6504, -138.7354,
#          -132.9308],
#         [ -63.7692,  -82.0899,  -80.8429,  ...,  -73.1414,  -75.5625,
#           -79.8313],
#         [ -49.2199,  -23.0232,  -29.9330,  ...,  -38.4708,  -37.5786,
#           -30.8451]], device='cuda:0')
# labels ：
# tensor([106,  89,  23, 167, 114, 126, 130,  80, 117,  50,  33, 120,  62,  98,
#         152, 127,  81,  36,  17,  45,  63, 162, 110,  12,  50, 131,  84, 130,
#          41, 156,  94,  20], device='cuda:0')
# loss ：
# tensor(0.6745, device='cuda:0')
# valid_data_j: 26
# Outputs :
# tensor([[ -77.0098,  -20.4465,  -12.0512,  ...,  -51.4108,  -36.7458,
#           -29.9985],
#         [  -4.0191,  -60.5700,  -52.8821,  ...,  -98.2427,  -80.3709,
#           -76.6694],
#         [ -30.5315,  -64.4189,  -73.8993,  ...,  -68.1191,  -81.4172,
#           -73.0131],
#         ...,
#         [ -33.2478,  -95.1477,  -83.4472,  ..., -116.1379, -109.4587,
#          -106.5368],
#         [ -91.9248,  -73.7964,  -82.6948,  ...,  -43.6946,  -51.4621,
#           -59.2493],
#         [ -88.6669, -162.2637, -151.9162,  ..., -132.2286, -182.0572,
#          -171.8447]], device='cuda:0')
# labels ：
# tensor([  5,  11,  49,  28, 100, 138,  64, 108, 136,  84, 155,  82,  11, 161,
#         113,  98,   7, 160, 154, 148,  48,  78,  60, 134, 123,   1,   7, 118,
#         172, 142, 102, 138], device='cuda:0')
# loss ：
# tensor(0.4432, device='cuda:0')
# valid_data_j: 27
# Outputs :
# tensor([[ -85.6648,  -85.8049,  -90.0124,  ...,  -46.5146,  -96.7327,
#           -89.3648],
#         [ -63.8129,  -82.5218,  -89.0219,  ...,  -32.4607,  -99.3956,
#           -88.3756],
#         [ -28.8162,  -93.1126,  -93.7249,  ..., -108.1041, -108.2226,
#          -101.8007],
#         ...,
#         [ -70.5605, -115.9674, -113.1352,  ..., -104.0437, -132.8394,
#          -125.9869],
#         [ -22.6902,  -92.3955,  -82.2345,  ..., -132.6721, -109.0436,
#          -105.2395],
#         [ -68.6975,  -85.6960,  -88.9137,  ...,  -98.7836,  -76.2388,
#           -81.0248]], device='cuda:0')
# labels ：
# tensor([127, 165,  56,  83,  36,  75, 103,  21,  44,  75,  38,  44, 161,  52,
#          82,  81, 103,  65, 103,  51,  93,  29,  61,  43, 140,  55, 130,  53,
#         169, 131, 143,  73], device='cuda:0')
# loss ：
# tensor(0.3683, device='cuda:0')
# valid_data_j: 28
# Outputs :
# tensor([[ -30.2293,  -68.6828,  -66.6905,  ...,  -97.5339,  -79.1017,
#           -79.0142],
#         [ -53.2825,  -89.3899,  -74.8140,  ..., -114.3537, -107.9924,
#          -105.7981],
#         [ -32.9159,  -70.8520,  -81.0418,  ...,  -73.9775,  -93.7342,
#           -82.6548],
#         ...,
#         [ -66.2402,  -41.0838,  -49.8104,  ...,  -57.0808,  -25.9186,
#           -32.2352],
#         [ -82.8533,  -18.7317,  -23.2875,  ...,  -25.7417,  -10.8375,
#           -13.2026],
#         [ -39.9823,  -57.2747,  -54.4881,  ...,  -89.4035,  -67.5433,
#           -65.7349]], device='cuda:0')
# labels ：
# tensor([ 84, 152,  48,  86, 128,  11,  10, 137,  95,  52,  49,  90,  78, 103,
#          63, 156,  59, 112,  94,   4,  25, 107,  88, 109,  46,  32,  97,  54,
#          54,  71, 144,  85], device='cuda:0')
# loss ：
# tensor(0.3457, device='cuda:0')
# valid_data_j: 29
# Outputs :
# tensor([[-1.1006e+02, -7.4026e+01, -8.3404e+01,  ..., -3.5456e+01,
#          -5.7871e+01, -6.0589e+01],
#         [-4.7412e+01, -7.5346e+01, -7.4948e+01,  ..., -9.7596e+01,
#          -7.2956e+01, -7.5025e+01],
#         [-6.2285e+01, -2.6862e+01, -3.4900e+01,  ..., -2.3827e-03,
#          -2.8310e+01, -2.3343e+01],
#         ...,
#         [-6.8055e+01, -1.0174e+02, -9.9824e+01,  ..., -8.8250e+01,
#          -1.1737e+02, -1.1088e+02],
#         [-8.0871e+01, -6.5951e+01, -7.4642e+01,  ..., -7.2494e+01,
#          -8.7734e+01, -7.9469e+01],
#         [-6.1730e+01, -4.3590e+01, -4.9526e+01,  ..., -2.5012e+01,
#          -3.6054e+01, -3.6131e+01]], device='cuda:0')
# labels ：
# tensor([103,  64, 170,  84, 127,  10, 127,  68, 132, 149,  92,  12,  23, 124,
#         133, 124,  33,  64,  12,  42,  35, 155, 119,  18, 158,  10, 139, 126,
#           9, 131,  23, 104], device='cuda:0')
# loss ：
# tensor(0.4314, device='cuda:0')
# valid_data_j: 30
# Outputs :
# tensor([[ -62.8788,   -1.0433,   -0.6948,  ...,  -21.7587,   -7.1150,
#            -3.2290],
#         [ -76.1221, -105.0092,  -98.3372,  ...,  -92.6419, -107.0251,
#          -108.5025],
#         [-102.1940, -162.9104, -153.9606,  ..., -128.4791, -179.4808,
#          -170.5717],
#         ...,
#         [ -38.0319,  -54.2545,  -45.2152,  ...,  -81.1307,  -64.0691,
#           -64.1212],
#         [ -77.6514,   -8.7454,  -13.4549,  ...,  -32.2478,   -0.3113,
#            -2.3575],
#         [ -50.2109,  -17.0200,  -19.0026,  ...,  -26.4328,  -13.1484,
#           -14.9849]], device='cuda:0')
# labels ：
# tensor([  2,  95, 136,   2, 150, 112, 141,  69,  20,  97,  16,  40,  92,  42,
#          77,  77, 170,  84,  94,  95,   3,   7,  72,  73,  10, 165,  82,  69,
#         157, 150, 171, 122], device='cuda:0')
# loss ：
# tensor(0.6866, device='cuda:0')
# valid_data_j: 31
# Outputs :
# tensor([[-112.2918,  -93.8846, -100.7820,  ...,  -53.8223,  -71.3414,
#           -80.1596],
#         [ -98.7902,  -84.0388,  -87.3280,  ...,  -39.6246,  -74.1854,
#           -78.0317],
#         [ -88.1654,  -89.0216,  -96.8223,  ...,  -62.0926,  -78.6526,
#           -77.4722],
#         ...,
#         [-121.8851,  -96.7562,  -99.6379,  ...,  -45.9591, -108.8986,
#           -99.3648],
#         [ -95.6944,  -82.4463,  -90.4971,  ...,  -57.1670,  -56.8552,
#           -67.1033],
#         [ -98.5278,  -77.7914,  -80.3953,  ...,  -38.1993,  -87.9811,
#           -80.0462]], device='cuda:0')
# labels ：
# tensor([ 99,  98, 106,  24, 110, 102,  21,  47,  75, 169,  28,   3,  52, 126,
#         117, 126, 134,  84,  42,  10,  79, 121, 155,  67,  87,  60,  57, 115,
#          62, 123, 101, 124], device='cuda:0')
# loss ：
# tensor(0.6594, device='cuda:0')
# valid_data_j: 32
# Outputs :
# tensor([[-124.0392,  -87.3507,  -93.8854,  ...,  -30.1511,  -93.7074,
#           -86.0254],
#         [ -16.0619,  -61.9616,  -70.1546,  ...,  -64.6362,  -76.2403,
#           -70.1764],
#         [ -37.8472,  -68.9902,  -79.2437,  ...,  -68.9639,  -82.6208,
#           -74.8766],
#         ...,
#         [ -56.6999,  -75.4725,  -71.4444,  ...,  -64.2706,  -74.9097,
#           -76.6309],
#         [ -69.7842,  -71.6764,  -73.8635,  ...,  -99.9931,  -60.7577,
#           -67.5211],
#         [ -54.0192,  -72.1837,  -83.4295,  ...,  -35.1905,  -70.5580,
#           -68.6019]], device='cuda:0')
# labels ：
# tensor([121,  51,  49, 129,   3, 110,  71, 116,  81, 167, 150,  38,  52,  37,
#          69, 118,  95,  93,  38,  57, 111,  25,  98, 167, 131,  60,   8, 104,
#         101,  96,  72, 113], device='cuda:0')
# loss ：
# tensor(0.6247, device='cuda:0')
# valid_data_j: 33
# Outputs :
# tensor([[ -70.5605, -115.9674, -113.1352,  ..., -104.0437, -132.8394,
#          -125.9869],
#         [-120.2294,  -94.4522, -106.8580,  ...,  -18.0218,  -85.2823,
#           -83.7522],
#         [ -10.1223,  -66.5923,  -70.3076,  ...,  -78.6748,  -87.5318,
#           -79.1349],
#         ...,
#         [-112.8409,  -77.9628,  -85.0897,  ...,  -25.1987,  -80.0020,
#           -74.7927],
#         [ -66.6880,  -16.1735,  -20.6155,  ...,  -22.4375,   -8.3621,
#           -10.8222],
#         [ -69.5102,  -49.9603,  -56.3657,  ...,  -55.4706,  -30.4259,
#           -38.4730]], device='cuda:0')
# labels ：
# tensor([131, 118,  52,  40,  29,   4,  98,  28, 150,  62, 161, 143,  77, 108,
#         136,  85,  12,  85,  57, 154,  91,  43,   1,  55,  10, 133, 149, 105,
#          78, 120, 155,  68], device='cuda:0')
# loss ：
# tensor(0.8168, device='cuda:0')
# valid_data_j: 34
# Outputs :
# tensor([[ -63.8129,  -82.5218,  -89.0219,  ...,  -32.4607,  -99.3956,
#           -88.3756],
#         [ -41.7787, -126.5894, -112.3175,  ..., -150.1194, -145.6959,
#          -141.3782],
#         [ -91.4766,  -78.3023,  -76.5620,  ...,  -46.6821,  -93.5723,
#           -84.5141],
#         ...,
#         [ -55.9248,  -50.0763,  -44.7533,  ...,  -60.6468,  -76.4838,
#           -64.8113],
#         [ -88.1654,  -89.0216,  -96.8223,  ...,  -62.0926,  -78.6526,
#           -77.4722],
#         [ -76.7261,  -26.2599,  -29.1903,  ...,  -35.1046,  -16.7774,
#           -20.9898]], device='cuda:0')
# labels ：
# tensor([165, 141, 124,  62,  11, 118,  38,  41, 128,  31,  52,  52, 147, 163,
#          39, 100,  65,  59, 144,  55,  49, 132,  91,  42, 170, 163,  62, 141,
#          52,  13, 106, 133], device='cuda:0')
# loss ：
# tensor(0.4936, device='cuda:0')
# valid_data_j: 35
# Outputs :
# tensor([[ -20.9304,  -90.5132,  -80.9478,  ..., -130.5504, -107.3750,
#          -103.2519],
#         [ -41.7787, -126.5894, -112.3175,  ..., -150.1194, -145.6959,
#          -141.3782],
#         [ -20.0028,  -77.1528,  -68.2963,  ..., -112.0543,  -91.4334,
#           -88.5562],
#         ...,
#         [ -69.3191,  -71.9118,  -68.5835,  ...,  -80.9937,  -66.1392,
#           -71.8044],
#         [ -75.6531,  -80.4383,  -80.1787,  ...,  -90.0645,  -72.6350,
#           -78.1389],
#         [ -62.4370,  -84.1584,  -87.6616,  ...,  -81.9215,  -80.0653,
#           -78.8556]], device='cuda:0')
# labels ：
# tensor([143, 141, 145, 127,  54, 153, 165, 150, 123,  11,  26, 163,  92,  19,
#          74, 156, 163,  72,  20, 145,  69,  58,  79,  43, 111, 123,  88, 158,
#         138,  32,  35, 108], device='cuda:0')
# loss ：
# tensor(0.5602, device='cuda:0')
# valid_data_j: 36
# Outputs :
# tensor([[ -98.5278,  -77.7914,  -80.3953,  ...,  -38.1993,  -87.9811,
#           -80.0462],
#         [ -69.9263,  -73.0800,  -75.4609,  ..., -102.4472,  -61.9024,
#           -68.9419],
#         [ -76.1221, -105.0092,  -98.3372,  ...,  -92.6419, -107.0251,
#          -108.5025],
#         ...,
#         [ -85.2420, -107.6828,  -95.1822,  ...,  -82.7569, -122.4394,
#          -116.9107],
#         [ -54.4776,  -73.6205,  -70.3731,  ..., -105.5911,  -70.7822,
#           -76.7013],
#         [ -39.9959,  -45.7897,  -44.1460,  ...,  -67.6947,  -52.3859,
#           -50.9619]], device='cuda:0')
# labels ：
# tensor([124,  72,  95, 122,  78,  57, 150,  31,  19,  24,  76, 105, 164,  29,
#          73,  69,   7,  95, 123, 107,  47, 131, 129,  87,  74,  70, 170,  95,
#         141, 159,  87,  85], device='cuda:0')
# loss ：
# tensor(0.4856, device='cuda:0')
# valid_data_j: 37
# Outputs :
# tensor([[ -61.7756,  -55.7137,  -40.9971,  ...,  -83.9108,  -77.2902,
#           -71.7784],
#         [ -50.2109,  -17.0200,  -19.0026,  ...,  -26.4328,  -13.1484,
#           -14.9849],
#         [ -88.9926,  -47.4342,  -42.0068,  ...,  -43.2668,  -66.3006,
#           -56.8381],
#         ...,
#         [ -69.1868,  -98.5790,  -98.6751,  ...,  -78.7796, -101.2046,
#           -97.5124],
#         [ -91.0395,  -49.8697,  -59.6127,  ...,   -6.9564,  -53.9596,
#           -47.4887],
#         [ -55.3475,  -15.6001,   -9.3465,  ...,  -38.0211,  -28.1716,
#           -22.9975]], device='cuda:0')
# labels ：
# tensor([  8, 122,  16, 152,  36,  11, 159, 107, 131, 155, 158,  72, 112,  42,
#          12,  53, 111, 166,  61, 103,  99,  38,  22,  33, 147, 123, 139,  50,
#          21, 109, 169,   4], device='cuda:0')
# loss ：
# tensor(1.0959, device='cuda:0')
# valid_data_j: 38
# Outputs :
# tensor([[ -30.7571,  -90.0039,  -90.1620,  ...,  -68.9522, -109.3259,
#          -100.9134],
#         [ -72.0884,  -78.4152,  -76.3353,  ...,  -86.8338,  -73.1076,
#           -77.7086],
#         [ -71.1625,  -33.7637,  -33.4858,  ...,  -53.5995,  -26.4316,
#           -30.9983],
#         ...,
#         [ -92.3116,  -38.9221,  -39.8883,  ...,  -30.8910,  -52.9528,
#           -43.5532],
#         [ -24.3924,  -93.4204,  -93.1478,  ..., -114.1701, -112.1539,
#          -104.8223],
#         [ -64.3470,   -6.2334,   -9.9345,  ...,  -26.6050,   -0.3852,
#            -1.5049]], device='cuda:0')
# labels ：
# tensor([162,  35, 111,  18, 170,  14,  95,  54,  12, 109, 161,  29, 158,  38,
#         155, 136, 119,  97, 147, 111,  89,  31, 147, 114,  47, 126, 112,  49,
#         146,  17,  53, 171], device='cuda:0')
# loss ：
# tensor(0.7246, device='cuda:0')
# valid_data_j: 39
# Outputs :
# tensor([[ -50.0016,  -52.1349,  -60.9700,  ...,  -17.0647,  -60.0077,
#           -53.5390],
#         [ -68.7041,  -43.1212,  -51.1697,  ...,  -60.1857,  -28.8137,
#           -34.9611],
#         [ -40.2032, -107.8333,  -96.1065,  ..., -115.5508, -124.1093,
#          -119.7049],
#         ...,
#         [ -33.1336,  -54.1035,  -53.7266,  ..., -102.5018,  -58.2210,
#           -61.9388],
#         [ -95.1191,  -64.7360,  -67.9300,  ...,  -95.9288,  -51.9869,
#           -60.6929],
#         [ -60.3797, -141.0012, -128.9592,  ..., -132.7756, -160.0373,
#          -153.1195]], device='cuda:0')
# labels ：
# tensor([168,  71, 140, 152, 133, 119,  58,  52,  32, 114, 158,  15,  88,  97,
#          24, 112, 168, 101,  48,  43, 125,  46, 152, 111,   4,  12,  83, 105,
#           4,  55, 100, 139], device='cuda:0')
# loss ：
# tensor(0.8924, device='cuda:0')
# valid_data_j: 40
# Outputs :
# tensor([[ -22.7972,  -62.7412,  -65.7350,  ...,  -72.7860,  -81.0209,
#           -74.8666],
#         [ -85.2420, -107.6828,  -95.1822,  ...,  -82.7569, -122.4394,
#          -116.9107],
#         [-104.3425,  -76.5219,  -84.3525,  ...,  -80.7965,  -47.5758,
#           -59.8591],
#         ...,
#         [ -51.7870,  -82.0758,  -80.1588,  ..., -101.3115,  -80.1701,
#           -81.0429],
#         [ -61.4880,  -76.4049,  -82.4591,  ...,  -70.7739,  -86.3248,
#           -80.6906],
#         [ -43.3186,  -94.9243,  -88.0350,  ..., -125.1346, -104.8264,
#          -103.4655]], device='cuda:0')
# labels ：
# tensor([ 82, 159,  91,  80, 116,  13, 152, 105, 123,  18,  72, 118,  79, 172,
#          69,  18, 145, 119,  33, 133, 119,  56,  10, 128, 105, 117,  57, 150,
#         151,  63,  43,  61], device='cuda:0')
# loss ：
# tensor(0.5898, device='cuda:0')
# valid_data_j: 41
# Outputs :
# tensor([[ -76.8885,  -83.4652,  -96.0043,  ...,  -29.9560,  -89.2935,
#           -81.6521],
#         [ -49.2839,  -38.2628,  -46.5057,  ...,  -50.6503,  -46.7051,
#           -44.5737],
#         [ -56.3885,  -75.9652,  -71.3656,  ..., -124.9803,  -77.2428,
#           -81.5814],
#         ...,
#         [ -44.4105, -125.6926, -109.8225,  ..., -152.6058, -144.2589,
#          -140.6763],
#         [ -72.2646,  -71.9674,  -78.0839,  ...,  -77.2766,  -51.9920,
#           -61.6562],
#         [ -71.8524,  -63.4349,  -56.2675,  ...,  -73.0185,  -95.2524,
#           -81.2067]], device='cuda:0')
# labels ：
# tensor([115,  24,  86, 124,  24,  18,  41,  82,  23,  87,  59,  20,  28, 108,
#         151, 157, 119, 138, 129,  90,  68,  52,  23,  18,  39, 151, 128,  24,
#          19, 142,  67,  13], device='cuda:0')
# loss ：
# tensor(0.4212, device='cuda:0')
# valid_data_j: 42
# Outputs :
# tensor([[-100.2937,  -92.3564,  -92.1140,  ...,  -54.4135, -108.0864,
#           -98.8042],
#         [-113.6646,  -98.7198, -106.4961,  ...,  -61.8468,  -72.1825,
#           -82.9526],
#         [ -62.4464,  -69.3804,  -74.3253,  ...,  -69.4398,  -52.8925,
#           -58.9354],
#         ...,
#         [ -47.6798,  -61.5355,  -51.3510,  ...,  -77.5761,  -73.0687,
#           -72.0232],
#         [ -60.3541,  -72.2371,  -69.3346,  ..., -101.0210,  -66.8878,
#           -73.6918],
#         [ -50.2109,  -17.0200,  -19.0026,  ...,  -26.4328,  -13.1484,
#           -14.9849]], device='cuda:0')
# labels ：
# tensor([125, 101,  65, 106,  44,  23,  38,  26,  79,  79,  79, 172, 130, 129,
#         155, 164,  83,   3,  37,  28,  88, 148, 172, 109,  19,  89, 126, 115,
#          40, 152,  87, 122], device='cuda:0')
# loss ：
# tensor(0.7162, device='cuda:0')
# valid_data_j: 43
# Outputs :
# tensor([[ -64.6957,  -61.4831,  -60.9133,  ...,  -87.1351,  -50.0989,
#           -56.6082],
#         [-103.4192, -134.2609, -132.3967,  ...,  -69.0965, -151.2638,
#          -140.8343],
#         [ -62.8229,  -76.9628,  -72.9555,  ..., -122.5433,  -75.2104,
#           -80.5115],
#         ...,
#         [ -16.0816,  -53.9327,  -48.5412,  ...,  -95.4120,  -65.0634,
#           -65.4202],
#         [-109.6055,  -83.9494,  -89.8551,  ...,  -21.5719,  -92.9427,
#           -84.9688],
#         [ -62.8287,  -56.8734,  -56.6157,  ...,  -62.2501,  -55.3413,
#           -55.9833]], device='cuda:0')
# labels ：
# tensor([ 90, 160,  86,  53, 110,  69,  19,  61, 126,  86, 140, 116, 102,  11,
#          83,  95, 165, 120, 171, 164,  53,  61, 116, 150, 116, 154, 117, 151,
#         163,  33, 167,  37], device='cuda:0')
# loss ：
# tensor(0.5051, device='cuda:0')
# valid_data_j: 44
# Outputs :
# tensor([[ -29.6014,  -60.3484,  -58.6970,  ...,  -87.7011,  -70.9492,
#           -69.6684],
#         [ -93.7506, -109.4490, -112.0529,  ..., -108.6359, -109.1802,
#          -108.7126],
#         [ -50.0016,  -52.1349,  -60.9700,  ...,  -17.0647,  -60.0077,
#           -53.5390],
#         ...,
#         [ -66.2402,  -41.0838,  -49.8104,  ...,  -57.0808,  -25.9186,
#           -32.2352],
#         [ -60.3797, -141.0012, -128.9592,  ..., -132.7756, -160.0373,
#          -153.1195],
#         [ -60.2624,  -79.6261,  -78.7634,  ...,  -81.7280,  -85.9880,
#           -85.1487]], device='cuda:0')
# labels ：
# tensor([ 84,  38, 168, 113,  28,  25, 109, 123, 144,   8,  99, 156,  50,  57,
#          83, 136,  66,  60,  98,  98, 138, 166,  34,  26,  28, 120,  22, 153,
#          82,  71, 139,  76], device='cuda:0')
# loss ：
# tensor(0.4202, device='cuda:0')
# valid_data_j: 45
# Outputs :
# tensor([[ -58.5226, -129.9764, -126.4949,  ...,  -94.1385, -154.1114,
#          -143.2542],
#         [ -51.8903, -100.3254,  -87.3465,  ..., -125.1146, -112.0752,
#          -110.3157],
#         [ -57.7335, -111.0119, -111.5506,  ...,  -94.3500, -112.2225,
#          -109.2894],
#         ...,
#         [ -64.4985,  -82.0580,  -67.9132,  ..., -113.2118,  -94.0851,
#           -94.9810],
#         [ -76.2590,  -72.1885,  -79.1250,  ...,  -45.3421,  -61.9406,
#           -61.9459],
#         [-113.9124,  -92.0836,  -95.8619,  ..., -102.4357,  -85.9061,
#           -92.3040]], device='cuda:0')
# labels ：
# tensor([161, 146, 110, 143, 107, 139,  64,  67,   4, 105,  21,   5, 106, 138,
#          74,  43,  86, 130, 101,  51,  74, 103, 111,  54,  72,  69, 162,  11,
#          92, 149, 106,  30], device='cuda:0')
# loss ：
# tensor(0.5228, device='cuda:0')
# valid_data_j: 46
# Outputs :
# tensor([[ -76.2590,  -72.1885,  -79.1250,  ...,  -45.3421,  -61.9406,
#           -61.9459],
#         [ -46.8325, -122.2212, -111.0037,  ..., -152.7352, -137.0033,
#          -134.1603],
#         [ -99.3544, -109.9239, -113.9375,  ..., -115.0450, -103.6929,
#          -107.6739],
#         ...,
#         [ -27.3781,  -64.7212,  -67.3616,  ...,  -74.7716,  -81.5727,
#           -76.1711],
#         [ -86.1533,  -56.4345,  -48.5297,  ...,  -54.5120,  -80.5257,
#           -69.4200],
#         [ -53.5914,  -59.1627,  -55.2147,  ...,  -38.0315,  -60.6065,
#           -60.2806]], device='cuda:0')
# labels ：
# tensor([106,  60,  39, 136,  83, 109, 135, 122,   9, 130,  10,  21, 134, 154,
#          64,  82,  76, 170, 120,  68,  42, 117,   5,  23, 106,   0, 169,  25,
#          79,  81,  14,  96], device='cuda:0')
# loss ：
# tensor(0.3971, device='cuda:0')
# valid_data_j: 47
# Outputs :
# tensor([[-118.7632,  -93.6967,  -97.7436,  ...,  -48.5156, -106.6381,
#           -96.5416],
#         [ -57.1548,  -52.7777,  -38.8380,  ...,  -79.8336,  -73.0133,
#           -68.1384],
#         [ -77.0098,  -20.4465,  -12.0512,  ...,  -51.4108,  -36.7458,
#           -29.9985],
#         ...,
#         [ -42.1808,  -64.1476,  -64.5388,  ...,  -85.8870,  -61.3994,
#           -64.3633],
#         [ -67.2331,  -97.2341,  -99.6117,  ...,  -94.9105,  -94.0484,
#           -92.3551],
#         [ -16.0816,  -53.9327,  -48.5412,  ...,  -95.4120,  -65.0634,
#           -65.4202]], device='cuda:0')
# labels ：
# tensor([123,   9,   5,  30,  18,  95,  85,  61,  84,   0, 100, 114,  32,  40,
#         117, 153,  76, 172, 123,  58, 108, 125,  97,  17, 143, 157,  71,  31,
#         108,  64, 108,  33], device='cuda:0')
# loss ：
# tensor(0.8292, device='cuda:0')
# valid_data_j: 48
# Outputs :
# tensor([[-106.5581, -137.1142, -132.6255,  ..., -121.2841, -148.7898,
#          -142.8223],
#         [ -34.0881,  -75.5672,  -73.1712,  ..., -106.8020,  -86.5038,
#           -86.5745],
#         [ -68.5372,  -37.3566,  -41.1666,  ...,  -51.7858,  -59.0615,
#           -48.8665],
#         ...,
#         [ -69.6429,  -38.9678,  -26.3738,  ...,  -70.2556,  -60.2024,
#           -53.1317],
#         [ -71.9540,  -29.1617,  -33.2388,  ...,  -38.9335,  -43.5247,
#           -35.6568],
#         [ -44.4105, -125.6926, -109.8225,  ..., -152.6058, -144.2589,
#          -140.6763]], device='cuda:0')
# labels ：
# tensor([134,  84,  19, 132, 163,   8,  71,  71, 139,  25, 125,  30, 164,  85,
#          51, 151,  42,  86, 155, 123,  72,  44,   3, 115,  26,   0,  58, 156,
#          49,   6,  18, 142], device='cuda:0')
# loss ：
# tensor(0.2894, device='cuda:0')
# valid_data_j: 49
# Outputs :
# tensor([[ -76.2590,  -72.1885,  -79.1250,  ...,  -45.3421,  -61.9406,
#           -61.9459],
#         [ -71.1575, -125.0724, -133.0672,  ...,  -83.9311, -129.1563,
#          -123.9331],
#         [ -38.0319,  -54.2545,  -45.2152,  ...,  -81.1307,  -64.0691,
#           -64.1212],
#         ...,
#         [ -73.1928,  -54.1565,  -60.9837,  ...,  -59.0622,  -64.2016,
#           -61.1046],
#         [ -59.6836, -112.8714, -114.4200,  ...,  -93.7601, -112.8227,
#          -110.5573],
#         [ -34.9943,  -99.1761,  -88.5855,  ..., -129.1736, -113.4999,
#          -111.0823]], device='cuda:0')
# labels ：
# tensor([106, 112, 150, 124,   9,  61, 157, 139,  55, 143, 151,  60,  60, 164,
#          82, 148, 158,  99,  19,  10, 125, 130, 113,  93,   8, 107, 135,  13,
#          64,  25, 110,  60], device='cuda:0')
# loss ：
# tensor(0.7854, device='cuda:0')
# valid_data_j: 50
# Outputs :
# tensor([[ -51.8668, -138.0552, -129.0655,  ..., -158.5835, -150.9661,
#          -145.6918],
#         [ -69.3191,  -71.9118,  -68.5835,  ...,  -80.9937,  -66.1392,
#           -71.8044],
#         [ -49.2839,  -38.2628,  -46.5057,  ...,  -50.6503,  -46.7051,
#           -44.5737],
#         ...,
#         [-121.8851,  -96.7562,  -99.6379,  ...,  -45.9591, -108.8986,
#           -99.3648],
#         [ -65.5943,  -75.5520,  -80.3920,  ...,  -29.5558,  -90.2481,
#           -80.5024],
#         [ -56.4836,  -74.9341,  -71.0526,  ...,  -63.7379,  -74.7267,
#           -76.1415]], device='cuda:0')
# labels ：
# tensor([ 58,  32,  24,  49, 121,  47,  79, 102,   7,  20,  59, 129,   4,  16,
#          30,  97,  45, 154,  16,  46, 165, 147, 151,  75,   6, 106,  41, 122,
#         102, 123, 165,  94], device='cuda:0')
# loss ：
# tensor(0.6559, device='cuda:0')
# valid_data_j: 51
# Outputs :
# tensor([[-89.9743, -76.3162, -74.9287,  ..., -48.8164, -71.5579, -74.2477],
#         [-63.2712, -60.1652, -44.5346,  ..., -89.9822, -82.9662, -77.3775],
#         [-80.4898, -80.3902, -90.7347,  ..., -20.4386, -74.3189, -72.3661],
#         ...,
#         [-43.4043, -70.2240, -80.0754,  ..., -67.8026, -80.9796, -74.0737],
#         [-71.9540, -29.1617, -33.2388,  ..., -38.9335, -43.5247, -35.6568],
#         [-65.0976, -48.1060, -52.3660,  ..., -52.4439, -32.1830, -38.6238]],
#        device='cuda:0')
# labels ：
# tensor([ 97,   8, 117,  13,  41,  16,  60,   9,  85,  48, 128,  58, 168, 125,
#          27,  93,  39,  28,   6,  37, 109, 162,  76, 161,  65, 168, 114,   2,
#         128,  47,  18,  68], device='cuda:0')
# loss ：
# tensor(0.6246, device='cuda:0')
# valid_data_j: 52
# Outputs :
# tensor([[-24.6797, -52.7152, -51.8923,  ..., -71.3021, -62.9787, -61.7564],
#         [-65.1967, -13.1138, -19.2919,  ..., -23.1065,  -4.8221,  -7.4888],
#         [-86.0342, -78.8739, -82.1050,  ..., -81.6025, -59.5770, -68.8319],
#         ...,
#         [-67.2331, -97.2341, -99.6117,  ..., -94.9105, -94.0484, -92.3551],
#         [-66.9886, -60.2040, -59.2154,  ..., -37.7047, -57.4914, -58.8152],
#         [-72.0884, -78.4152, -76.3353,  ..., -86.8338, -73.1076, -77.7086]],
#        device='cuda:0')
# labels ：
# tensor([ 83, 166,  91,   8, 157,  26,  85,  45, 130,  18, 126,   8,   0,  92,
#         116,  50, 157, 149,  62, 150, 135, 138,  13, 149, 147,  78, 101,  85,
#           3, 108,  97,  35], device='cuda:0')
# loss ：
# tensor(0.5371, device='cuda:0')
# valid_data_j: 53
# Outputs :
# tensor([[ -80.6023,  -74.8789,  -74.3510,  ..., -106.8326,  -61.4511,
#           -69.0140],
#         [  -0.5541,  -62.9344,  -58.7057,  ...,  -98.4936,  -85.7046,
#           -79.0515],
#         [ -66.5181, -116.9474,  -97.6046,  ..., -141.9948, -138.7416,
#          -136.1577],
#         ...,
#         [ -65.1240, -131.3917, -124.7249,  ..., -149.0005, -141.2042,
#          -138.9419],
#         [-102.0336,  -85.1216,  -87.3000,  ...,  -88.5270,  -80.6600,
#           -85.5806],
#         [ -54.1513,  -58.5448,  -68.5626,  ...,  -19.5905,  -67.3863,
#           -60.2375]], device='cuda:0')
# labels ：
# tensor([ 90,   0, 153,  16,  23,  13,   8,  89,  68,  95, 116, 148,   9,  62,
#          96,  11, 105, 165,  27,  75, 145, 123, 140,  40,  46,  52, 163, 156,
#          38,  59,  30, 168], device='cuda:0')
# loss ：
# tensor(0.2575, device='cuda:0')
# valid_data_j: 54
# Outputs :
# tensor([[ -54.0423,  -58.8731,  -54.6493,  ...,  -39.5154,  -60.1988,
#           -60.1712],
#         [ -73.8860, -100.3940, -113.5931,  ...,  -45.7698, -112.4290,
#          -102.5496],
#         [ -71.9540,  -29.1617,  -33.2388,  ...,  -38.9335,  -43.5247,
#           -35.6568],
#         ...,
#         [ -80.8352, -100.6949,  -90.6384,  ...,  -71.7198, -113.2478,
#          -107.8755],
#         [ -32.8784,  -66.4755,  -66.2249,  ...,  -88.1530,  -81.4518,
#           -78.8076],
#         [ -76.7261,  -26.2599,  -29.1903,  ...,  -35.1046,  -16.7774,
#           -20.9898]], device='cuda:0')
# labels ：
# tensor([ 96, 114,  18,  11, 130,  88,  99, 114,  83,  51,  13,  37, 158,  74,
#          68,  68,  83,  55, 122, 133, 160, 140,  25, 110,   5, 123, 164, 104,
#         161, 158,  83, 133], device='cuda:0')
# loss ：
# tensor(0.4620, device='cuda:0')
# valid_data_j: 55
# Outputs :
# tensor([[ -50.7152,  -85.8749,  -71.2352,  ..., -110.1424,  -99.7515,
#           -98.7955],
#         [ -61.7299,  -43.5901,  -49.5260,  ...,  -25.0117,  -36.0537,
#           -36.1310],
#         [ -97.6482,  -77.5791,  -82.3908,  ...,  -32.1461,  -68.6380,
#           -71.2485],
#         ...,
#         [ -79.7341, -102.4564, -107.9642,  ...,  -76.2359,  -90.7319,
#           -92.5386],
#         [ -96.8412,  -12.5181,  -18.5948,  ...,  -44.0792,   -0.1799,
#            -3.5878],
#         [  -0.6636,  -64.8753,  -61.7718,  ..., -101.5698,  -88.5305,
#           -81.1535]], device='cuda:0')
# labels ：
# tensor([147, 104,  98,  23, 128,  69,  97, 153, 143,  85,  17,  34, 109, 156,
#         133, 102, 132,  14, 120,  39, 113, 163,  50, 147,  96, 172,  95, 108,
#         112, 107, 171,   0], device='cuda:0')
# loss ：
# tensor(0.5779, device='cuda:0')
# valid_data_j: 56
# Outputs :
# tensor([[ -74.9048,   -2.5928,   -0.6626,  ...,  -29.2718,  -10.1432,
#            -5.8495],
#         [ -68.1595,  -87.9620,  -92.9078,  ...,  -88.0247, -104.0204,
#           -98.2499],
# ...
# loss ：
# tensor(0.4681, device='cuda:0')
# valid_data_j: 1302
# Outputs :
# tensor([[ -88.4007,  -77.3254,  -79.3613,  ...,  -84.0973,  -65.9933,
#           -73.5432],
#         [ -31.0383,  -74.9168,  -81.3153,  ...,  -44.6411,  -94.8748,
#           -84.5571],
#         [ -86.6046,  -77.0074,  -84.8836,  ...,  -81.4762,  -52.8719,
#           -64.3871],
#         ...,
#         [ -64.6093,  -78.6471,  -79.4530,  ...,  -85.9514,  -80.6221,
#           -82.9387],
#         [ -62.2701, -104.2085, -101.4518,  ...,  -93.8554, -119.7729,
#          -113.4568],
#         [ -68.0551, -101.7442,  -99.8240,  ...,  -88.2504, -117.3656,
#          -110.8795]], device='cuda:0')
# labels ：
# tensor([ 31, 163,  67,  17,  11, 132, 137,  77, 147,  61,  62,  41, 124, 144,
#         146,  62, 138,  10,  86, 109,  91, 102, 158,  41,  74, 107, 120,  32,
#         163,  76, 131, 131], device='cuda:0')
# loss ：
# tensor(0.3640, device='cuda:0')
# valid_data_j: 1303
# Outputs :
# tensor([[ -29.6014,  -60.3484,  -58.6970,  ...,  -87.7011,  -70.9492,
#           -69.6684],
#         [ -86.1533,  -56.4345,  -48.5297,  ...,  -54.5120,  -80.5257,
#           -69.4200],
#         [ -35.6437,  -37.2403,  -43.4428,  ...,  -60.6741,  -39.9206,
#           -41.8157],
#         ...,
#         [ -66.5181, -116.9474,  -97.6046,  ..., -141.9948, -138.7416,
#          -136.1577],
#         [ -91.4766,  -78.3023,  -76.5620,  ...,  -46.6821,  -93.5723,
#           -84.5141],
#         [ -77.2817,  -88.4495,  -97.2640,  ...,  -25.9459,  -88.1101,
#           -83.8630]], device='cuda:0')
# labels ：
# tensor([ 84,  14,  55, 168,  62,  82,  23, 141,  65,  82, 108, 160,  12,  30,
#         148,   4, 131,  37, 124, 117,  92,   6,  49,  46,  28,  61, 140, 115,
#          22, 153, 124, 116], device='cuda:0')
# loss ：
# tensor(0.2181, device='cuda:0')
# valid_data_j: 1304
# Outputs :
# tensor([[ -25.2637,  -54.9072,  -63.2990,  ...,  -56.9445,  -68.3513,
#           -61.5676],
#         [ -54.7515,  -27.2196,  -35.4987,  ...,  -43.2775,  -43.4969,
#           -36.0484],
#         [ -58.7417,   -1.5460,   -4.0625,  ...,  -17.8323,   -2.5679,
#            -0.3714],
#         ...,
#         [ -50.6899,  -22.3298,  -29.0709,  ...,  -39.6067,  -36.7736,
#           -30.1902],
#         [ -73.7634,  -89.6481,  -90.8242,  ...,  -92.4082,  -93.2906,
#           -94.6407],
#         [ -76.8893,  -82.6795,  -91.3030,  ...,  -62.1868, -102.4878,
#           -91.3829]], device='cuda:0')
# labels ：
# tensor([ 50,  20, 172, 109,   7, 145,  91,  92,  57,  79, 105,  72, 170,  66,
#          81, 117, 163, 166,  41, 167,  55,  48,  41, 146, 105,  24,  45,  93,
#         110,  20,  76,  45], device='cuda:0')
# loss ：
# tensor(0.8541, device='cuda:0')
# valid_data_j: 1305
# Outputs :
# tensor([[ -60.7276,  -81.7357,  -68.3960,  ...,  -80.9264,  -98.9316,
#           -94.1551],
#         [ -88.3068,  -56.2685,  -48.3888,  ...,  -54.8239,  -80.3953,
#           -69.2425],
#         [ -61.2007,  -20.0915,  -29.3916,  ...,  -40.3231,   -6.6438,
#           -12.4020],
#         ...,
#         [ -71.1625,  -33.7637,  -33.4858,  ...,  -53.5995,  -26.4316,
#           -30.9983],
#         [ -46.8325, -122.2212, -111.0037,  ..., -152.7352, -137.0033,
#          -134.1603],
#         [ -58.7353,  -74.8472,  -76.0756,  ...,  -74.9324,  -79.9374,
#           -79.8911]], device='cuda:0')
# labels ：
# tensor([157,  14, 155, 153,  90, 132,  86,  45, 114, 138,  61,  78, 112, 154,
#         119,   8, 121, 125, 154,  95, 101,  93,  52, 136,  95, 124, 117,  97,
#         154, 111,  60,  78], device='cuda:0')
# loss ：
# tensor(0.6533, device='cuda:0')
# valid_data_j: 1306
# Outputs :
# tensor([[-8.4997e+01, -8.4774e+01, -9.6631e+01,  ..., -2.1480e+01,
#          -7.7590e+01, -7.5916e+01],
#         [-5.1890e+01, -1.0033e+02, -8.7347e+01,  ..., -1.2511e+02,
#          -1.1208e+02, -1.1032e+02],
#         [-7.0312e+01, -2.9974e+01, -3.8196e+01,  ..., -1.2664e-02,
#          -3.1567e+01, -2.6298e+01],
#         ...,
#         [-6.7552e+01, -3.9292e+01, -3.6243e+01,  ..., -5.1355e+01,
#          -3.9255e+01, -4.1386e+01],
#         [-8.9357e+01, -4.8050e+01, -5.7273e+01,  ..., -6.5546e+00,
#          -5.1939e+01, -4.5683e+01],
#         [-6.2528e+01, -4.4422e+01, -3.1220e+01,  ..., -7.3028e+01,
#          -6.5048e+01, -5.9093e+01]], device='cuda:0')
# labels ：
# tensor([117, 146, 170,   2,  99, 117,  94,  30,   9, 142,  18, 145,  14,  48,
#          29, 152,  75, 166, 144, 120, 140,  68, 172, 130,  52,  96,  26, 138,
#         147, 111, 169,   7], device='cuda:0')
# loss ：
# tensor(0.6889, device='cuda:0')
# valid_data_j: 1307
# Outputs :
# tensor([[ -89.9743,  -76.3162,  -74.9287,  ...,  -48.8164,  -71.5579,
#           -74.2477],
#         [-102.9846,  -66.6308,  -80.1908,  ...,  -81.7373,  -36.7742,
#           -49.0553],
#         [ -43.4043,  -70.2240,  -80.0754,  ...,  -67.8026,  -80.9796,
#           -74.0737],
#         ...,
#         [-111.1658, -119.7943, -121.4087,  ..., -125.0300, -120.2164,
#          -118.9858],
#         [ -34.0881,  -75.5672,  -73.1712,  ..., -106.8020,  -86.5038,
#           -86.5745],
#         [  -0.6707,  -60.4188,  -56.7033,  ...,  -95.7951,  -82.0902,
#           -75.5594]], device='cuda:0')
# labels ：
# tensor([ 97,  69,  47,  25,  75, 118, 162, 124,  59, 123,  28,  23, 110,  36,
#          13, 124, 119,  46,  60, 170, 157, 157,  38, 155,  50, 154,  86,   6,
#          47,  38,  84,  88], device='cuda:0')
# loss ：
# tensor(0.8827, device='cuda:0')
# valid_data_j: 1308
# Outputs :
# tensor([[ -76.8885,  -83.4652,  -96.0043,  ...,  -29.9560,  -89.2935,
#           -81.6521],
#         [-106.2931,  -82.7654,  -92.3869,  ...,  -43.0110,  -59.1009,
#           -67.1135],
#         [ -88.1253,  -47.9384,  -57.1012,  ...,   -6.7522,  -51.9391,
#           -45.7130],
#         ...,
#         [ -34.4745, -112.6210,  -99.8019,  ..., -143.4737, -130.4869,
#          -126.5134],
#         [-103.8814, -134.1675, -133.2776,  ..., -114.2848, -145.2755,
#          -139.2286],
#         [ -32.3651,  -63.3869,  -66.6698,  ...,  -68.9337,  -78.3932,
#           -73.4459]], device='cuda:0')
# labels ：
# tensor([115, 102, 169, 170, 112,  48,  11,  11,  56,  22,  13, 123,  87,  45,
#          73, 109,  14,  40,  59, 159,  29, 133,  23,  56,  13,  15,  11, 162,
#         165, 143, 134,  81], device='cuda:0')
# loss ：
# tensor(0.9676, device='cuda:0')
# valid_data_j: 1309
# Outputs :
# tensor([[ -90.9902, -117.6675, -118.8479,  ..., -113.2649, -125.7731,
#          -121.8434],
#         [ -64.1497, -113.9731, -120.7154,  ...,  -78.4712, -117.5915,
#          -113.0035],
#         [ -96.0672,  -81.1086,  -87.3087,  ...,  -22.9483,  -91.4034,
#           -82.9000],
#         ...,
#         [ -31.3173,  -96.8304,  -97.2272,  ..., -110.9271, -111.0996,
#          -104.9617],
#         [ -67.3634,  -45.1389,  -50.3666,  ...,  -31.3536,  -42.7311,
#           -39.4808],
#         [ -74.9048,   -2.5928,   -0.6626,  ...,  -29.2718,  -10.1432,
#            -5.8495]], device='cuda:0')
# labels ：
# tensor([ 40, 112, 167, 149,   1, 142,  22, 148, 102,  26, 157, 128, 144, 118,
#          35,  51,  77, 115, 117,  97, 108, 166,  32,  46, 168, 145, 126, 149,
#          46,  56, 105,   3], device='cuda:0')
# loss ：
# tensor(0.3233, device='cuda:0')
# valid_data_j: 1310
# Outputs :
# tensor([[ -99.8790, -179.5453, -168.3802,  ..., -144.1619, -201.7053,
#          -190.0516],
#         [ -44.1387,  -37.6910,  -44.1568,  ...,   -9.9959,  -43.1234,
#           -38.1291],
#         [ -41.7787, -126.5894, -112.3175,  ..., -150.1194, -145.6959,
#          -141.3782],
#         ...,
#         [-139.7184, -117.0572, -124.6133,  ...,  -73.3375,  -88.7075,
#          -100.1421],
#         [ -29.8696,  -65.8124,  -68.7505,  ...,  -75.4790,  -82.7338,
#           -77.3049],
#         [ -90.3085, -102.4545, -111.9232,  ...,  -55.6817, -119.5372,
#          -108.8484]], device='cuda:0')
# labels ：
# tensor([137, 168, 141, 147, 128,  38, 114, 158, 104, 144, 170,  43,  65,  24,
#         167,  43,  76,  77,  54,  66,  32, 105, 141,  83,  73,  47, 135, 103,
#          34,  99,  82, 128], device='cuda:0')
# loss ：
# tensor(0.6155, device='cuda:0')
# valid_data_j: 1311
# Outputs :
# tensor([[ -95.7824,   -4.8499,   -1.3308,  ...,  -38.5508,  -15.5477,
#            -9.7843],
#         [ -39.2265,  -66.7770,  -76.7417,  ...,  -66.3517,  -78.9471,
#           -71.6182],
#         [ -66.5181, -116.9474,  -97.6046,  ..., -141.9948, -138.7416,
#          -136.1577],
#         ...,
#         [ -67.1491,  -82.2761,  -65.4065,  ..., -109.8684, -108.0578,
#          -101.7437],
#         [ -71.1625,  -33.7637,  -33.4858,  ...,  -53.5995,  -26.4316,
#           -30.9983],
#         [ -47.4120,  -75.3458,  -74.9480,  ...,  -97.5958,  -72.9556,
#           -75.0247]], device='cuda:0')
# labels ：
# tensor([  3,  46, 153,  98,  38,  12,  93,  34, 151,  19, 121, 124,   3, 155,
#          58, 108,  88, 140, 156, 170, 166, 109,  62, 112,  74,  38, 151,  30,
#         148,   9, 111,  64], device='cuda:0')
# loss ：
# tensor(0.4077, device='cuda:0')
# valid_data_j: 1312
# Outputs :
# tensor([[-106.6263,  -77.1298,  -82.2907,  ...,  -70.2905,  -83.9774,
#           -82.6433],
#         [-133.5234,  -99.7329, -101.3434,  ...,  -71.9435, -107.4889,
#          -104.5345],
#         [ -32.3651,  -63.3869,  -66.6698,  ...,  -68.9337,  -78.3932,
#           -73.4459],
#         ...,
#         [ -95.1191,  -64.7360,  -67.9300,  ...,  -95.9288,  -51.9869,
#           -60.6929],
#         [ -11.1438,  -70.4886,  -74.8638,  ...,  -81.7009,  -92.6767,
#           -83.7101],
#         [ -88.4209,  -58.4257,  -70.2097,  ...,  -70.8094,  -33.7498,
#           -43.8200]], device='cuda:0')
# labels ：
# tensor([ 26,  27,  81, 148, 111, 110,  86,  88, 116, 146, 125,  11,  43,  83,
#           3, 172, 165,   3,  69, 114, 144,  80,  97,   6, 138,  66,  65, 158,
#          87, 100,  52,  70], device='cuda:0')
# loss ：
# tensor(0.9865, device='cuda:0')
# valid_data_j: 1313
# Outputs :
# tensor([[-66.2402, -41.0838, -49.8104,  ..., -57.0808, -25.9186, -32.2352],
#         [-30.5315, -64.4189, -73.8993,  ..., -68.1191, -81.4172, -73.0131],
#         [-44.6744, -35.8183, -45.0998,  ..., -48.5906, -41.8960, -40.8980],
#         ...,
#         [-88.2202, -37.0781, -38.5470,  ..., -31.2192, -50.5361, -41.6907],
#         [-91.0439, -38.8339, -40.7042,  ..., -32.7122, -52.5529, -43.5832],
#         [-71.1625, -33.7637, -33.4858,  ..., -53.5995, -26.4316, -30.9983]],
#        device='cuda:0')
# labels ：
# tensor([ 71,  49,  24, 100, 150,  22,  24, 169, 102,  69,  46, 170,  28,  46,
#         104,  10,  50, 168,  62,  48,  68, 147,  28,   2,  46,  19, 136,  26,
#          28,  17,  17, 111], device='cuda:0')
# loss ：
# tensor(0.4081, device='cuda:0')
# valid_data_j: 1314
# Outputs :
# tensor([[ -94.5526, -136.2961, -131.1546,  ..., -144.4236, -143.4697,
#          -142.2826],
#         [ -53.9069,  -79.3914,  -80.7959,  ...,  -73.3594,  -76.8778,
#           -75.7031],
#         [ -65.1263,  -37.9057,  -34.9918,  ...,  -48.1715,  -37.3624,
#           -39.5679],
#         ...,
#         [ -69.5102,  -49.9603,  -56.3657,  ...,  -55.4706,  -30.4259,
#           -38.4730],
#         [ -73.6960,  -93.7004,  -91.7290,  ...,  -84.8278,  -87.0077,
#           -91.7375],
#         [ -65.5838,  -67.4842,  -63.6542,  ...,  -73.7909,  -63.7525,
#           -68.4103]], device='cuda:0')
# labels ：
# tensor([ 75, 108, 111, 107, 104,  33,  69, 131,  41,   1,  59, 131,  89, 112,
#         114,  23,  65,  33, 145,  82,  49,  80,  12, 153,   6,  96,  22,  25,
#          86,  68,  94,  32], device='cuda:0')
# loss ：
# tensor(0.4627, device='cuda:0')
# valid_data_j: 1315
# Outputs :
# tensor([[ -20.0028,  -77.1528,  -68.2963,  ..., -112.0543,  -91.4334,
#           -88.5562],
#         [ -68.6975,  -85.6960,  -88.9137,  ...,  -98.7836,  -76.2388,
#           -81.0248],
#         [ -47.4193, -126.4828, -113.8710,  ..., -135.2648, -144.8305,
#          -139.3457],
#         ...,
#         [ -24.6452, -101.8473, -102.0052,  ..., -124.9772, -123.5482,
#          -115.2633],
#         [ -61.7756,  -55.7137,  -40.9971,  ...,  -83.9108,  -77.2902,
#           -71.7784],
#         [ -37.8472,  -68.9902,  -79.2437,  ...,  -68.9639,  -82.6208,
#           -74.8766]], device='cuda:0')
# labels ：
# tensor([145,  73, 140, 167,   2,  34, 121,  14, 172,  75, 110,  90,  23,  84,
#         148, 168,   3,  39,  25,  64,  63,  41,  93,  96,  94,  52,  13, 128,
#         150,  53,   8,  49], device='cuda:0')
# loss ：
# tensor(0.6933, device='cuda:0')
# valid_data_j: 1316
# Outputs :
# tensor([[-65.6881,  -3.9222,  -6.9630,  ..., -23.0352,  -0.7558,  -0.7499],
#         [-37.3444, -89.4994, -89.6250,  ..., -99.7617, -99.3921, -94.2015],
#         [-95.4562, -86.5664, -90.1194,  ..., -84.8753, -65.7083, -75.8726],
#         ...,
#         [-43.4650, -36.4822, -45.8570,  ..., -53.1545, -46.7853, -44.1532],
#         [-60.2624, -79.6261, -78.7634,  ..., -81.7280, -85.9880, -85.1487],
#         [-16.0816, -53.9327, -48.5412,  ..., -95.4120, -65.0634, -65.4202]],
#        device='cuda:0')
# labels ：
# tensor([172,  54,  92, 133,   7,  12,  55,  88,  13, 143, 134,  37,  31,  28,
#          66,  15,  64,  42, 111, 109,  71, 105, 155,  44, 159,  66,  96,  89,
#         143,  23,  76,  33], device='cuda:0')
# loss ：
# tensor(0.9061, device='cuda:0')
# valid_data_j: 1317
# Outputs :
# tensor([[ -95.1191,  -64.7360,  -67.9300,  ...,  -95.9288,  -51.9869,
#           -60.6929],
#         [ -75.5812,  -71.2691,  -70.7747,  ..., -100.9126,  -59.2442,
#           -66.1054],
#         [-100.2937,  -92.3564,  -92.1140,  ...,  -54.4135, -108.0864,
#           -98.8042],
#         ...,
#         [ -72.5197,  -80.7916,  -84.6543,  ...,  -51.9082,  -92.1986,
#           -85.4522],
#         [  -4.0191,  -60.5700,  -52.8821,  ...,  -98.2427,  -80.3709,
#           -76.6694],
#         [-113.1298, -155.3753, -153.7350,  ..., -160.5300, -152.2603,
#          -153.9509]], device='cuda:0')
# labels ：
# tensor([100,  90, 125,  82, 138,  76, 132, 153, 148, 104,  58,  33, 144,  39,
#         124, 126, 113,  76,  14, 118, 143,  34,   2,  44,  90,  11,  84, 167,
#          65, 129,  11,  74], device='cuda:0')
# loss ：
# tensor(0.5701, device='cuda:0')
# valid_data_j: 1318
# Outputs :
# tensor([[ -45.7038, -116.1142, -108.9126, -110.2406, -108.6139, -110.6282,
#          -110.9281, -103.4832,  -99.9174,  -90.0920,  -99.9548,  -45.6611,
#          -108.6936, -116.1462, -122.8461, -136.4299, -143.2865, -166.3737,
#          -159.6134, -158.1378, -143.8553, -120.7757,  -64.4308, -119.3304,
#          -100.7156, -112.5456, -122.2791, -122.0686, -104.2343, -118.0774,
#          -101.0771, -112.4769,  -96.8972,  -54.5948,  -81.3384,  -78.9131,
#           -81.7388,  -88.2625,  -68.6409,  -53.1424,  -52.8677,  -93.0466,
#           -76.5988, -106.8466,  -70.2106, -122.0497,  -55.5146,  -90.4731,
#           -75.6501,  -59.9708,  -61.4178,  -39.1749,  -33.8635,  -18.5115,
#            -9.8458,  -70.2170,  -14.6051,   -3.9930,   -0.2778,   -1.5201,
#            -5.2283,  -11.7941,  -14.0158,  -20.0250,  -22.1108,  -28.9825,
#           -56.7025,  -44.6098,  -68.4219,  -81.9826,  -69.0017,  -68.4802,
#           -46.7954,  -33.9046,  -31.4294,  -35.3209,  -62.6130,  -72.5287,
#           -53.7971,  -62.9128,  -63.5672,  -71.3896,  -69.7385,  -74.7067,
#           -76.4274,  -82.2585,  -84.8173,  -85.0551,  -42.2022,  -92.3453,
#           -69.7959,  -70.5677,  -83.2409,  -73.5819,  -82.9179,  -82.9883,
#           -90.3038, -103.6915, -117.5077, -107.9878, -102.2748,  -94.1797,
#          -105.6786, -106.8302,  -89.2333,  -72.4955,  -56.0741,  -36.8231,
#           -27.1398,  -20.6013,  -23.7035, -101.9619,  -30.6878,  -50.6763,
#           -78.9817, -101.2569,  -90.0172, -103.6282, -140.5987, -144.9142,
#          -130.5575, -121.4908, -108.3078, -116.7359, -112.3921, -101.1917,
#          -104.9743, -106.3102,  -91.3121,  -67.1608,  -56.8535,  -33.1912,
#           -38.7385, -132.1892,  -32.6381,  -33.3108,  -31.1695,  -30.1665,
#           -30.1735,  -22.7641,  -27.8438,  -27.4369,  -29.7332,  -25.3740,
#          -133.2560,  -28.2213,  -30.6557,  -51.3690,  -79.1335,  -94.0917,
#           -91.4992,  -85.4830,  -78.2382,  -76.2001,  -74.7630, -120.8637,
#           -59.8864,  -66.4729,  -78.4601,  -82.1955,  -73.2752,  -42.1364,
#           -29.2274,  -44.2931,  -76.3344,  -95.0040, -141.8602,  -99.8430,
#           -96.4838, -129.0689, -134.6597, -126.6378, -122.9974]],
#        device='cuda:0')
# labels ：
# tensor([58], device='cuda:0')
# loss ：
# tensor(0.2778, device='cuda:0')

# %% [markdown]
# 验证集 结果：准确率、误差图像
# -

# %%
history.append([avg_valid_loss, avg_valid_acc])

print("Validation: Loss: {:.4f}, Accuracy: {:.4f}%".format(
    avg_valid_loss, avg_valid_acc*100
))
# print("Validation: MSE: {:.4f}".format( ))

diff = predictions_all - labels_all
conc_all = torch.cat((labels_all,predictions_all,diff),dim=0)

plt.scatter(labels_all[0:50000].cpu(),diff[0:50000].cpu(),s=5)
# plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('labels')
plt.ylabel('diff')
# plt.ylim(0, 1)
# plt.savefig("C:\\Users\\nanolab115\Desktop\\"+"diff1.png")
plt.show()

plt.scatter(labels_all[0:50000].cpu(),predictions_all[0:50000].cpu(),s=5)
# plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('labels')
plt.ylabel('predictions')
# plt.ylim(0, 1)
# plt.savefig("C:\\Users\\nanolab115\Desktop\\"+"diff1.png")
plt.show()
# Out:
# Validation: Loss: 0.6524, Accuracy: 81.3216%

# %% [markdown]
# 测试组：用未训练的 0104-2组 进行测试
# -

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

cudnn.benchmark = True
plt.ion()   # interactive mode

# Data augmentation and normalization for training
# Just normalization for validation
image_transforms  = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees = 45),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# dataset = 'E:\gmd_data\microsphere2_dataAugmented'
dataset = 'E:\gmd_data\GMD_0104_2_DATA' # 测试集 0104-2
# dataset = 'E:\gmd_data\GMD_0104_3_DATA' # 测试集 0104-3
# dataset = 'E:\gmd_data\\fangdai_MixTest' # 防呆测试 0104-2-3混合
# dataset = 'E:\gmd_data\GMD_0104_2_DATA_TEST' # 测试集 0104-2 50-8650 照明测试

# train_directory = os.path.join(dataset, 'train')
valid_directory = os.path.join(dataset, 'valid')

batch_size = 32
# num_classes = 173
# class Datset():
#     def __getitem(self,index):
        
#         return image_torch
#     def __len__(self):
#         pass

# data = {
#     # 'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),
#     'valid':Datset(root=valid_directory, transform=image_transforms['valid'])

# }
data = {
    # 'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),
    'valid': datasets.ImageFolder(root=valid_directory, transform=image_transforms['valid'])

}



# train_data_size = len(data['train'])
valid_data_size = len(data['valid'])

# train_data = DataLoader(data['train'], batch_size=batch_size, shuffle=True)
valid_data = DataLoader(data['valid'], batch_size=batch_size, shuffle=True)

print("Validation: valid_data_size: {:.4f}".format(
    valid_data_size
))


# 导入模型 将验证集和真值对比图画出来
dataset = 'E:\gmd_data\microsphere2_dataAugmented'
model38 = torch.load( dataset+'/models/'+'model_38.pt')
for param in model38.parameters():
    param.requires_grad = False
model38 = model38.to('cuda:0')
loss_function = nn.NLLLoss()



device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
history = []
best_acc = 0.0
best_epoch = 0


valid_loss = 0.0
valid_acc = 0.0

predictions_all = torch.tensor([]).to(device)
labels_all = torch.tensor([]).to(device)

with torch.no_grad():
    model38.eval()
    for j, (inputs, labels) in enumerate(valid_data):
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model38(inputs)

        loss = loss_function(outputs, labels)
        # print("valid_data_j: {}".format(j))
        # print("Outputs : ")
        # print(outputs)
        # print("labels ：")
        # print(labels)
        # print("loss ：")
        # print(loss)

        valid_loss += loss.item() * inputs.size(0)

        ret, predictions = torch.max(outputs.data, 1)

        predictions_all = torch.cat((predictions_all,predictions),dim=0)
        labels_all = torch.cat((labels_all,labels),dim=0)

        correct_counts = predictions.eq(labels.data.view_as(predictions))

        acc = torch.mean(correct_counts.type(torch.FloatTensor))

        valid_acc += acc.item() * inputs.size(0)

avg_valid_loss = valid_loss/valid_data_size
avg_valid_acc = valid_acc/valid_data_size

avg_valid_loss = valid_loss/valid_data_size
avg_valid_acc = valid_acc/valid_data_size

# plot
history.append([avg_valid_loss, avg_valid_acc])

print("Validation: Loss: {:.4f}, Accuracy: {:.4f}%".format(
    avg_valid_loss, avg_valid_acc*100
))
# print("Validation: MSE: {:.4f}".format( ))

diff = predictions_all - labels_all
conc_all = torch.cat((labels_all,predictions_all,diff),dim=0)

plt.scatter(labels_all[0:50000].cpu(),diff[0:50000].cpu(),s=5)
# plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('labels')
plt.ylabel('diff')
# plt.ylim(0, 1)
# plt.savefig("C:\\Users\\nanolab115\Desktop\\"+"diff1.png")
plt.show()

plt.scatter(labels_all.cpu(),predictions_all.cpu(),s=5)
# plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('labels')
plt.ylabel('predictions')
# plt.ylim(0, 1)
# plt.savefig("C:\\Users\\nanolab115\Desktop\\"+"diff1.png")
plt.show()
# Out:
# Validation: valid_data_size: 1060.0000
# Validation: Loss: 931.1962, Accuracy: 0.0000%

# %% [markdown]
# Test Command
# ------

# %%
value,num = torch.max(outputs, 1)
print("num:",num,"value:",value)
# Out:
# num: tensor([168], device='cuda:0') value: tensor([-0.0022], device='cuda:0')

# %%
print("outputs:",outputs)

outputs1 = torch.cat((outputs,outputs),dim=0)
print("outputs1:",outputs1)

value,num = torch.max(outputs1, 1)
print("num:",num,"value:",value)
# Out:
# outputs: tensor([[-4.9504e+01, -5.5556e+01, -6.4833e+01, -7.4970e+01, -8.5962e+01,
#          -8.8016e+01, -9.6433e+01, -1.0100e+02, -9.9389e+01, -1.0482e+02,
#          -1.0389e+02, -4.7640e+01, -8.3659e+01, -7.6490e+01, -6.6539e+01,
#          -6.6105e+01, -6.2998e+01, -6.6530e+01, -6.1330e+01, -5.6204e+01,
#          -3.3516e+01, -3.4015e+01, -2.9832e+01, -5.1219e+01, -5.1118e+01,
#          -7.7792e+01, -8.0729e+01, -8.7210e+01, -7.7605e+01, -1.0523e+02,
#          -9.8735e+01, -1.0985e+02, -1.2003e+02, -4.8393e+01, -1.2292e+02,
#          -1.2874e+02, -1.2656e+02, -1.1117e+02, -1.1285e+02, -1.0200e+02,
#          -9.0714e+01, -8.9426e+01, -7.5569e+01, -6.9013e+01, -4.4566e+01,
#          -5.4173e+01, -5.0531e+01, -4.3763e+01, -4.0917e+01, -4.7471e+01,
#          -4.0777e+01, -4.0884e+01, -4.5677e+01, -6.0832e+01, -6.6128e+01,
#          -3.3768e+01, -6.3326e+01, -8.3918e+01, -8.3963e+01, -7.3704e+01,
#          -1.0347e+02, -9.3055e+01, -1.0524e+02, -1.1130e+02, -1.0509e+02,
#          -1.0142e+02, -6.6610e+01, -9.6827e+01, -1.1382e+02, -9.0097e+01,
#          -5.1047e+01, -7.6856e+01, -1.0575e+02, -9.4665e+01, -8.4263e+01,
#          -6.5992e+01, -5.3295e+01, -5.8472e+01, -4.7509e+01, -5.7496e+01,
#          -6.0891e+01, -5.0808e+01, -4.7159e+01, -7.8419e+01, -9.5157e+01,
#          -8.1005e+01, -1.1044e+02, -1.1190e+02, -5.0850e+01, -6.7190e+01,
#          -1.0783e+02, -9.9765e+01, -1.1036e+02, -9.6552e+01, -9.4117e+01,
#          -8.4111e+01, -4.7208e+01, -7.0809e+01, -6.8591e+01, -8.7595e+01,
#          -6.0792e+01, -9.9449e+01, -9.7951e+01, -7.4775e+01, -6.9963e+01,
#          -4.8413e+01, -7.7606e+01, -7.7363e+01, -7.3048e+01, -4.8639e+01,
#          -6.4123e+01, -5.2178e+01, -4.1367e+01, -3.3251e+01, -2.3735e+01,
#          -1.9802e+01, -2.2401e+01, -2.5856e+01, -2.5576e+01, -3.4785e+01,
#          -5.1293e+01, -5.6569e+01, -5.0932e+01, -5.8218e+01, -6.9542e+01,
#          -6.0571e+01, -3.3236e+01, -2.5751e+01, -1.8430e+01, -1.7330e+01,
#          -1.9362e+01, -3.0725e+01, -3.9755e+01, -4.5791e+01, -5.9570e+01,
#          -7.3055e+01, -7.3024e+01, -8.0604e+01, -9.8530e+01, -8.8274e+01,
#          -9.9293e+01, -9.9565e+01, -1.2586e+02, -1.1402e+02, -3.7030e+01,
#          -1.1206e+02, -1.1050e+02, -1.0881e+02, -9.7738e+01, -9.6298e+01,
#          -8.9559e+01, -9.1399e+01, -1.0981e+02, -1.0503e+02, -8.0258e+01,
#          -4.4443e+01, -7.4228e+01, -6.5347e+01, -4.7284e+01, -4.2370e+01,
#          -2.8603e+01, -3.6405e+01, -2.7950e+01, -1.4470e+01, -1.5340e+01,
#          -1.3862e+01, -5.4725e+01, -1.0313e+01, -2.2178e-03, -6.1282e+00,
#          -1.9063e+01, -6.4408e+01, -5.7527e+01]], device='cuda:0')
# outputs1: tensor([[-4.9504e+01, -5.5556e+01, -6.4833e+01, -7.4970e+01, -8.5962e+01,
#          -8.8016e+01, -9.6433e+01, -1.0100e+02, -9.9389e+01, -1.0482e+02,
#          -1.0389e+02, -4.7640e+01, -8.3659e+01, -7.6490e+01, -6.6539e+01,
#          -6.6105e+01, -6.2998e+01, -6.6530e+01, -6.1330e+01, -5.6204e+01,
#          -3.3516e+01, -3.4015e+01, -2.9832e+01, -5.1219e+01, -5.1118e+01,
#          -7.7792e+01, -8.0729e+01, -8.7210e+01, -7.7605e+01, -1.0523e+02,
#          -9.8735e+01, -1.0985e+02, -1.2003e+02, -4.8393e+01, -1.2292e+02,
#          -1.2874e+02, -1.2656e+02, -1.1117e+02, -1.1285e+02, -1.0200e+02,
#          -9.0714e+01, -8.9426e+01, -7.5569e+01, -6.9013e+01, -4.4566e+01,
#          -5.4173e+01, -5.0531e+01, -4.3763e+01, -4.0917e+01, -4.7471e+01,
#          -4.0777e+01, -4.0884e+01, -4.5677e+01, -6.0832e+01, -6.6128e+01,
#          -3.3768e+01, -6.3326e+01, -8.3918e+01, -8.3963e+01, -7.3704e+01,
#          -1.0347e+02, -9.3055e+01, -1.0524e+02, -1.1130e+02, -1.0509e+02,
#          -1.0142e+02, -6.6610e+01, -9.6827e+01, -1.1382e+02, -9.0097e+01,
#          -5.1047e+01, -7.6856e+01, -1.0575e+02, -9.4665e+01, -8.4263e+01,
#          -6.5992e+01, -5.3295e+01, -5.8472e+01, -4.7509e+01, -5.7496e+01,
#          -6.0891e+01, -5.0808e+01, -4.7159e+01, -7.8419e+01, -9.5157e+01,
#          -8.1005e+01, -1.1044e+02, -1.1190e+02, -5.0850e+01, -6.7190e+01,
#          -1.0783e+02, -9.9765e+01, -1.1036e+02, -9.6552e+01, -9.4117e+01,
#          -8.4111e+01, -4.7208e+01, -7.0809e+01, -6.8591e+01, -8.7595e+01,
#          -6.0792e+01, -9.9449e+01, -9.7951e+01, -7.4775e+01, -6.9963e+01,
#          -4.8413e+01, -7.7606e+01, -7.7363e+01, -7.3048e+01, -4.8639e+01,
#          -6.4123e+01, -5.2178e+01, -4.1367e+01, -3.3251e+01, -2.3735e+01,
#          -1.9802e+01, -2.2401e+01, -2.5856e+01, -2.5576e+01, -3.4785e+01,
#          -5.1293e+01, -5.6569e+01, -5.0932e+01, -5.8218e+01, -6.9542e+01,
#          -6.0571e+01, -3.3236e+01, -2.5751e+01, -1.8430e+01, -1.7330e+01,
#          -1.9362e+01, -3.0725e+01, -3.9755e+01, -4.5791e+01, -5.9570e+01,
#          -7.3055e+01, -7.3024e+01, -8.0604e+01, -9.8530e+01, -8.8274e+01,
#          -9.9293e+01, -9.9565e+01, -1.2586e+02, -1.1402e+02, -3.7030e+01,
#          -1.1206e+02, -1.1050e+02, -1.0881e+02, -9.7738e+01, -9.6298e+01,
#          -8.9559e+01, -9.1399e+01, -1.0981e+02, -1.0503e+02, -8.0258e+01,
#          -4.4443e+01, -7.4228e+01, -6.5347e+01, -4.7284e+01, -4.2370e+01,
#          -2.8603e+01, -3.6405e+01, -2.7950e+01, -1.4470e+01, -1.5340e+01,
#          -1.3862e+01, -5.4725e+01, -1.0313e+01, -2.2178e-03, -6.1282e+00,
#          -1.9063e+01, -6.4408e+01, -5.7527e+01],
#         [-4.9504e+01, -5.5556e+01, -6.4833e+01, -7.4970e+01, -8.5962e+01,
#          -8.8016e+01, -9.6433e+01, -1.0100e+02, -9.9389e+01, -1.0482e+02,
#          -1.0389e+02, -4.7640e+01, -8.3659e+01, -7.6490e+01, -6.6539e+01,
#          -6.6105e+01, -6.2998e+01, -6.6530e+01, -6.1330e+01, -5.6204e+01,
#          -3.3516e+01, -3.4015e+01, -2.9832e+01, -5.1219e+01, -5.1118e+01,
#          -7.7792e+01, -8.0729e+01, -8.7210e+01, -7.7605e+01, -1.0523e+02,
#          -9.8735e+01, -1.0985e+02, -1.2003e+02, -4.8393e+01, -1.2292e+02,
#          -1.2874e+02, -1.2656e+02, -1.1117e+02, -1.1285e+02, -1.0200e+02,
#          -9.0714e+01, -8.9426e+01, -7.5569e+01, -6.9013e+01, -4.4566e+01,
#          -5.4173e+01, -5.0531e+01, -4.3763e+01, -4.0917e+01, -4.7471e+01,
#          -4.0777e+01, -4.0884e+01, -4.5677e+01, -6.0832e+01, -6.6128e+01,
#          -3.3768e+01, -6.3326e+01, -8.3918e+01, -8.3963e+01, -7.3704e+01,
#          -1.0347e+02, -9.3055e+01, -1.0524e+02, -1.1130e+02, -1.0509e+02,
#          -1.0142e+02, -6.6610e+01, -9.6827e+01, -1.1382e+02, -9.0097e+01,
#          -5.1047e+01, -7.6856e+01, -1.0575e+02, -9.4665e+01, -8.4263e+01,
#          -6.5992e+01, -5.3295e+01, -5.8472e+01, -4.7509e+01, -5.7496e+01,
#          -6.0891e+01, -5.0808e+01, -4.7159e+01, -7.8419e+01, -9.5157e+01,
#          -8.1005e+01, -1.1044e+02, -1.1190e+02, -5.0850e+01, -6.7190e+01,
#          -1.0783e+02, -9.9765e+01, -1.1036e+02, -9.6552e+01, -9.4117e+01,
#          -8.4111e+01, -4.7208e+01, -7.0809e+01, -6.8591e+01, -8.7595e+01,
#          -6.0792e+01, -9.9449e+01, -9.7951e+01, -7.4775e+01, -6.9963e+01,
#          -4.8413e+01, -7.7606e+01, -7.7363e+01, -7.3048e+01, -4.8639e+01,
#          -6.4123e+01, -5.2178e+01, -4.1367e+01, -3.3251e+01, -2.3735e+01,
#          -1.9802e+01, -2.2401e+01, -2.5856e+01, -2.5576e+01, -3.4785e+01,
#          -5.1293e+01, -5.6569e+01, -5.0932e+01, -5.8218e+01, -6.9542e+01,
#          -6.0571e+01, -3.3236e+01, -2.5751e+01, -1.8430e+01, -1.7330e+01,
#          -1.9362e+01, -3.0725e+01, -3.9755e+01, -4.5791e+01, -5.9570e+01,
#          -7.3055e+01, -7.3024e+01, -8.0604e+01, -9.8530e+01, -8.8274e+01,
#          -9.9293e+01, -9.9565e+01, -1.2586e+02, -1.1402e+02, -3.7030e+01,
#          -1.1206e+02, -1.1050e+02, -1.0881e+02, -9.7738e+01, -9.6298e+01,
#          -8.9559e+01, -9.1399e+01, -1.0981e+02, -1.0503e+02, -8.0258e+01,
#          -4.4443e+01, -7.4228e+01, -6.5347e+01, -4.7284e+01, -4.2370e+01,
#          -2.8603e+01, -3.6405e+01, -2.7950e+01, -1.4470e+01, -1.5340e+01,
#          -1.3862e+01, -5.4725e+01, -1.0313e+01, -2.2178e-03, -6.1282e+00,
#          -1.9063e+01, -6.4408e+01, -5.7527e+01]], device='cuda:0')
# num: tensor([168, 168], device='cuda:0') value: tensor([-0.0022, -0.0022], device='cuda:0')

# %%
num2 = torch.tensor([]).to(device)
num1 = torch.cat((num2,num),dim=0)

# %%
print('C:\\Users\\nanolab115\Desktop\\'+'diff1.png')
# Out:
# C:\Users\nanolab115\Desktop\diff1.png
