# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %matplotlib inline

# %% [markdown]
# Transfer Learning for Computer Vision Tutorial
# ==============================================
#
# These two major transfer learning scenarios look as follows:
#
# -  **Finetuning the convnet**: Instead of random initialization, we
#    initialize the network with a pretrained network, like the one that is
#    trained on imagenet 1000 dataset. Rest of the training looks as
#    usual.
# -  **ConvNet as fixed feature extractor**: Here, we will freeze the weights
#    for all of the network except that of the final fully connected
#    layer. This last fully connected layer is replaced with a new one
#    with random weights and only this layer is trained.

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# Load Data
# ---------
#
# We will use torchvision and torch.utils.data packages for loading the
# data.
#
# The problem we're going to solve today is to train a model to classify
# **ants** and **bees**. We have about 120 training images each for ants and bees.
# There are 75 validation images for each class. Usually, this is a very
# small dataset to generalize upon, if trained from scratch. Since we
# are using transfer learning, we should be able to generalize reasonably
# well.
#
# This dataset is a very small subset of imagenet.
#
# .. Note ::
#    Download the data from
#    `here <https://download.pytorch.org/tutorial/hymenoptera_data.zip>`_
#    and extract it to the current directory.

# %%
# Data augmentation and normalization for training
# Just normalization for validation
image_transforms  = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees = 45),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

dataset = 'E:\gmd_data\microsphere2_dataAugmented'
train_directory = os.path.join(dataset, 'train')
valid_directory = os.path.join(dataset, 'valid')

batch_size = 16
# num_classes = 173

data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),
    'valid': datasets.ImageFolder(root=valid_directory, transform=image_transforms['valid'])

}


train_data_size = len(data['train'])
valid_data_size = len(data['valid'])

train_data = DataLoader(data['train'], batch_size=batch_size, shuffle=True)
valid_data = DataLoader(data['valid'], batch_size=batch_size, shuffle=True)

print(train_data_size, valid_data_size)
# Out:
# 168537 42177

# %% [markdown]
# 迁移学习
# ---------
#
#
# 这里使用ResNet-50的预训练模型。

# %%
resnet50 = models.resnet50(pretrained=True)

for param in resnet50.parameters():
    param.requires_grad = True

fc_inputs = resnet50.fc.in_features
resnet50.fc = nn.Sequential(
    nn.Linear(fc_inputs, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256,128),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(128, 64),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(64, 173),
    nn.LogSoftmax(dim = 1)


)
resnet50 = resnet50.to('cuda:0')
loss_func = nn.NLLLoss()
optimizer = optim.AdamW(resnet50.parameters(),lr=1e-4)

# %% [markdown]
# Training the model
# ------------------
#
# Now, let's write a general function to train a model. Here, we will
# illustrate:
#
# -  Scheduling the learning rate
# -  Saving the best model
#
# In the following, parameter ``scheduler`` is an LR scheduler object from
# ``torch.optim.lr_scheduler``.

# %%
def train_and_valid(model, loss_function, optimizer, epochs=25):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    history = []
    best_acc = 0.0
    best_epoch = 0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))

        model.train()

        train_loss = 0.0
        train_acc = 0.0
        valid_loss = 0.0
        valid_acc = 0.0

        for i, (inputs, labels) in enumerate(train_data):
            inputs = inputs.to(device)
            labels = labels.to(device)

            #因为这里梯度是累加的，所以每次记得清零
            optimizer.zero_grad()

            outputs = model(inputs)

            loss = loss_function(outputs, labels)

            loss.backward()

            optimizer.step()

            train_loss += loss.item() * inputs.size(0)

            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))

            acc = torch.mean(correct_counts.type(torch.FloatTensor))

            train_acc += acc.item() * inputs.size(0)

        with torch.no_grad():
            model.eval()

            for j, (inputs, labels) in enumerate(valid_data):
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)

                loss = loss_function(outputs, labels)

                valid_loss += loss.item() * inputs.size(0)

                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                valid_acc += acc.item() * inputs.size(0)

        avg_train_loss = train_loss/train_data_size
        avg_train_acc = train_acc/train_data_size

        avg_valid_loss = valid_loss/valid_data_size
        avg_valid_acc = valid_acc/valid_data_size

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])

        if best_acc < avg_valid_acc:
            best_acc = avg_valid_acc
            best_epoch = epoch + 1

        epoch_end = time.time()

        print("Epoch: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation: Loss: {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(
            epoch+1, avg_valid_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start
        ))
        print("Best Accuracy for validation : {:.4f} at epoch {:03d}".format(best_acc, best_epoch))

        torch.save(model, dataset+'/models/'+'model_'+str(epoch+1)+'.pt')
        if epoch + 1 - 100 >  best_epoch:
            break
    return model, history

# %%
num_epochs = 3000
trained_model, history = train_and_valid(resnet50, loss_func, optimizer, num_epochs)
torch.save(history, 'models/'+dataset+'_history.pt')
# Out:
# Epoch: 1/3000
# Epoch: 001, Training: Loss: 2.7203, Accuracy: 4.7450%,
# 		Validation: Loss: 2.7203, Accuracy: 16.4497%, Time: 7685.7318s
# Best Accuracy for validation : 0.1645 at epoch 001
# Epoch: 2/3000
# Epoch: 002, Training: Loss: 2.0987, Accuracy: 12.0359%,
# 		Validation: Loss: 2.0987, Accuracy: 23.6171%, Time: 7545.2356s
# Best Accuracy for validation : 0.2362 at epoch 002
# Epoch: 3/3000
# Epoch: 003, Training: Loss: 1.8168, Accuracy: 17.1630%,
# 		Validation: Loss: 1.8168, Accuracy: 28.6791%, Time: 7537.4531s
# Best Accuracy for validation : 0.2868 at epoch 003
# Epoch: 4/3000
# Epoch: 004, Training: Loss: 1.6571, Accuracy: 21.5537%,
# 		Validation: Loss: 1.6571, Accuracy: 35.2633%, Time: 7579.0966s
# Best Accuracy for validation : 0.3526 at epoch 004
# Epoch: 5/3000
# Epoch: 005, Training: Loss: 1.6023, Accuracy: 24.5881%,
# 		Validation: Loss: 1.6023, Accuracy: 30.8415%, Time: 7515.4545s
# Epoch: 030, Training: Loss: 1.7651, Accuracy: 60.1067%,
# 		Validation: Loss: 1.7651, Accuracy: 44.9344%, Time: 7284.8534s
# Best Accuracy for validation : 0.5834 at epoch 029
# Epoch: 31/3000
# Epoch: 031, Training: Loss: 1.2240, Accuracy: 61.0655%,
# 		Validation: Loss: 1.2240, Accuracy: 56.5118%, Time: 7482.0714s
# Best Accuracy for validation : 0.5834 at epoch 029
# Epoch: 32/3000
# Epoch: 032, Training: Loss: 1.1769, Accuracy: 62.4219%,
# 		Validation: Loss: 1.1769, Accuracy: 56.5308%, Time: 7260.5326s
# Best Accuracy for validation : 0.5834 at epoch 029
# Epoch: 33/3000
# Epoch: 033, Training: Loss: 1.2309, Accuracy: 63.4282%,
# 		Validation: Loss: 1.2309, Accuracy: 60.7843%, Time: 7311.3197s
# Best Accuracy for validation : 0.6078 at epoch 033
# Epoch: 34/3000
# Epoch: 034, Training: Loss: 1.0751, Accuracy: 64.8730%,
# 		Validation: Loss: 1.0751, Accuracy: 59.2835%, Time: 8552.2313s
# Best Accuracy for validation : 0.6078 at epoch 033
# Epoch: 35/3000
# Epoch: 035, Training: Loss: 1.1309, Accuracy: 65.9440%,
# 		Validation: Loss: 1.1309, Accuracy: 58.5106%, Time: 9025.4856s
# Best Accuracy for validation : 0.6078 at epoch 033
# Epoch: 36/3000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\NANOLA~1\AppData\Local\Temp/ipykernel_8592/2532451553.py in <module>
#       1 num_epochs = 3000
# ----> 2 trained_model, history = train_and_valid(resnet50, loss_func, optimizer, num_epochs)
#       3 torch.save(history, 'models/'+dataset+'_history.pt')
#       4
#
# C:\Users\NANOLA~1\AppData\Local\Temp/ipykernel_8592/4243363850.py in train_and_valid(model, loss_function, optimizer, epochs)
#      16         valid_acc = 0.0
#      17
# ---> 18         for i, (inputs, labels) in enumerate(train_data):
#      19             inputs = inputs.to(device)
#      20             labels = labels.to(device)
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     568     def _next_data(self):
#     569         index = self._next_index()  # may raise StopIteration
# --> 570         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571         if self._pin_memory:
#     572             data = _utils.pin_memory.pin_memory(data)
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torchvision\datasets\folder.py in __getitem__(self, index)
#     228         """
#     229         path, target = self.samples[index]
# --> 230         sample = self.loader(path)
#     231         if self.transform is not None:
#     232             sample = self.transform(sample)
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torchvision\datasets\folder.py in default_loader(path)
#     267         return accimage_loader(path)
#     268     else:
# --> 269         return pil_loader(path)
#     270
#     271
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torchvision\datasets\folder.py in pil_loader(path)
#     247     with open(path, "rb") as f:
#     248         img = Image.open(f)
# --> 249         return img.convert("RGB")
#     250
#     251
#
# D:\anacondagmd\envs\d2l\lib\site-packages\PIL\Image.py in convert(self, mode, matrix, dither, palette, colors)
#     887         """
#     888
# --> 889         self.load()
#     890
#     891         has_transparency = self.info.get("transparency") is not None
#
# D:\anacondagmd\envs\d2l\lib\site-packages\PIL\ImageFile.py in load(self)
#     233                         while True:
#     234                             try:
# --> 235                                 s = read(self.decodermaxblock)
#     236                             except (IndexError, struct.error) as e:
#     237                                 # truncated png/gif
#
# KeyboardInterrupt:

# %%
history = np.array(history)
plt.plot(history[:, 0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0, 1)
plt.savefig(dataset+'_loss_curve.png')
plt.show()

plt.plot(history[:, 2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.savefig(dataset+'_accuracy_curve.png')
plt.show()

# %%
print(dataset+'\models\\'+'model_'+str(1)+'.pt')

# %%
print( dataset+'/models/'+'model_'+str(1)+'.pt')
