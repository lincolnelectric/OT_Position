# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %matplotlib inline

# %% [markdown]
# Transfer Learning for Computer Vision Tutorial
# ==============================================
#
# These two major transfer learning scenarios look as follows:
#
# -  **Finetuning the convnet**: Instead of random initialization, we
#    initialize the network with a pretrained network, like the one that is
#    trained on imagenet 1000 dataset. Rest of the training looks as
#    usual.
# -  **ConvNet as fixed feature extractor**: Here, we will freeze the weights
#    for all of the network except that of the final fully connected
#    layer. This last fully connected layer is replaced with a new one
#    with random weights and only this layer is trained.

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# Load Data
# ---------
#
# We will use torchvision and torch.utils.data packages for loading the
# data.
#
# The problem we're going to solve today is to train a model to classify
# **ants** and **bees**. We have about 120 training images each for ants and bees.
# There are 75 validation images for each class. Usually, this is a very
# small dataset to generalize upon, if trained from scratch. Since we
# are using transfer learning, we should be able to generalize reasonably
# well.
#
# This dataset is a very small subset of imagenet.
#
# .. Note ::
#    Download the data from
#    `here <https://download.pytorch.org/tutorial/hymenoptera_data.zip>`_
#    and extract it to the current directory.

# %%
# Data augmentation and normalization for training
# Just normalization for validation
image_transforms  = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees = 45),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

dataset = 'E:\gmd_data\microsphere2_dataAugmented'
train_directory = os.path.join(dataset, 'train')
valid_directory = os.path.join(dataset, 'valid')

batch_size = 32
# num_classes = 173

data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),
    'valid': datasets.ImageFolder(root=valid_directory, transform=image_transforms['valid'])

}


train_data_size = len(data['train'])
valid_data_size = len(data['valid'])

train_data = DataLoader(data['train'], batch_size=batch_size, shuffle=True)
valid_data = DataLoader(data['valid'], batch_size=batch_size, shuffle=True)

print(train_data_size, valid_data_size)
# Out:
# 168537 42177

# %% [markdown]
# 迁移学习
# ---------
#
#
# 这里使用ResNet-50的预训练模型。

# %%
resnet50 = models.resnet50(pretrained=True)

for param in resnet50.parameters():
    param.requires_grad = True

fc_inputs = resnet50.fc.in_features
resnet50.fc = nn.Sequential(
    nn.Linear(fc_inputs, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(128, 64),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(64, 173),
    nn.LogSoftmax(dim = 1)


)
resnet50 = resnet50.to('cuda:0')
loss_func = nn.NLLLoss()
# optimizer = optim.AdamW(resnet50.parameters(),lr=1e-4)

# %% [markdown]
# Training the model
# ------------------
#
# Now, let's write a general function to train a model. Here, we will
# illustrate:
#
# -  Scheduling the learning rate
# -  Saving the best model
#
# In the following, parameter ``scheduler`` is an LR scheduler object from
# ``torch.optim.lr_scheduler``.

# %%
def train_and_valid(model, loss_function, epochs=25):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    history = []
    best_acc = 0.0
    best_epoch = 0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))

        model.train()

        train_loss = 0.0
        train_acc = 0.0
        valid_loss = 0.0
        valid_acc = 0.0
#         学习率递减
        if epoch <= 10:
            LR = 1e-4;
        elif epoch <= 20:
            LR = 1e-4*0.5;
        elif epoch <= 30:
            LR = 1e-4*0.5*0.5;
        elif epoch <= 40:
            LR = 1e-4*0.5*0.5*0.5;
        else:
            LR = 1e-4*0.5*0.5*0.5*0.5;
        optimizer = optim.AdamW(resnet50.parameters(),lr=LR)

        for i, (inputs, labels) in enumerate(train_data):
            inputs = inputs.to(device)
            labels = labels.to(device)

            #因为这里梯度是累加的，所以每次记得清零
            optimizer.zero_grad()

            outputs = model(inputs)

            loss = loss_function(outputs, labels)

            loss.backward()

            optimizer.step()

            train_loss += loss.item() * inputs.size(0)

            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))

            acc = torch.mean(correct_counts.type(torch.FloatTensor))

            train_acc += acc.item() * inputs.size(0)

        with torch.no_grad():
            model.eval()

            for j, (inputs, labels) in enumerate(valid_data):
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)

                loss = loss_function(outputs, labels)

                valid_loss += loss.item() * inputs.size(0)

                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                valid_acc += acc.item() * inputs.size(0)

        avg_train_loss = train_loss/train_data_size
        avg_train_acc = train_acc/train_data_size

        avg_valid_loss = valid_loss/valid_data_size
        avg_valid_acc = valid_acc/valid_data_size

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])

        if best_acc < avg_valid_acc:
            best_acc = avg_valid_acc
            best_epoch = epoch + 1

        epoch_end = time.time()

        print("Epoch: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation: Loss: {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(
            epoch+1, avg_valid_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start
        ))
        print("Best Accuracy for validation : {:.4f} at epoch {:03d}".format(best_acc, best_epoch))

        torch.save(model, dataset+'/models/'+'model_'+str(epoch+1)+'.pt')
    return model, history

# %%
num_epochs = 3000
trained_model, history = train_and_valid(resnet50, loss_func, num_epochs)
torch.save(history, 'models/'+dataset+'_history.pt')
# Out:
# Epoch: 1/3000
# Epoch: 1/3000
# Epoch: 001, Training: Loss: 2.7878, Accuracy: 4.7230%,
# 		Validation: Loss: 2.7878, Accuracy: 15.0414%, Time: 8412.3150s
# Best Accuracy for validation : 0.1504 at epoch 001
# Epoch: 001, Training: Loss: 2.7878, Accuracy: 4.7230%,
# 		Validation: Loss: 2.7878, Accuracy: 15.0414%, Time: 8412.3150s
# Best Accuracy for validation : 0.1504 at epoch 001
# Epoch: 2/3000
# Epoch: 2/3000
# Epoch: 002, Training: Loss: 2.2598, Accuracy: 13.3917%,
# 		Validation: Loss: 2.2598, Accuracy: 18.2991%, Time: 8981.4649s
# Best Accuracy for validation : 0.1830 at epoch 002
# Epoch: 002, Training: Loss: 2.2598, Accuracy: 13.3917%,
# 		Validation: Loss: 2.2598, Accuracy: 18.2991%, Time: 8981.4649s
# Best Accuracy for validation : 0.1830 at epoch 002
# Epoch: 3/3000
# Epoch: 3/3000
# Epoch: 003, Training: Loss: 1.6855, Accuracy: 20.6530%,
# 		Validation: Loss: 1.6855, Accuracy: 30.5095%, Time: 8811.8746s
# Best Accuracy for validation : 0.3051 at epoch 003
# Epoch: 003, Training: Loss: 1.6855, Accuracy: 20.6530%,
# 		Validation: Loss: 1.6855, Accuracy: 30.5095%, Time: 8811.8746s
# Best Accuracy for validation : 0.3051 at epoch 003
# Epoch: 4/3000
# Epoch: 4/3000
# Epoch: 004, Training: Loss: 1.4812, Accuracy: 25.9350%,
# 		Validation: Loss: 1.4812, Accuracy: 38.7130%, Time: 8745.2444s
# Best Accuracy for validation : 0.3871 at epoch 004
# Epoch: 004, Training: Loss: 1.4812, Accuracy: 25.9350%,
# 		Validation: Loss: 1.4812, Accuracy: 38.7130%, Time: 8745.2444s
# Best Accuracy for validation : 0.3871 at epoch 004
# Epoch: 5/3000
# Epoch: 5/3000
# Epoch: 005, Training: Loss: 1.4132, Accuracy: 30.1898%,
# 		Validation: Loss: 1.4132, Accuracy: 39.3508%, Time: 8281.2216s
# Best Accuracy for validation : 0.3935 at epoch 005
# Epoch: 005, Training: Loss: 1.4132, Accuracy: 30.1898%,
# 		Validation: Loss: 1.4132, Accuracy: 39.3508%, Time: 8281.2216s
# Best Accuracy for validation : 0.3935 at epoch 005
# Epoch: 6/3000
# Epoch: 6/3000
# Epoch: 006, Training: Loss: 1.2154, Accuracy: 33.7178%,
# 		Validation: Loss: 1.2154, Accuracy: 52.4504%, Time: 8314.4973s
# Best Accuracy for validation : 0.5245 at epoch 006
# Epoch: 006, Training: Loss: 1.2154, Accuracy: 33.7178%,
# 		Validation: Loss: 1.2154, Accuracy: 52.4504%, Time: 8314.4973s
# Best Accuracy for validation : 0.5245 at epoch 006
# Epoch: 7/3000
# Epoch: 7/3000
# Epoch: 007, Training: Loss: 1.2791, Accuracy: 36.6543%,
# 		Validation: Loss: 1.2791, Accuracy: 38.4878%, Time: 8344.1881s
# Best Accuracy for validation : 0.5245 at epoch 006
# Epoch: 007, Training: Loss: 1.2791, Accuracy: 36.6543%,
# 		Validation: Loss: 1.2791, Accuracy: 38.4878%, Time: 8344.1881s
# Best Accuracy for validation : 0.5245 at epoch 006
# Epoch: 8/3000
# Epoch: 8/3000
# Epoch: 008, Training: Loss: 1.1361, Accuracy: 39.1309%,
# 		Validation: Loss: 1.1361, Accuracy: 54.9209%, Time: 8384.6401s
# Best Accuracy for validation : 0.5492 at epoch 008
# Epoch: 008, Training: Loss: 1.1361, Accuracy: 39.1309%,
# 		Validation: Loss: 1.1361, Accuracy: 54.9209%, Time: 8384.6401s
# Best Accuracy for validation : 0.5492 at epoch 008
# Epoch: 9/3000
# Epoch: 9/3000
# Epoch: 009, Training: Loss: 1.1118, Accuracy: 41.6407%,
# 		Validation: Loss: 1.1118, Accuracy: 55.3382%, Time: 8316.5371s
# Best Accuracy for validation : 0.5534 at epoch 009
# Epoch: 009, Training: Loss: 1.1118, Accuracy: 41.6407%,
# 		Validation: Loss: 1.1118, Accuracy: 55.3382%, Time: 8316.5371s
# Best Accuracy for validation : 0.5534 at epoch 009
# Epoch: 10/3000
# Epoch: 10/3000
# Epoch: 010, Training: Loss: 1.0734, Accuracy: 43.8438%,
# 		Validation: Loss: 1.0734, Accuracy: 56.2653%, Time: 8220.6728s
# Best Accuracy for validation : 0.5627 at epoch 010
# Epoch: 010, Training: Loss: 1.0734, Accuracy: 43.8438%,
# 		Validation: Loss: 1.0734, Accuracy: 56.2653%, Time: 8220.6728s
# Best Accuracy for validation : 0.5627 at epoch 010
# Epoch: 11/3000
# Epoch: 11/3000
# Epoch: 011, Training: Loss: 1.0144, Accuracy: 46.0196%,
# 		Validation: Loss: 1.0144, Accuracy: 57.8989%, Time: 8424.0412s
# Best Accuracy for validation : 0.5790 at epoch 011
# Epoch: 011, Training: Loss: 1.0144, Accuracy: 46.0196%,
# 		Validation: Loss: 1.0144, Accuracy: 57.8989%, Time: 8424.0412s
# Best Accuracy for validation : 0.5790 at epoch 011
# Epoch: 12/3000
# Epoch: 12/3000
# Epoch: 012, Training: Loss: 0.9149, Accuracy: 50.7325%,
# 		Validation: Loss: 0.9149, Accuracy: 66.9180%, Time: 8320.9056s
# Best Accuracy for validation : 0.6692 at epoch 012
# Epoch: 012, Training: Loss: 0.9149, Accuracy: 50.7325%,
# 		Validation: Loss: 0.9149, Accuracy: 66.9180%, Time: 8320.9056s
# Best Accuracy for validation : 0.6692 at epoch 012
# Epoch: 13/3000
# Epoch: 13/3000
# Epoch: 013, Training: Loss: 0.9367, Accuracy: 52.6128%,
# 		Validation: Loss: 0.9367, Accuracy: 65.5215%, Time: 8354.1486s
# Best Accuracy for validation : 0.6692 at epoch 012
# Epoch: 013, Training: Loss: 0.9367, Accuracy: 52.6128%,
# 		Validation: Loss: 0.9367, Accuracy: 65.5215%, Time: 8354.1486s
# Best Accuracy for validation : 0.6692 at epoch 012
# Epoch: 14/3000
# Epoch: 14/3000
# Epoch: 014, Training: Loss: 0.8909, Accuracy: 54.4041%,
# 		Validation: Loss: 0.8909, Accuracy: 68.8954%, Time: 8224.3794s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 014, Training: Loss: 0.8909, Accuracy: 54.4041%,
# 		Validation: Loss: 0.8909, Accuracy: 68.8954%, Time: 8224.3794s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 15/3000
# Epoch: 15/3000
# Epoch: 015, Training: Loss: 0.9422, Accuracy: 55.6566%,
# 		Validation: Loss: 0.9422, Accuracy: 63.6058%, Time: 8413.3526s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 015, Training: Loss: 0.9422, Accuracy: 55.6566%,
# 		Validation: Loss: 0.9422, Accuracy: 63.6058%, Time: 8413.3526s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 16/3000
# Epoch: 16/3000
# Epoch: 016, Training: Loss: 0.8671, Accuracy: 57.3298%,
# 		Validation: Loss: 0.8671, Accuracy: 66.9038%, Time: 8420.2203s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 016, Training: Loss: 0.8671, Accuracy: 57.3298%,
# 		Validation: Loss: 0.8671, Accuracy: 66.9038%, Time: 8420.2203s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 17/3000
# Epoch: 17/3000
# Epoch: 017, Training: Loss: 0.8788, Accuracy: 58.5634%,
# 		Validation: Loss: 0.8788, Accuracy: 67.2570%, Time: 8518.8632s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 017, Training: Loss: 0.8788, Accuracy: 58.5634%,
# 		Validation: Loss: 0.8788, Accuracy: 67.2570%, Time: 8518.8632s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 18/3000
# Epoch: 18/3000
# Epoch: 018, Training: Loss: 0.9320, Accuracy: 60.0521%,
# 		Validation: Loss: 0.9320, Accuracy: 65.8297%, Time: 8307.3785s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 018, Training: Loss: 0.9320, Accuracy: 60.0521%,
# 		Validation: Loss: 0.9320, Accuracy: 65.8297%, Time: 8307.3785s
# Best Accuracy for validation : 0.6890 at epoch 014
# Epoch: 19/3000
# Epoch: 19/3000
# Epoch: 019, Training: Loss: 0.7999, Accuracy: 61.4684%,
# 		Validation: Loss: 0.7999, Accuracy: 74.1257%, Time: 8234.7468s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 019, Training: Loss: 0.7999, Accuracy: 61.4684%,
# 		Validation: Loss: 0.7999, Accuracy: 74.1257%, Time: 8234.7468s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 20/3000
# Epoch: 20/3000
# Epoch: 020, Training: Loss: 0.9810, Accuracy: 63.0366%,
# 		Validation: Loss: 0.9810, Accuracy: 65.1089%, Time: 8319.6256s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 020, Training: Loss: 0.9810, Accuracy: 63.0366%,
# 		Validation: Loss: 0.9810, Accuracy: 65.1089%, Time: 8319.6256s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 21/3000
# Epoch: 21/3000
# Epoch: 021, Training: Loss: 0.8171, Accuracy: 64.6974%,
# 		Validation: Loss: 0.8171, Accuracy: 70.4483%, Time: 8010.4017s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 021, Training: Loss: 0.8171, Accuracy: 64.6974%,
# 		Validation: Loss: 0.8171, Accuracy: 70.4483%, Time: 8010.4017s
# Best Accuracy for validation : 0.7413 at epoch 019
# Epoch: 22/3000
# Epoch: 22/3000
# Epoch: 022, Training: Loss: 0.7793, Accuracy: 67.8444%,
# 		Validation: Loss: 0.7793, Accuracy: 74.3320%, Time: 8313.0873s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 022, Training: Loss: 0.7793, Accuracy: 67.8444%,
# 		Validation: Loss: 0.7793, Accuracy: 74.3320%, Time: 8313.0873s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 23/3000
# Epoch: 23/3000
# Epoch: 023, Training: Loss: 0.8611, Accuracy: 69.0596%,
# 		Validation: Loss: 0.8611, Accuracy: 70.8965%, Time: 8408.0875s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 023, Training: Loss: 0.8611, Accuracy: 69.0596%,
# 		Validation: Loss: 0.8611, Accuracy: 70.8965%, Time: 8408.0875s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 24/3000
# Epoch: 24/3000
# Epoch: 024, Training: Loss: 0.8013, Accuracy: 70.2611%,
# 		Validation: Loss: 0.8013, Accuracy: 74.0901%, Time: 8365.3434s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 024, Training: Loss: 0.8013, Accuracy: 70.2611%,
# 		Validation: Loss: 0.8013, Accuracy: 74.0901%, Time: 8365.3434s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 25/3000
# Epoch: 25/3000
# Epoch: 025, Training: Loss: 0.7899, Accuracy: 71.2045%,
# 		Validation: Loss: 0.7899, Accuracy: 73.2058%, Time: 8423.8834s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 025, Training: Loss: 0.7899, Accuracy: 71.2045%,
# 		Validation: Loss: 0.7899, Accuracy: 73.2058%, Time: 8423.8834s
# Best Accuracy for validation : 0.7433 at epoch 022
# Epoch: 26/3000
# Epoch: 26/3000
# Epoch: 026, Training: Loss: 0.7543, Accuracy: 72.1841%,
# 		Validation: Loss: 0.7543, Accuracy: 77.2056%, Time: 8404.9979s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 026, Training: Loss: 0.7543, Accuracy: 72.1841%,
# 		Validation: Loss: 0.7543, Accuracy: 77.2056%, Time: 8404.9979s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 27/3000
# Epoch: 27/3000
# Epoch: 027, Training: Loss: 0.7528, Accuracy: 72.9377%,
# 		Validation: Loss: 0.7528, Accuracy: 76.2193%, Time: 8352.7937s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 027, Training: Loss: 0.7528, Accuracy: 72.9377%,
# 		Validation: Loss: 0.7528, Accuracy: 76.2193%, Time: 8352.7937s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 28/3000
# Epoch: 28/3000
# Epoch: 028, Training: Loss: 0.8207, Accuracy: 74.1760%,
# 		Validation: Loss: 0.8207, Accuracy: 74.9176%, Time: 7747.7625s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 028, Training: Loss: 0.8207, Accuracy: 74.1760%,
# 		Validation: Loss: 0.8207, Accuracy: 74.9176%, Time: 7747.7625s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 29/3000
# Epoch: 29/3000
# Epoch: 029, Training: Loss: 0.7930, Accuracy: 74.9497%,
# 		Validation: Loss: 0.7930, Accuracy: 73.8673%, Time: 8316.0652s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 029, Training: Loss: 0.7930, Accuracy: 74.9497%,
# 		Validation: Loss: 0.7930, Accuracy: 73.8673%, Time: 8316.0652s
# Best Accuracy for validation : 0.7721 at epoch 026
# Epoch: 30/3000
# Epoch: 30/3000
# Epoch: 030, Training: Loss: 0.7693, Accuracy: 75.8023%,
# 		Validation: Loss: 0.7693, Accuracy: 77.4948%, Time: 7185.3099s
# Best Accuracy for validation : 0.7749 at epoch 030
# Epoch: 030, Training: Loss: 0.7693, Accuracy: 75.8023%,
# 		Validation: Loss: 0.7693, Accuracy: 77.4948%, Time: 7185.3099s
# Best Accuracy for validation : 0.7749 at epoch 030
# Epoch: 31/3000
# Epoch: 31/3000
# Epoch: 031, Training: Loss: 0.7836, Accuracy: 76.7647%,
# 		Validation: Loss: 0.7836, Accuracy: 73.7274%, Time: 7208.2856s
# Best Accuracy for validation : 0.7749 at epoch 030
# Epoch: 031, Training: Loss: 0.7836, Accuracy: 76.7647%,
# 		Validation: Loss: 0.7836, Accuracy: 73.7274%, Time: 7208.2856s
# Best Accuracy for validation : 0.7749 at epoch 030
# Epoch: 32/3000
# Epoch: 32/3000
# Epoch: 032, Training: Loss: 0.6982, Accuracy: 78.4605%,
# 		Validation: Loss: 0.6982, Accuracy: 78.0473%, Time: 7740.8255s
# Best Accuracy for validation : 0.7805 at epoch 032
# Epoch: 032, Training: Loss: 0.6982, Accuracy: 78.4605%,
# 		Validation: Loss: 0.6982, Accuracy: 78.0473%, Time: 7740.8255s
# Best Accuracy for validation : 0.7805 at epoch 032
# Epoch: 33/3000
# Epoch: 33/3000
# Epoch: 033, Training: Loss: 0.7224, Accuracy: 79.1494%,
# 		Validation: Loss: 0.7224, Accuracy: 79.3347%, Time: 8396.1221s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 033, Training: Loss: 0.7224, Accuracy: 79.1494%,
# 		Validation: Loss: 0.7224, Accuracy: 79.3347%, Time: 8396.1221s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 34/3000
# Epoch: 34/3000
# Epoch: 034, Training: Loss: 0.7491, Accuracy: 79.7142%,
# 		Validation: Loss: 0.7491, Accuracy: 76.9709%, Time: 8522.5748s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 034, Training: Loss: 0.7491, Accuracy: 79.7142%,
# 		Validation: Loss: 0.7491, Accuracy: 76.9709%, Time: 8522.5748s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 35/3000
# Epoch: 35/3000
# Epoch: 035, Training: Loss: 0.7467, Accuracy: 80.2945%,
# 		Validation: Loss: 0.7467, Accuracy: 75.0196%, Time: 8487.4049s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 035, Training: Loss: 0.7467, Accuracy: 80.2945%,
# 		Validation: Loss: 0.7467, Accuracy: 75.0196%, Time: 8487.4049s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 36/3000
# Epoch: 36/3000
# Epoch: 036, Training: Loss: 0.6818, Accuracy: 80.6333%,
# 		Validation: Loss: 0.6818, Accuracy: 78.0828%, Time: 7266.3552s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 036, Training: Loss: 0.6818, Accuracy: 80.6333%,
# 		Validation: Loss: 0.6818, Accuracy: 78.0828%, Time: 7266.3552s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 37/3000
# Epoch: 37/3000
# Epoch: 037, Training: Loss: 0.6863, Accuracy: 80.9496%,
# 		Validation: Loss: 0.6863, Accuracy: 77.8647%, Time: 7297.9431s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 037, Training: Loss: 0.6863, Accuracy: 80.9496%,
# 		Validation: Loss: 0.6863, Accuracy: 77.8647%, Time: 7297.9431s
# Best Accuracy for validation : 0.7933 at epoch 033
# Epoch: 38/3000
# Epoch: 38/3000
# Epoch: 038, Training: Loss: 0.6523, Accuracy: 81.5394%,
# 		Validation: Loss: 0.6523, Accuracy: 81.3216%, Time: 8380.9847s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 038, Training: Loss: 0.6523, Accuracy: 81.5394%,
# 		Validation: Loss: 0.6523, Accuracy: 81.3216%, Time: 8380.9847s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 39/3000
# Epoch: 39/3000
# Epoch: 039, Training: Loss: 0.6905, Accuracy: 81.8734%,
# 		Validation: Loss: 0.6905, Accuracy: 78.8344%, Time: 7177.0423s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 039, Training: Loss: 0.6905, Accuracy: 81.8734%,
# 		Validation: Loss: 0.6905, Accuracy: 78.8344%, Time: 7177.0423s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 40/3000
# Epoch: 40/3000
# Epoch: 040, Training: Loss: 0.6800, Accuracy: 82.3671%,
# 		Validation: Loss: 0.6800, Accuracy: 77.6584%, Time: 7165.4367s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 040, Training: Loss: 0.6800, Accuracy: 82.3671%,
# 		Validation: Loss: 0.6800, Accuracy: 77.6584%, Time: 7165.4367s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 41/3000
# Epoch: 41/3000
# Epoch: 041, Training: Loss: 0.6992, Accuracy: 82.5148%,
# 		Validation: Loss: 0.6992, Accuracy: 78.4409%, Time: 7180.0553s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 041, Training: Loss: 0.6992, Accuracy: 82.5148%,
# 		Validation: Loss: 0.6992, Accuracy: 78.4409%, Time: 7180.0553s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 42/3000
# Epoch: 42/3000
# Epoch: 042, Training: Loss: 0.7085, Accuracy: 83.4446%,
# 		Validation: Loss: 0.7085, Accuracy: 76.9424%, Time: 7202.8630s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 042, Training: Loss: 0.7085, Accuracy: 83.4446%,
# 		Validation: Loss: 0.7085, Accuracy: 76.9424%, Time: 7202.8630s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 43/3000
# Epoch: 43/3000
# Epoch: 043, Training: Loss: 0.6958, Accuracy: 83.9679%,
# 		Validation: Loss: 0.6958, Accuracy: 78.3436%, Time: 7203.8156s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 043, Training: Loss: 0.6958, Accuracy: 83.9679%,
# 		Validation: Loss: 0.6958, Accuracy: 78.3436%, Time: 7203.8156s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 44/3000
# Epoch: 44/3000
# Epoch: 044, Training: Loss: 0.6769, Accuracy: 84.0765%,
# 		Validation: Loss: 0.6769, Accuracy: 79.5647%, Time: 8085.1803s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 044, Training: Loss: 0.6769, Accuracy: 84.0765%,
# 		Validation: Loss: 0.6769, Accuracy: 79.5647%, Time: 8085.1803s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 45/3000
# Epoch: 45/3000
# Epoch: 045, Training: Loss: 0.7106, Accuracy: 84.2278%,
# 		Validation: Loss: 0.7106, Accuracy: 77.7556%, Time: 9233.5630s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 045, Training: Loss: 0.7106, Accuracy: 84.2278%,
# 		Validation: Loss: 0.7106, Accuracy: 77.7556%, Time: 9233.5630s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 46/3000
# Epoch: 46/3000
# Epoch: 046, Training: Loss: 0.6661, Accuracy: 84.3643%,
# 		Validation: Loss: 0.6661, Accuracy: 80.0507%, Time: 9920.7980s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 046, Training: Loss: 0.6661, Accuracy: 84.3643%,
# 		Validation: Loss: 0.6661, Accuracy: 80.0507%, Time: 9920.7980s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 47/3000
# Epoch: 47/3000
# Epoch: 047, Training: Loss: 0.6815, Accuracy: 84.6152%,
# 		Validation: Loss: 0.6815, Accuracy: 78.2701%, Time: 12759.4504s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 047, Training: Loss: 0.6815, Accuracy: 84.6152%,
# 		Validation: Loss: 0.6815, Accuracy: 78.2701%, Time: 12759.4504s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 48/3000
# Epoch: 48/3000
# Epoch: 048, Training: Loss: 0.6873, Accuracy: 84.7434%,
# 		Validation: Loss: 0.6873, Accuracy: 78.5570%, Time: 15494.5561s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 048, Training: Loss: 0.6873, Accuracy: 84.7434%,
# 		Validation: Loss: 0.6873, Accuracy: 78.5570%, Time: 15494.5561s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 49/3000
# Epoch: 49/3000
# Epoch: 049, Training: Loss: 0.7007, Accuracy: 85.1617%,
# 		Validation: Loss: 0.7007, Accuracy: 77.6015%, Time: 13535.1470s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 049, Training: Loss: 0.7007, Accuracy: 85.1617%,
# 		Validation: Loss: 0.7007, Accuracy: 77.6015%, Time: 13535.1470s
# Best Accuracy for validation : 0.8132 at epoch 038
# Epoch: 50/3000
# Epoch: 50/3000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\NANOLA~1\AppData\Local\Temp/ipykernel_28536/2181074094.py in <module>
#       1 num_epochs = 3000
# ----> 2 trained_model, history = train_and_valid(resnet50, loss_func, num_epochs)
#       3 torch.save(history, 'models/'+dataset+'_history.pt')
#       4
#
# C:\Users\NANOLA~1\AppData\Local\Temp/ipykernel_28536/1225346874.py in train_and_valid(model, loss_function, epochs)
#      55             model.eval()
#      56
# ---> 57             for j, (inputs, labels) in enumerate(valid_data):
#      58                 inputs = inputs.to(device)
#      59                 labels = labels.to(device)
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     525
#     526     def __next__(self) -> Any:
# --> 527         with torch.autograd.profiler.record_function(self._profile_name):
#     528             if self._sampler_iter is None:
#     529                 self._reset()
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\autograd\profiler.py in __init__(self, name, args)
#     431         # Stores underlying RecordFunction as a tensor. TODO: move to custom
#     432         # class (https://github.com/pytorch/pytorch/issues/35026).
# --> 433         self.handle: torch.Tensor = torch.zeros(1)
#     434
#     435     def __enter__(self):
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\NANOLA~1\AppData\Local\Temp/ipykernel_28536/2181074094.py in <module>
#       1 num_epochs = 3000
# ----> 2 trained_model, history = train_and_valid(resnet50, loss_func, num_epochs)
#       3 torch.save(history, 'models/'+dataset+'_history.pt')
#       4
#
# C:\Users\NANOLA~1\AppData\Local\Temp/ipykernel_28536/1225346874.py in train_and_valid(model, loss_function, epochs)
#      55             model.eval()
#      56
# ---> 57             for j, (inputs, labels) in enumerate(valid_data):
#      58                 inputs = inputs.to(device)
#      59                 labels = labels.to(device)
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     525
#     526     def __next__(self) -> Any:
# --> 527         with torch.autograd.profiler.record_function(self._profile_name):
#     528             if self._sampler_iter is None:
#     529                 self._reset()
#
# D:\anacondagmd\envs\d2l\lib\site-packages\torch\autograd\profiler.py in __init__(self, name, args)
#     431         # Stores underlying RecordFunction as a tensor. TODO: move to custom
#     432         # class (https://github.com/pytorch/pytorch/issues/35026).
# --> 433         self.handle: torch.Tensor = torch.zeros(1)
#     434
#     435     def __enter__(self):
#
# KeyboardInterrupt:

# %%
history = np.array(history)
plt.plot(history[:, 0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0, 1)
plt.savefig(dataset+'_loss_curve.png')
plt.show()

plt.plot(history[:, 2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.savefig(dataset+'_accuracy_curve.png')
plt.show()

# %%
# 将验证集和真值对比图画出来 导入模型
dataset = 'E:\gmd_data\microsphere2_dataAugmented'
model38 = torch.load( dataset+'/models/'+'model_38.pt')
for param in model38.parameters():
    param.requires_grad = False
model38 = model38.to('cuda:0')
loss_function = nn.NLLLoss()



device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
history = []
best_acc = 0.0
best_epoch = 0


valid_loss = 0.0
valid_acc = 0.0

for j, (inputs, labels) in enumerate(valid_data):
    inputs = inputs.to(device)
    labels = labels.to(device)

    outputs = model38(inputs)

    loss = loss_function(outputs, labels)
    print("valid_data_j: {}".format(j))
    print("Outputs : ")
    print(outputs)
    print("labels ：")
    print(labels)
    print("loss ：")
    print(loss)

    valid_loss += loss.item() * inputs.size(0)

    ret, predictions = torch.max(outputs.data, 1)
    correct_counts = predictions.eq(labels.data.view_as(predictions))

    acc = torch.mean(correct_counts.type(torch.FloatTensor))

    valid_acc += acc.item() * inputs.size(0)

avg_valid_loss = valid_loss/valid_data_size
avg_valid_acc = valid_acc/valid_data_size
# Out:
# valid_data_j: 0
# Outputs :
# tensor([[-100.2883,  -92.3576,  -92.1173,  ...,  -54.4081, -108.0811,
#           -98.8013],
#         [ -65.5693,  -67.4664,  -63.6391,  ...,  -73.7634,  -63.7410,
#           -68.3932],
#         [ -64.6967,  -61.4826,  -60.9130,  ...,  -87.1294,  -50.0973,
#           -56.6066],
#         ...,
#         [ -50.7181,  -85.8765,  -71.2357,  ..., -110.1529,  -99.7539,
#           -98.7987],
#         [ -98.8066,  -84.0519,  -87.3415,  ...,  -39.6289,  -74.1971,
#           -78.0432],
#         [ -80.4934,  -80.3928,  -90.7395,  ...,  -20.4374,  -74.3231,
#           -72.3688]], device='cuda:0')
# labels ：
# tensor([125,  32,  90, 162, 109,  90,  24, 165,  78,  58,  49,  26, 121, 122,
#          67, 158, 128,  71,  25,  89, 130, 163,   2,  21, 110,  61,  16,  81,
#         138, 147,  98, 117], device='cuda:0')
# loss ：
# tensor(0.5662, device='cuda:0')
# valid_data_j: 1
# Outputs :
# tensor([[ -56.7027,  -75.4782,  -71.4482,  ...,  -64.2741,  -74.9183,
#           -76.6378],
#         [ -88.4017,  -77.3248,  -79.3611,  ...,  -84.0961,  -65.9937,
#           -73.5432],
#         [ -12.8346,  -49.2243,  -57.9149,  ...,  -52.4513,  -68.9094,
#           -60.1479],
#         ...,
#         [ -46.0358,  -67.4922,  -68.2619,  ...,  -92.1486,  -64.4905,
#           -67.9569],
#         [-107.7272,  -81.5970,  -84.4143,  ...,  -65.4955,  -75.7699,
#           -79.2216],
#         [  -0.9556,  -68.0978,  -64.3521,  ..., -109.7258,  -92.0063,
#           -84.5851]], device='cuda:0')
# labels ：
# tensor([ 96,  31,  50, 141,  76,  26, 104, 139, 103,  13, 124,  72, 119,  26,
#          33, 160, 162, 150,   7, 166,  68, 139, 168, 125, 118, 113, 119,  93,
#           7,  64,  29,  88], device='cuda:0')
# loss ：
# tensor(0.7329, device='cuda:0')
# valid_data_j: 2
# Outputs :
# tensor([[ -49.0068,  -18.3719,  -11.6330,  ...,  -39.2970,  -31.0443,
#           -26.1781],
#         [ -40.1996, -107.8260,  -96.1010,  ..., -115.5508, -124.0973,
#          -119.6935],
#         [ -57.1548,  -52.7777,  -38.8380,  ...,  -79.8336,  -73.0133,
#           -68.1384],
#         ...,
#         [ -56.7027,  -75.4782,  -71.4482,  ...,  -64.2741,  -74.9183,
#           -76.6378],
#         [ -41.4005,  -78.2118,  -85.1861,  ...,  -41.4742,  -97.9506,
#           -87.1064],
#         [ -47.3745,  -85.5704,  -69.9293,  ..., -120.6615, -104.3574,
#          -103.0329]], device='cuda:0')
# labels ：
# tensor([  6, 140,   9,  89, 151,  87,  67,  46,  61,  61,  68, 115, 107, 140,
#         100, 111,  22,  39, 116, 107,  91, 110,  12,  62, 166,   6,   8, 111,
#          76,  96, 164, 148], device='cuda:0')
# loss ：
# tensor(0.6701, device='cuda:0')
# valid_data_j: 3
# Outputs :
# tensor([[ -98.8066,  -84.0519,  -87.3415,  ...,  -39.6289,  -74.1971,
#           -78.0432],
#         [ -62.1480,  -64.7393,  -63.3248,  ...,  -71.3465,  -58.8432,
#           -63.6790],
#         [ -93.6084,  -81.1302,  -79.0046,  ...,  -49.1132,  -96.9923,
#           -87.5479],
#         ...,
#         [ -88.9923,  -47.4286,  -42.0025,  ...,  -43.2595,  -66.2897,
#           -56.8304],
#         [ -29.8659,  -65.8121,  -68.7496,  ...,  -75.4798,  -82.7350,
#           -77.3054],
#         [ -41.7757, -126.5856, -112.3143,  ..., -150.1182, -145.6923,
#          -141.3746]], device='cuda:0')
# labels ：
# tensor([ 98,  34, 124,  42,  60,  25,   6, 109, 141,  59, 172,   5,  75,  38,
#          29, 115, 115, 134, 153, 104,  45,  56,  21, 162,  16,  24,  44, 111,
#         105,  16,  82, 141], device='cuda:0')
# loss ：
# tensor(0.6273, device='cuda:0')
# valid_data_j: 4
# Outputs :
# tensor([[ -59.0919, -100.3743,  -86.8958,  ...,  -91.7742, -117.7563,
#          -112.9290],
#         [ -43.4717,  -36.4900,  -45.8648,  ...,  -53.1622,  -46.7926,
#           -44.1611],
#         [ -34.9939,  -99.1763,  -88.5857,  ..., -129.1736, -113.5000,
#          -111.0824],
#         ...,
#         [ -67.3694,  -52.2110,  -63.3975,  ...,  -47.7519,  -37.2908,
#           -42.8092],
#         [ -99.1538,  -72.5896,  -81.5259,  ...,  -15.6392,  -64.7881,
#           -64.4580],
#         [ -24.6757,  -52.7241,  -51.9019,  ...,  -71.3132,  -62.9899,
#           -61.7668]], device='cuda:0')
# labels ：
# tensor([157,  23,  60, 100, 124,  90,  83, 107, 172, 118, 150, 172,  75, 119,
#         138, 170, 152, 138,  42, 139, 104,  29,  76,  64, 154, 162, 127,   0,
#          62,  70, 119,  83], device='cuda:0')
# loss ：
# tensor(0.5716, device='cuda:0')
# valid_data_j: 5
# Outputs :
# tensor([[ -63.8484,  -82.5340,  -89.0302,  ...,  -32.4633,  -99.4076,
#           -88.3871],
#         [ -57.1246,  -72.4979,  -60.5117,  ...,  -72.2194,  -87.8315,
#           -83.5610],
#         [ -45.7028, -116.1630, -108.9601,  ..., -134.7186, -126.6936,
#          -123.0462],
#         ...,
#         [ -47.6356,  -52.7243,  -45.8784,  ...,  -68.8437,  -74.1915,
#           -66.3259],
#         [ -78.9710,  -58.7451,  -65.6092,  ...,  -31.8123,  -48.9605,
#           -48.9816],
#         [ -72.5174,  -80.7914,  -84.6534,  ...,  -51.9061,  -92.1989,
#           -85.4521]], device='cuda:0')
# labels ：
# tensor([165, 157,  58, 145, 117, 115, 169,  56,  66,  98, 148,  97, 144, 156,
#          83, 126, 142, 117,  27,  65,  48, 125,  73, 106, 138,  87, 141,   3,
#          13,  12, 104, 129], device='cuda:0')
# loss ：
# tensor(0.3563, device='cuda:0')
# valid_data_j: 6
# Outputs :
# tensor([[ -43.4066,  -70.2130,  -80.0663,  ...,  -67.7846,  -80.9656,
#           -74.0605],
#         [ -72.2596,  -71.9664,  -78.0832,  ...,  -77.2714,  -51.9900,
#           -61.6536],
#         [ -95.7121,  -69.6543,  -74.4385,  ...,  -25.2347,  -75.2713,
#           -69.0423],
#         ...,
#         [ -37.8488,  -68.9954,  -79.2486,  ...,  -68.9747,  -82.6292,
#           -74.8848],
#         [-101.6187,  -67.1398,  -76.5129,  ...,  -14.8742,  -61.5255,
#           -60.1715],
#         [ -49.9853,  -52.1104,  -60.9403,  ...,  -17.0571,  -59.9794,
#           -53.5138]], device='cuda:0')
# labels ：
# tensor([ 47,  67, 121,  49,  74,   4, 149,  97,  63,  36,  37,  59,  90,  29,
#           9, 136, 149,  77,  76, 169,  97, 103, 166,  33, 101,  16,  71,  74,
#          88,  49, 119, 168], device='cuda:0')
# loss ：
# tensor(0.5880, device='cuda:0')
# valid_data_j: 7
# Outputs :
# tensor([[ -39.2252,  -66.7680,  -76.7324,  ...,  -66.3336,  -78.9353,
#           -71.6066],
#         [ -46.0358,  -67.4922,  -68.2619,  ...,  -92.1486,  -64.4905,
#           -67.9569],
#         [ -63.8484,  -82.5340,  -89.0302,  ...,  -32.4633,  -99.4076,
#           -88.3871],
#         ...,
#         [ -42.8001,  -53.3892,  -54.6201,  ..., -100.6993,  -53.0140,
#           -58.1097],
#         [ -69.2711,  -82.3248,  -86.0452,  ...,  -53.6625,  -95.3548,
#           -88.1962],
#         [ -88.6668, -162.2637, -151.9162,  ..., -132.2285, -182.0572,
#          -171.8447]], device='cuda:0')
# labels ：
# tensor([ 46,  64, 165,  88, 122, 172,  82, 155, 161,  32, 116, 170,  42, 168,
#         106,  51, 166, 148,  39, 141,  30, 111,  47, 133, 156,  75,   2, 102,
#          11,  66, 129, 138], device='cuda:0')
# loss ：
# tensor(0.6267, device='cuda:0')
# valid_data_j: 8
# Outputs :
# tensor([[-72.5273, -48.9444, -58.3794,  ..., -58.3621, -26.5206, -35.7097],
#         [-72.0622, -51.9255, -58.6778,  ..., -55.6334, -57.9116, -56.7815],
#         [-73.7634, -89.6482, -90.8243,  ..., -92.4082, -93.2906, -94.6407],
#         ...,
#         [-88.4251, -58.4291, -70.2138,  ..., -70.8192, -33.7493, -43.8215],
#         [-69.3231, -71.9149, -68.5884,  ..., -80.9909, -66.1419, -71.8071],
#         [-72.2596, -71.9664, -78.0832,  ..., -77.2714, -51.9900, -61.6536]],
#        device='cuda:0')
# labels ：
# tensor([ 69,  26,  76, 172,  51,  20, 137, 168,  62,  87, 157, 162, 129,  67,
#         131,  71,  44,  73,  31,  45,  77,  41,  90,  15, 103,  38, 151,  42,
#          15,  70,  32,  67], device='cuda:0')
# loss ：
# tensor(0.5346, device='cuda:0')
# valid_data_j: 9
# Outputs :
# tensor([[ -60.2868,  -79.6335,  -78.7766,  ...,  -81.7192,  -85.9898,
#           -85.1536],
#         [ -72.0622,  -51.9255,  -58.6778,  ...,  -55.6334,  -57.9116,
#           -56.7815],
#         [-107.7272,  -81.5970,  -84.4143,  ...,  -65.4955,  -75.7699,
#           -79.2216],
#         ...,
#         [ -92.3087,  -38.9239,  -39.8900,  ...,  -30.8929,  -52.9552,
#           -43.5554],
#         [ -56.0549,  -76.5076,  -62.5802,  ..., -106.8594,  -90.3224,
#           -90.1869],
#         [ -57.3579, -110.4185,  -96.1236,  ..., -137.8711, -124.0936,
#          -122.0290]], device='cuda:0')
# labels ：
# tensor([ 76,  26,  29,  50, 159, 172,  79,  94,  90,  27,  74, 142, 141,  84,
#          10, 153, 160,  46, 154,  70, 169, 161, 171, 162,  14,  78, 168,  45,
#         115,  17, 149, 146], device='cuda:0')
# loss ：
# tensor(0.4632, device='cuda:0')
# valid_data_j: 10
# Outputs :
# tensor([[ -69.9481,  -99.6160, -102.2043,  ...,  -93.8128,  -95.9552,
#           -94.3011],
#         [-107.9838,  -84.1671,  -86.3236,  ...,  -76.7537,  -82.0723,
#           -84.9909],
#         [ -64.3596,   -6.2333,   -9.9343,  ...,  -26.6060,   -0.3852,
#            -1.5049],
#         ...,
#         [ -62.4472,  -69.3818,  -74.3277,  ...,  -69.4483,  -52.8922,
#           -58.9359],
#         [ -54.4953,  -56.8431,  -53.2590,  ...,  -67.5592,  -52.6432,
#           -57.1832],
#         [ -56.4953,  -74.9557,  -71.0713,  ...,  -63.7577,  -74.7542,
#           -76.1673]], device='cuda:0')
# labels ：
# tensor([108,  29, 171,  84,  46,  70,  26,  67,  89,  94,  88,  13,   2, 160,
#         112,  18, 104,  36,  59, 155,  21, 110, 120, 136,  23,  40, 151,  79,
#         137,  65,  36,  94], device='cuda:0')
# loss ：
# tensor(0.7796, device='cuda:0')
# valid_data_j: 11
# Outputs :
# tensor([[ -47.3745,  -85.5704,  -69.9293,  ..., -120.6615, -104.3574,
#          -103.0329],
#         [ -50.2250,  -17.0244,  -19.0063,  ...,  -26.4411,  -13.1523,
#           -14.9891],
#         [ -79.7347, -102.4487, -107.9570,  ...,  -76.2285,  -90.7232,
#           -92.5297],
#         ...,
#         [ -68.7770,  -85.3177,  -90.3802,  ...,  -84.5180,  -99.6956,
#           -94.5238],
#         [ -65.1937,  -13.1113,  -19.2909,  ...,  -23.1147,   -4.8162,
#            -7.4841],
#         [ -43.4717,  -36.4900,  -45.8648,  ...,  -53.1622,  -46.7926,
#           -44.1611]], device='cuda:0')
# labels ：
# tensor([148, 122, 107,  68,  38,  47, 114, 104,  54,  28, 123,  13,  39,  99,
#         104,  69, 114,  75, 172, 106,  10, 157,  66,  23,  76,  79,  70, 124,
#         103,  80, 166,  23], device='cuda:0')
# loss ：
# tensor(0.9258, device='cuda:0')
# valid_data_j: 12
# Outputs :
# tensor([[ -43.4066,  -70.2130,  -80.0663,  ...,  -67.7846,  -80.9656,
#           -74.0605],
#         [ -78.3166,  -90.5932,  -94.2803,  ...,  -60.4986, -104.4194,
#           -96.7101],
#         [ -51.4116, -100.6706,  -95.7284,  ..., -127.3699, -106.7327,
#          -106.3532],
#         ...,
#         [ -37.1904, -100.2485,  -99.7056,  ...,  -74.6185, -121.4165,
#          -111.7977],
#         [ -61.7752,  -55.7238,  -41.0048,  ...,  -83.9193,  -77.3057,
#           -71.7915],
#         [ -41.4005,  -78.2118,  -85.1861,  ...,  -41.4742,  -97.9506,
#           -87.1064]], device='cuda:0')
# labels ：
# tensor([ 47, 129,  62, 158, 102,  73,  71,  47, 149,  75, 112, 149, 138,  22,
#          34, 169, 165, 147,  70,  49, 151,   6,   9, 135,  65, 115, 171,  60,
#          32, 162,   8, 164], device='cuda:0')
# loss ：
# tensor(0.6288, device='cuda:0')
# valid_data_j: 13
# Outputs :
# tensor([[ -16.5985,  -76.6128,  -66.7332,  ..., -130.8918,  -96.6377,
#           -95.2462],
#         [  -0.6635,  -64.8744,  -61.7702,  ..., -101.5697,  -88.5285,
#           -81.1525],
#         [-102.4701, -142.1602, -135.0347,  ..., -118.8173, -156.8072,
#          -149.1587],
#         ...,
#         [ -57.9766,  -40.4413,  -34.1777,  ...,  -44.1819,  -60.5469,
#           -51.5456],
#         [ -93.0186,  -31.9625,  -33.5348,  ...,  -30.3016,  -25.8007,
#           -28.4087],
#         [ -99.1538,  -72.5896,  -81.5259,  ...,  -15.6392,  -64.7881,
#           -64.4580]], device='cuda:0')
# labels ：
# tensor([ 33,   0, 135,   9,  79,  58,  18,  76,  39, 115, 129, 143,  25,  65,
#         137,  63,  74,  60,  49,  70,  82,   5,   5,   3, 106, 164, 136, 136,
#          74,  14, 133, 119], device='cuda:0')
# loss ：
# tensor(0.4710, device='cuda:0')
# valid_data_j: 14
# Outputs :
# tensor([[ -60.5483,  -76.0120,  -63.2133,  ...,  -76.1457,  -92.5000,
#           -87.9313],
#         [ -66.9952,  -60.2060,  -59.2164,  ...,  -37.7064,  -57.4938,
#           -58.8175],
#         [ -93.6084,  -81.1302,  -79.0046,  ...,  -49.1132,  -96.9923,
#           -87.5479],
#         ...,
#         [ -76.7365,  -26.2496,  -29.1831,  ...,  -35.0865,  -16.7675,
#           -20.9778],
#         [-102.4344,  -82.5769,  -87.9016,  ...,  -34.1748,  -72.1996,
#           -75.4533],
#         [ -83.6118, -115.9998, -114.9869,  ..., -125.4283, -111.9285,
#          -114.7492]], device='cuda:0')
# labels ：
# tensor([157,  97, 124, 139,  65,  83,  87, 125, 167, 149,  95,  23,  24,  84,
#         153, 141,  17, 147, 169, 122,   2, 171, 125, 169,  60, 109, 106,  38,
#          30, 133,  98,  74], device='cuda:0')
# loss ：
# tensor(0.4211, device='cuda:0')
# valid_data_j: 15
# Outputs :
# tensor([[-6.0287e+01, -7.9633e+01, -7.8777e+01,  ..., -8.1719e+01,
#          -8.5990e+01, -8.5154e+01],
#         [-6.5569e+01, -6.7466e+01, -6.3639e+01,  ..., -7.3763e+01,
#          -6.3741e+01, -6.8393e+01],
#         [-7.0312e+01, -2.9974e+01, -3.8196e+01,  ..., -1.2664e-02,
#          -3.1567e+01, -2.6298e+01],
#         ...,
#         [-2.2614e+01, -6.1873e+01, -5.7927e+01,  ..., -1.1101e+02,
#          -7.4157e+01, -7.4860e+01],
#         [-2.8453e+01, -8.0706e+01, -8.4466e+01,  ..., -5.5021e+01,
#          -1.0112e+02, -9.1193e+01],
#         [-3.4697e+00, -6.1577e+01, -5.5568e+01,  ..., -9.5323e+01,
#          -8.2259e+01, -7.7707e+01]], device='cuda:0')
# labels ：
# tensor([ 76,  32, 170, 122, 156,  39,  40,  18, 126,  30, 139, 113,  16,  47,
#         157,  99,  41,  62,  75, 157, 135, 105,  22,  37,  44,  84,   5,  18,
#          34,  44, 163,  22], device='cuda:0')
# loss ：
# tensor(0.5478, device='cuda:0')
# valid_data_j: 16
# Outputs :
# tensor([[ -72.5387,  -99.0479, -112.2882,  ...,  -44.7140, -109.1585,
#          -100.1652],
#         [ -67.1452,  -82.2738,  -65.4038,  ..., -109.8690, -108.0554,
#          -101.7417],
#         [ -99.3542, -109.9240, -113.9377,  ..., -115.0450, -103.6930,
#          -107.6740],
#         ...,
#         [ -28.8132,  -93.1203,  -93.7327,  ..., -108.1124, -108.2338,
#          -101.8116],
#         [ -43.4066,  -70.2130,  -80.0663,  ...,  -67.7846,  -80.9656,
#           -74.0605],
#         [-107.3330, -149.9087, -142.6591,  ..., -124.0831, -164.8395,
#          -156.9094]], device='cuda:0')
# labels ：
# tensor([114,   9,  39,  77,  80,  93,   2,  93,  26,   1,  71,  63,  99,  91,
#          46,  22,  47,  22, 136,  70, 122, 142, 112, 120,  88,  62, 132, 108,
#         125,  56,  47, 135], device='cuda:0')
# loss ：
# tensor(0.6036, device='cuda:0')
# valid_data_j: 17
# Outputs :
# tensor([[ -61.4872,  -76.4035,  -82.4577,  ...,  -70.7727,  -86.3235,
#           -80.6892],
#         [ -27.0962,  -78.5645,  -67.6454,  ..., -106.8624,  -89.4575,
#           -87.8763],
#         [ -86.2566,  -50.7075,  -57.3428,  ...,  -23.0851,  -39.7044,
#           -41.2072],
#         ...,
#         [ -69.3231,  -71.9149,  -68.5884,  ...,  -80.9909,  -66.1419,
#           -71.8071],
#         [ -85.8671,  -92.2388,  -94.9520,  ...,  -88.6202, -104.5284,
#           -97.5625],
#         [ -69.1752,  -98.5541,  -98.6519,  ...,  -78.7602, -101.1782,
#           -97.4848]], device='cuda:0')
# labels ：
# tensor([ 43, 146, 103,   1, 115,  57, 158,  32,  63,  27,  18,  80, 123,   0,
#          21,  78,  51,  31, 148, 171,  15, 107, 166, 130,  97, 138,  63,  69,
#          48,  32,  41, 109], device='cuda:0')
# loss ：
# tensor(0.6765, device='cuda:0')
# valid_data_j: 18
# Outputs :
# tensor([[ -70.7123,  -29.1167,  -31.5295,  ...,  -42.2080,  -46.8451,
#           -37.6386],
#         [ -44.4034, -125.6869, -109.8187,  ..., -152.6158, -144.2550,
#          -140.6721],
#         [ -88.1310,  -47.9382,  -57.1013,  ...,   -6.7511,  -51.9388,
#           -45.7123],
#         ...,
#         [ -65.5693,  -67.4664,  -63.6391,  ...,  -73.7634,  -63.7410,
#           -68.3932],
#         [ -49.7619,  -99.2061,  -93.9401,  ..., -126.2859, -106.4140,
#          -105.6793],
#         [ -64.7122,  -68.6295,  -70.2572,  ...,  -96.2483,  -58.8886,
#           -65.0847]], device='cuda:0')
# labels ：
# tensor([ 19, 142, 169,  58, 168, 137,  28,  77,  85, 155,  99,  58,  28,  22,
#          33, 167,  19, 144,  30, 162, 169,  39, 149, 168, 120, 153, 110,  54,
#         126,  32,  62,  72], device='cuda:0')
# loss ：
# tensor(0.4648, device='cuda:0')
# valid_data_j: 19
# Outputs :
# tensor([[ -29.0459,  -93.4496,  -91.4741,  ..., -114.2975, -108.4333,
#          -102.2918],
#         [-118.9867,  -99.4947, -106.1961,  ...,  -60.9334,  -75.5171,
#           -85.0170],
#         [ -62.5321,  -44.4315,  -31.2271,  ...,  -73.0370,  -65.0567,
#           -59.1030],
#         ...,
#         [ -49.7238,  -65.7403,  -66.7936,  ...,  -64.6255,  -71.9549,
#           -70.7252],
#         [ -60.2163,   -0.6461,   -1.4552,  ...,  -18.8923,   -4.7298,
#            -1.5630],
#         [ -37.1904, -100.2485,  -99.7056,  ...,  -74.6185, -121.4165,
#          -111.7977]], device='cuda:0')
# labels ：
# tensor([ 56,  99,   7,  82,  50, 108,  40, 102, 117, 127,  46, 135, 102, 171,
#         137,  21, 123, 143, 120,   5, 136, 119,  75,  32,  98, 135,  74,  89,
#          64,  80,   1, 162], device='cuda:0')
# loss ：
# tensor(0.6705, device='cuda:0')
# valid_data_j: 20
# Outputs :
# tensor([[ -10.1234,  -66.5815,  -70.2989,  ...,  -78.6611,  -87.5201,
#           -79.1226],
#         [ -63.7903,  -82.1211,  -80.8732,  ...,  -73.1727,  -75.5912,
#           -79.8620],
#         [ -96.8296,  -12.5181,  -18.5943,  ...,  -44.0716,   -0.1800,
#            -3.5881],
#         ...,
#         [ -25.2670,  -54.9126,  -63.3045,  ...,  -56.9501,  -68.3536,
#           -61.5720],
#         [ -84.3128,  -96.5740,  -95.5040,  ...,  -88.8349,  -86.0610,
#           -92.3524],
#         [-102.0423,  -85.1209,  -87.2988,  ...,  -88.5129,  -80.6599,
#           -85.5788]], device='cuda:0')
# labels ：
# tensor([ 52,  94, 171,  23, 172,  45,  47,   4,   3,  47, 128,  99,  33,   4,
#          76,  29,  63, 124,  25,  83,  25,  90, 143, 132, 117, 142,  16, 135,
#         118,  50,  93,  30], device='cuda:0')
# loss ：
# tensor(0.9633, device='cuda:0')
# valid_data_j: 21
# Outputs :
# tensor([[ -62.8206,  -76.9503,  -72.9445,  ..., -122.5285,  -75.1989,
#           -80.4983],
#         [ -35.6407,  -37.2408,  -43.4427,  ...,  -60.6783,  -39.9215,
#           -41.8169],
#         [ -47.7588,  -81.4037,  -78.9529,  ..., -101.9779,  -81.4790,
#           -82.3216],
#         ...,
#         [ -16.0882,  -53.9221,  -48.5342,  ...,  -95.3941,  -65.0452,
#           -65.4048],
#         [ -69.9292,  -73.0847,  -75.4656,  ..., -102.4511,  -61.9073,
#           -68.9469],
#         [ -47.4132, -126.4713, -113.8608,  ..., -135.2547, -144.8205,
#          -139.3356]], device='cuda:0')
# labels ：
# tensor([ 86,  55,  63,  33,  50, 122,  19, 146, 157,  37, 126,  96,  29,  30,
#          92,  87, 104,  50,  89,  52,  71,  50, 111,  83, 168, 113, 166,  32,
#         128,  33,  72, 140], device='cuda:0')
# loss ：
# tensor(0.5148, device='cuda:0')
# valid_data_j: 22
# Outputs :
# tensor([[ -66.1487,  -27.4092,  -22.6263,  ...,  -30.2767,  -39.0224,
#           -33.5661],
#         [ -46.5003,  -41.0323,  -51.5767,  ...,  -57.2375,  -57.9885,
#           -51.7450],
#         [ -39.9998,  -45.7942,  -44.1509,  ...,  -67.6995,  -52.3906,
#           -50.9663],
#         ...,
#         [ -53.7196, -111.0986, -106.0297,  ..., -127.7403, -118.9190,
#          -117.0660],
#         [ -72.5387,  -99.0479, -112.2882,  ...,  -44.7140, -109.1585,
#          -100.1652],
#         [ -78.8995,  -88.5272,  -97.8804,  ...,  -70.2846, -110.6862,
#           -98.7969]], device='cuda:0')
# labels ：
# tensor([ 15,  21,  85,   9,   5,  25,  42,  98, 106, 136,  34,  28,  98, 125,
#          67,  96, 146,   3,  93,  98,   9, 163, 110,  23, 120,  64, 106,  98,
#         124,  59, 114,  45], device='cuda:0')
# loss ：
# tensor(0.5530, device='cuda:0')
# valid_data_j: 23
# Outputs :
# tensor([[ -83.6118, -115.9998, -114.9869,  ..., -125.4283, -111.9285,
#          -114.7492],
#         [ -69.3231,  -71.9149,  -68.5884,  ...,  -80.9909,  -66.1419,
#           -71.8071],
#         [ -90.0718,  -85.9127,  -81.9376,  ...,  -67.8084, -104.7223,
#           -95.4909],
#         ...,
#         [ -61.7752,  -55.7238,  -41.0048,  ...,  -83.9193,  -77.3057,
#           -71.7915],
#         [ -61.7709, -111.2096,  -93.3338,  ..., -137.9122, -132.1203,
#          -129.6867],
#         [ -40.1996, -107.8260,  -96.1010,  ..., -115.5508, -124.0973,
#          -119.6935]], device='cuda:0')
# labels ：
# tensor([ 74,  32, 125,  71, 124, 141,  45,  79, 167,   5,  43, 134,   2,  77,
#          87, 111,  43,  38, 172, 136, 147, 120, 159,  86,  75, 124,  23,  18,
#          48,   8, 153, 140], device='cuda:0')
# loss ：
# tensor(0.6171, device='cuda:0')
# valid_data_j: 24
# Outputs :
# tensor([[ -73.6584,  -91.0801,  -89.8354,  ...,  -83.8258,  -82.4904,
#           -87.8375],
#         [ -49.2219,  -23.0302,  -29.9416,  ...,  -38.4724,  -37.5877,
#           -30.8529],
#         [ -26.8759,  -73.4315,  -70.2199,  ...,  -86.7330,  -82.2142,
#           -78.0452],
#         ...,
#         [ -93.0186,  -31.9625,  -33.5348,  ...,  -30.3016,  -25.8007,
#           -28.4087],
#         [ -51.9615, -109.4466,  -95.1316,  ..., -112.9088, -131.1174,
#          -125.5317],
#         [ -95.7121,  -69.6543,  -74.4385,  ...,  -25.2347,  -75.2713,
#           -69.0423]], device='cuda:0')
# labels ：
# tensor([ 92,  20,  57, 164, 110,  20, 140, 111,  16,   2,  34,  16,  33, 101,
#         109,  37, 161, 148,   1,  28,  93,   3, 106, 119,  33,  32,   2,  44,
#          63, 133, 156, 121], device='cuda:0')
# loss ：
# tensor(0.6216, device='cuda:0')
# valid_data_j: 25
# Outputs :
# tensor([[ -47.3745,  -85.5704,  -69.9293,  ..., -120.6615, -104.3574,
#          -103.0329],
#         [ -30.5297,  -64.4074,  -73.8877,  ...,  -68.1139,  -81.4024,
#           -73.0004],
#         [-113.5460, -110.8323, -112.2923,  ...,  -61.8143, -125.5084,
#          -116.2112],
#         ...,
#         [ -80.4934,  -80.3928,  -90.7395,  ...,  -20.4374,  -74.3231,
#           -72.3688],
#         [ -65.6095,  -75.5579,  -80.3977,  ...,  -29.5573,  -90.2578,
#           -80.5116],
#         [ -92.8006, -137.3395, -131.6394,  ..., -146.5894, -145.4011,
#          -143.9087]], device='cuda:0')
# labels ：
# tensor([148,  49, 126,  23, 140,  11, 163,  54,  66,  27, 164,   2, 126,  17,
#         143, 135,  82,   7, 112, 115, 127,   6, 114,  33, 160, 149, 142,  54,
#          78, 117, 165,  75], device='cuda:0')
# loss ：
# tensor(0.6635, device='cuda:0')
# valid_data_j: 26
# Outputs :
# tensor([[-6.2282e+01, -2.6854e+01, -3.4890e+01,  ..., -2.3799e-03,
#          -2.8301e+01, -2.3336e+01],
#         [-1.9628e+01, -7.8124e+01, -7.9564e+01,  ..., -9.3306e+01,
#          -9.4895e+01, -8.8252e+01],
#         [-9.7099e+01, -8.8060e+01, -8.8169e+01,  ..., -9.2046e+01,
#          -7.8491e+01, -8.5677e+01],
#         ...,
#         [-1.2187e+02, -9.6738e+01, -9.9618e+01,  ..., -4.5952e+01,
#          -1.0888e+02, -9.9347e+01],
#         [-5.7977e+01, -4.0441e+01, -3.4178e+01,  ..., -4.4182e+01,
#          -6.0547e+01, -5.1546e+01],
#         [-7.5248e+01, -1.3687e+02, -1.1813e+02,  ..., -1.4933e+02,
#          -1.5890e+02, -1.5531e+02]], device='cuda:0')
# labels ：
# tensor([170,  52,  31,  50,   3,  74, 128,  99,   2,  23, 169, 171,  87,  67,
#         153,  23,  74,  87, 132, 166,  83,   1, 158, 147, 105, 151, 119, 164,
#          56, 123,  14, 154], device='cuda:0')
# loss ：
# tensor(0.5820, device='cuda:0')
# valid_data_j: 27
# Outputs :
# tensor([[ -72.4911,  -55.3878,  -62.0412,  ...,  -61.0223,  -67.5299,
#           -63.3955],
#         [ -77.5010,  -97.1833,  -94.1837,  ...,  -86.9023,  -91.0405,
#           -95.5528],
#         [-113.5460, -110.8323, -112.2923,  ...,  -61.8143, -125.5084,
#          -116.2112],
#         ...,
#         [ -58.8508,  -62.8850,  -50.8015,  ...,  -84.6910,  -86.1779,
#           -79.0931],
#         [ -45.1594,  -61.0257,  -61.3743,  ...,  -55.1122,  -56.9897,
#           -58.8308],
#         [ -51.9615, -109.4466,  -95.1316,  ..., -112.9088, -131.1174,
#          -125.5317]], device='cuda:0')
# labels ：
# tensor([ 25,  95, 126,  27,  72,  25, 150,  87, 106, 156,  23,  71, 111,   7,
#          32,  12,  89,  20,  40,  19, 133, 106, 103,  23,  81,  57,  55, 133,
#          24,  10,  93, 156], device='cuda:0')
# loss ：
# tensor(0.7315, device='cuda:0')
# valid_data_j: 28
# Outputs :
# tensor([[ -87.0943,  -87.9517, -100.2821,  ...,  -22.0739,  -80.8258,
#           -78.9208],
#         [ -44.0442, -120.2315, -114.0631,  ..., -140.9540, -133.2032,
#          -127.1713],
#         [ -64.4986,  -82.0486,  -67.9051,  ..., -113.1967,  -94.0744,
#           -94.9703],
#         ...,
#         [ -86.4116,  -82.9385,  -84.0205,  ...,  -49.5319,  -95.9101,
#           -88.2042],
#         [ -69.1495,  -77.6109,  -82.7359,  ...,  -46.7911,  -89.2195,
#           -82.0036],
#         [ -96.6054, -127.5428, -125.0906,  ...,  -67.0568, -143.9317,
#          -134.0011]], device='cuda:0')
# labels ：
# tensor([117,  57, 149, 105, 117,  61, 104,  88, 109,  37,  25, 137, 127,   3,
#          80, 146, 114,  95, 148,  31,  75, 137,  52, 120,  78,  28,  83,  51,
#          18, 126, 129, 160], device='cuda:0')
# loss ：
# tensor(0.6247, device='cuda:0')
# valid_data_j: 29
# Outputs :
# tensor([[-57.1548, -52.7777, -38.8380,  ..., -79.8336, -73.0133, -68.1384],
#         [-59.2957, -64.2367, -72.9447,  ..., -19.6524, -67.4319, -62.3790],
#         [-53.9001, -79.3864, -80.7914,  ..., -73.3542, -76.8718, -75.6977],
#         ...,
#         [-47.4124, -75.3467, -74.9489,  ..., -97.5963, -72.9565, -75.0256],
#         [-71.1011, -50.3465, -56.3384,  ..., -27.2317, -42.0392, -41.8977],
#         [-68.5421, -37.3638, -41.1766,  ..., -51.8013, -59.0715, -48.8772]],
#        device='cuda:0')
# labels ：
# tensor([  9, 116, 108, 127, 113, 166, 134, 143,  92, 114, 119,  94,  53, 151,
#         127,  83, 134,  63,  87, 168,   5,  18, 117,  82,   4, 161, 145, 156,
#          88,  64, 104,  19], device='cuda:0')
# loss ：
# tensor(0.6825, device='cuda:0')
# valid_data_j: 30
# Outputs :
# tensor([[ -97.0987,  -88.0597,  -88.1689,  ...,  -92.0462,  -78.4912,
#           -85.6767],
#         [ -60.2868,  -79.6335,  -78.7766,  ...,  -81.7192,  -85.9898,
#           -85.1536],
#         [-114.7870, -129.6118, -133.9813,  ..., -136.1346, -121.5336,
#          -126.4779],
#         ...,
#         [-108.7381,  -84.3814,  -88.4998,  ...,  -43.0523,  -95.5531,
#           -86.4988],
#         [ -73.9114, -136.9569, -125.6388,  ..., -115.4451, -153.6946,
#          -146.5192],
#         [ -66.8552, -121.6076, -101.9319,  ..., -147.7874, -144.1032,
#          -141.3568]], device='cuda:0')
# labels ：
# tensor([ 31,  76,  39,  66, 108, 141, 140, 139, 171,  44, 125,  53, 134, 168,
#          86,  97, 159,  25, 150,  54,  32,  70, 172, 153, 102,  23,  14, 171,
#         160, 123, 137, 153], device='cuda:0')
# loss ：
# tensor(0.6795, device='cuda:0')
# valid_data_j: 31
# Outputs :
# tensor([[ -37.1904, -100.2485,  -99.7056,  ...,  -74.6185, -121.4165,
#          -111.7977],
#         [ -68.5795, -115.2966, -124.5199,  ...,  -70.4879, -118.7515,
#          -113.7594],
#         [ -90.9847, -117.6689, -118.8503,  ..., -113.2701, -125.7713,
#          -121.8461],
#         ...,
#         [ -92.0600, -160.9117, -149.3996,  ..., -129.3197, -180.2719,
#          -170.5732],
#         [ -83.6118, -115.9998, -114.9869,  ..., -125.4283, -111.9285,
#          -114.7492],
#         [ -49.0068,  -18.3719,  -11.6330,  ...,  -39.2970,  -31.0443,
#           -26.1781]], device='cuda:0')
# labels ：
# tensor([162, 112,  40, 172,  92,  85,  99, 129,   0, 115, 108,   8,  36, 137,
#           6, 101,  26,  88,  65, 171,  64,   4,   2, 132,  21, 153, 111,  95,
#         110, 137,  74,   6], device='cuda:0')
# loss ：
# tensor(0.7785, device='cuda:0')
# valid_data_j: 32
# Outputs :
# tensor([[ -13.5448,  -50.0196,  -56.0038,  ...,  -55.7375,  -61.2085,
#           -56.6444],
#         [ -46.0535,  -69.5650,  -78.5641,  ...,  -59.2294,  -89.4094,
#           -78.2932],
#         [ -59.0919, -100.3743,  -86.8958,  ...,  -91.7742, -117.7563,
#          -112.9290],
#         ...,
#         [ -71.6729,  -85.5728,  -67.7481,  ..., -113.0410, -112.7904,
#          -105.9331],
#         [ -93.7556, -109.4492, -112.0561,  ..., -108.6467, -109.1761,
#          -108.7100],
#         [-111.1872, -119.8116, -121.4279,  ..., -125.0523, -120.2274,
#          -118.9982]], device='cuda:0')
# labels ：
# tensor([ 51,  47, 157,  27,  77,  92,  52, 162, 170,  19, 142,  57,  52,  20,
#          86,  74, 102,  61,  34,  74,  58, 151, 170,  73,   7,  98, 161,  55,
#          39,   9,  38,  38], device='cuda:0')
# loss ：
# tensor(0.4748, device='cuda:0')
# valid_data_j: 33
# Outputs :
# tensor([[ -52.7690,  -46.7279,  -48.5233,  ...,  -87.1212,  -40.9822,
#           -46.9799],
#         [ -29.4627,  -29.0256,  -34.1055,  ...,  -46.7659,  -31.2205,
#           -32.5602],
#         [ -78.8995,  -88.5272,  -97.8804,  ...,  -70.2846, -110.6862,
#           -98.7969],
#         ...,
#         [ -88.4017,  -77.3248,  -79.3611,  ...,  -84.0961,  -65.9937,
#           -73.5432],
#         [ -75.5786,  -71.2677,  -70.7719,  ..., -100.9166,  -59.2435,
#           -66.1047],
#         [ -68.5421,  -37.3638,  -41.1766,  ...,  -51.8013,  -59.0715,
#           -48.8772]], device='cuda:0')
# labels ：
# tensor([ 77,  55,  45, 131, 118, 161,  85,   8,  65,  35,  67, 164,  97, 108,
#          44, 152, 157,  93,  84, 169,  47,  18,  62,  44,  70,  33,  70,   8,
#          81,  31,  90,  19], device='cuda:0')
# loss ：
# tensor(0.4106, device='cuda:0')
# valid_data_j: 34
# Outputs :
# tensor([[ -60.0195,  -90.4325, -102.3195,  ...,  -45.0051,  -92.8282,
#           -88.6007],
#         [ -41.7353,  -37.9064,  -32.4388,  ...,  -50.0676,  -56.7249,
#           -49.1304],
#         [ -53.6380, -116.6342, -102.1519,  ..., -118.6365, -138.7200,
#          -132.9163],
#         ...,
#         [ -48.0707,  -64.2343,  -52.9691,  ...,  -92.3972,  -74.4130,
#           -74.9439],
#         [ -41.7757, -126.5856, -112.3143,  ..., -150.1182, -145.6923,
#          -141.3746],
#         [ -54.4737,  -73.6115,  -70.3648,  ..., -105.5770,  -70.7708,
#           -76.6913]], device='cuda:0')
# labels ：
# tensor([113,  13, 156,  96,  86,  14,  15,  13,  29,  28,  78, 171,  87, 135,
#         160,  49,  97,  99,  71,  32, 162, 172, 102, 142,  24,  99, 149,  28,
#          42, 150, 141,  87], device='cuda:0')
# loss ：
# tensor(0.4781, device='cuda:0')
# valid_data_j: 35
# Outputs :
# tensor([[ -76.2714,  -72.2000,  -79.1375,  ...,  -45.3501,  -61.9483,
#           -61.9545],
#         [ -76.7306,  -98.1521,  -99.8295,  ..., -108.1598,  -90.4115,
#           -94.6914],
#         [ -43.4066,  -70.2130,  -80.0663,  ...,  -67.7846,  -80.9656,
#           -74.0605],
#         ...,
#         [-125.5084, -108.2798, -118.2605,  ...,  -72.6794,  -75.8041,
#           -88.9650],
#         [ -64.1485, -113.9733, -120.7153,  ...,  -78.4753, -117.5919,
#          -113.0042],
#         [ -49.7619,  -99.2061,  -93.9401,  ..., -126.2859, -106.4140,
#          -105.6793]], device='cuda:0')
# labels ：
# tensor([106,  73,  47, 168,  30,  69, 145,  72,  57, 172,  79,  21,  24, 140,
#          43,  74, 145,   3, 105, 103, 131, 142,   2,  35,   8, 105,  18, 118,
#           7, 101, 112,  62], device='cuda:0')
# loss ：
# tensor(0.5435, device='cuda:0')
# valid_data_j: 36
# Outputs :
# tensor([[ -65.0743,  -42.0845,  -49.5687,  ...,  -59.2082,  -27.8184,
#           -34.1217],
#         [ -73.2976,  -88.2992,  -91.4319,  ...,  -60.7704, -102.0059,
#           -94.5878],
#         [-129.2484,  -99.2465, -102.2741,  ...,  -78.9606,  -93.1160,
#           -97.0644],
#         ...,
#         [ -76.2714,  -72.2000,  -79.1375,  ...,  -45.3501,  -61.9483,
#           -61.9545],
#         [ -70.5706, -115.9765, -113.1444,  ..., -104.0501, -132.8494,
#          -125.9967],
#         [ -39.9778,  -57.2762,  -54.4895,  ...,  -89.4097,  -67.5464,
#           -65.7382]], device='cuda:0')
# labels ：
# tensor([ 72, 130,  29,  90,  27,  83, 127,  56,  46, 150,  88, 112,  24,   4,
#         134, 145, 146,  39, 103,  10,  56,  90, 139,  18,  57, 120, 115,  18,
#          41, 106, 131,  85], device='cuda:0')
# loss ：
# tensor(0.6152, device='cuda:0')
# valid_data_j: 37
# Outputs :
# tensor([[ -51.5749,  -63.2679,  -64.9628,  ..., -110.4184,  -58.4768,
#           -65.4304],
#         [  -4.0508,  -59.5682,  -51.2534,  ...,  -97.1747,  -78.8097,
#           -75.3466],
#         [ -77.2898, -104.3567, -118.3129,  ...,  -47.6647, -116.8031,
#          -106.4571],
#         ...,
#         [ -73.1866,  -54.1521,  -60.9781,  ...,  -59.0603,  -64.1989,
#           -61.1017],
#         [ -54.4953,  -56.8431,  -53.2590,  ...,  -67.5592,  -52.6432,
#           -57.1832],
#         [ -66.9952,  -60.2060,  -59.2164,  ...,  -37.7064,  -57.4938,
#           -58.8175]], device='cuda:0')
# labels ：
# tensor([ 66,  11, 114, 134, 148,  96,  18, 150, 106,  56, 100,   9,  18, 115,
#          11,  28, 150, 110, 172,  78,  38, 134,  67,   4,  15, 134, 110, 107,
#          48,  25,  36,  97], device='cuda:0')
# loss ：
# tensor(0.5751, device='cuda:0')
# valid_data_j: 38
# Outputs :
# tensor([[-88.1310, -47.9382, -57.1013,  ...,  -6.7511, -51.9388, -45.7123],
#         [-63.4998, -58.6100, -45.4858,  ..., -79.5957, -81.9254, -75.0351],
#         [-86.3868, -62.9541, -70.6482,  ..., -34.9066, -52.0224, -52.2807],
#         ...,
#         [-95.8099,  -4.8513,  -1.3311,  ..., -38.5624, -15.5502,  -9.7861],
#         [-90.7760, -79.8517, -79.4836,  ..., -61.9636, -87.2757, -85.4728],
#         [-43.4066, -70.2130, -80.0663,  ..., -67.7846, -80.9656, -74.0605]],
#        device='cuda:0')
# labels ：
# tensor([169,  10, 104,  60,  69, 154,  93, 146,  24,  97,  46,  95,  36, 153,
#          49,  89, 171,   6,  22, 170, 127,  68, 169,  89, 172, 126,  86, 156,
#          55,   3,  28,  47], device='cuda:0')
# loss ：
# tensor(0.6526, device='cuda:0')
# valid_data_j: 39
# Outputs :
# tensor([[-103.8690, -134.1494, -133.2589,  ..., -114.2690, -145.2567,
#          -139.2119],
#         [ -73.2976,  -88.2992,  -91.4319,  ...,  -60.7704, -102.0059,
#           -94.5878],
#         [ -67.3977,  -35.1218,  -23.4045,  ...,  -64.8027,  -54.9433,
#           -48.2363],
#         ...,
#         [ -83.6377,  -59.8251,  -64.3745,  ...,  -54.8989,  -65.2554,
#           -64.0362],
#         [ -72.7797,  -84.8659,  -75.6451,  ...,  -62.3321,  -95.8525,
#           -91.2270],
#         [ -65.1061,  -48.1163,  -52.3769,  ...,  -52.4457,  -32.1908,
#           -38.6331]], device='cuda:0')
# labels ：
# tensor([134, 130,   6, 109,  98, 172,  26,  15, 124,  52,  28,  62, 134, 143,
#          81, 147, 127,  69,  60,  89,  16, 118, 133,  50,   7, 164, 105,  88,
#          73,  26, 158,  68], device='cuda:0')
# loss ：
# tensor(0.6099, device='cuda:0')
# valid_data_j: 40
# Outputs :
# tensor([[ -62.5321,  -44.4315,  -31.2271,  ...,  -73.0370,  -65.0567,
#           -59.1030],
#         [ -77.6492,   -8.7408,  -13.4490,  ...,  -32.2414,   -0.3112,
#            -2.3555],
#         [ -82.7500, -116.7546, -124.9256,  ..., -110.2343, -126.8598,
#          -120.3109],
#         ...,
#         [ -72.5387,  -99.0479, -112.2882,  ...,  -44.7140, -109.1585,
#          -100.1652],
#         [ -69.4935,  -76.7429,  -85.2581,  ...,  -70.8396,  -89.1500,
#           -82.7354],
#         [-135.6729, -166.6198, -166.3738,  ..., -138.2876, -179.2037,
#          -171.8658]], device='cuda:0')
# labels ：
# tensor([  7, 171,  42, 111, 128, 131, 156,  28,  51,  97,  40, 118, 168,   9,
#           7,  94,   7, 157, 151,  41,  34,  60, 145, 163,  54,  44,  12, 128,
#         128, 114,  43, 132], device='cuda:0')
# loss ：
# tensor(0.3517, device='cuda:0')
# valid_data_j: 41
# Outputs :
# tensor([[-6.9948e+01, -9.9616e+01, -1.0220e+02,  ..., -9.3813e+01,
#          -9.5955e+01, -9.4301e+01],
#         [-5.1788e+01, -8.2072e+01, -8.0156e+01,  ..., -1.0130e+02,
#          -8.0160e+01, -8.1034e+01],
#         [-3.6670e+01, -7.3524e+01, -6.9451e+01,  ..., -1.0986e+02,
#          -8.2699e+01, -8.3833e+01],
#         ...,
#         [-6.0393e+01, -1.4101e+02, -1.2897e+02,  ..., -1.3277e+02,
#          -1.6005e+02, -1.5313e+02],
#         [-7.0312e+01, -2.9974e+01, -3.8196e+01,  ..., -1.2664e-02,
#          -3.1567e+01, -2.6298e+01],
#         [-9.5131e+01, -6.4733e+01, -6.7928e+01,  ..., -9.5919e+01,
#          -5.1979e+01, -6.0687e+01]], device='cuda:0')
# labels ：
# tensor([108,  63,  87,  32,  27, 126, 143,  35,  92, 122,  40, 149, 129, 141,
#          31,  35,   3,  33,  88,  55,   8,  56,  26,  50, 131,  43,  70, 121,
#         143, 139, 170, 100], device='cuda:0')
# loss ：
# tensor(1.6620, device='cuda:0')
# valid_data_j: 42
# Outputs :
# tensor([[ -76.2714,  -72.2000,  -79.1375,  ...,  -45.3501,  -61.9483,
#           -61.9545],
#         [ -73.2976,  -88.2992,  -91.4319,  ...,  -60.7704, -102.0059,
#           -94.5878],
#         [ -95.7121,  -69.6543,  -74.4385,  ...,  -25.2347,  -75.2713,
#           -69.0423],
#         ...,
#         [ -56.0549,  -76.5076,  -62.5802,  ..., -106.8594,  -90.3224,
#           -90.1869],
#         [ -28.3235,  -68.7757,  -71.6510,  ...,  -79.3828,  -86.9934,
#           -80.9800],
#         [ -99.3542, -109.9240, -113.9377,  ..., -115.0450, -103.6930,
#          -107.6740]], device='cuda:0')
# labels ：
# tensor([106, 130, 121, 115, 138,  16,  29,  38,  52, 161, 154, 118, 112,  63,
#          26,  97, 111, 148, 138,  77, 160,  11, 145,   8,  63,  46, 168, 155,
#          79, 149,  82,  39], device='cuda:0')
# loss ：
# tensor(0.3701, device='cuda:0')
# valid_data_j: 43
# Outputs :
# tensor([[ -88.9923,  -47.4286,  -42.0025,  ...,  -43.2595,  -66.2897,
#           -56.8304],
#         [ -60.6929,  -93.8652,  -89.2468,  ..., -106.2612, -104.9235,
#          -103.8387],
#         [ -83.8832,  -19.6669,  -11.2065,  ...,  -51.9650,  -36.0625,
#           -29.2378],
#         ...,
#         [ -65.5693,  -67.4664,  -63.6391,  ...,  -73.7634,  -63.7410,
#           -68.3932],
#         [ -57.3552,  -74.3664,  -75.9114,  ..., -126.8775,  -69.7765,
#           -77.4104],
#         [ -88.6668, -162.2637, -151.9162,  ..., -132.2285, -182.0572,
#          -171.8447]], device='cuda:0')
# labels ：
# tensor([ 16,  78,   5, 121, 109, 137, 150, 161,  63, 158,  19, 155, 155,  98,
#         120,  23,  96, 154,  94,  31,  45,  89,   1,  96,  27,  32,  64,  22,
#         111,  32,  66, 138], device='cuda:0')
# loss ：
# tensor(0.6953, device='cuda:0')
# valid_data_j: 44
# Outputs :
# tensor([[ -34.9939,  -99.1763,  -88.5857,  ..., -129.1736, -113.5000,
#          -111.0824],
#         [ -72.2596,  -71.9664,  -78.0832,  ...,  -77.2714,  -51.9900,
#           -61.6536],
#         [ -85.2286, -107.6582,  -95.1594,  ...,  -82.7444, -122.4125,
#          -116.8855],
#         ...,
#         [ -19.6285,  -78.1242,  -79.5638,  ...,  -93.3064,  -94.8952,
#           -88.2519],
#         [ -95.4273,  -86.5495,  -90.1012,  ...,  -84.8660,  -65.6956,
#           -75.8573],
#         [ -70.5706, -115.9765, -113.1444,  ..., -104.0501, -132.8494,
#          -125.9967]], device='cuda:0')
# labels ：
# tensor([ 60,  67, 159,  75, 128,  33,  43, 116,  51,  90,   0,  62,  74,  55,
#         101, 109, 163, 153, 164,  53,  46, 162,  20,  28, 156,  59, 169, 102,
#          59,  52,  92, 131], device='cuda:0')
# loss ：
# tensor(0.4258, device='cuda:0')
# valid_data_j: 45
# Outputs :
# tensor([[ -83.6118, -115.9998, -114.9869,  ..., -125.4283, -111.9285,
#          -114.7492],
#         [ -65.6859,   -3.9197,   -6.9595,  ...,  -23.0260,   -0.7564,
#            -0.7495],
#         [ -82.8537,  -18.7329,  -23.2870,  ...,  -25.7406,  -10.8383,
#           -13.2038],
#         ...,
#         [-102.0423,  -85.1209,  -87.2988,  ...,  -88.5129,  -80.6599,
#           -85.5788],
#         [ -90.0837,  -82.2869,  -87.6017,  ...,  -41.4170,  -92.8866,
#           -85.3013],
#         [ -37.1904, -100.2485,  -99.7056,  ...,  -74.6185, -121.4165,
#          -111.7977]], device='cuda:0')
# labels ：
# tensor([ 74, 172, 144,  95,  19, 121,  98,  77, 166,  30,  53, 172,  24,  32,
#          60, 159,  18, 164,   6,  71,  88,  12,  24, 115,  86,  18, 169, 157,
#         155,  30, 127, 162], device='cuda:0')
# loss ：
# tensor(0.4861, device='cuda:0')
# valid_data_j: 46
# Outputs :
# tensor([[ -62.4027, -125.3974, -119.4424,  ..., -143.6769, -134.4391,
#          -132.5229],
#         [ -27.3646,  -64.7144,  -67.3538,  ...,  -74.7686,  -81.5672,
#           -76.1649],
#         [ -93.8782,  -83.8641,  -82.8378,  ...,  -65.2267,  -90.9365,
#           -89.5293],
#         ...,
#         [ -71.6729,  -85.5728,  -67.7481,  ..., -113.0410, -112.7904,
#          -105.9331],
#         [ -65.1937,  -13.1113,  -19.2909,  ...,  -23.1147,   -4.8162,
#            -7.4841],
#         [ -42.1828,  -64.1511,  -64.5412,  ...,  -85.8874,  -61.4020,
#           -64.3669]], device='cuda:0')
# labels ：
# tensor([ 59,  81,  28,  17,  40,   4, 102,  29, 115,  85, 126, 147,  38,  55,
#         104, 145, 121, 149,   8,  43, 156, 104,  22, 151, 156,  87,  87,  85,
#         162,   9, 166,  64], device='cuda:0')
# loss ：
# tensor(0.7564, device='cuda:0')
# valid_data_j: 47
# Outputs :
# tensor([[ -62.5321,  -44.4315,  -31.2271,  ...,  -73.0370,  -65.0567,
#           -59.1030],
#         [ -71.2330, -131.4654, -119.9210,  ..., -111.3655, -146.4031,
#          -140.1863],
#         [ -40.7112, -112.6207,  -97.5612,  ..., -139.3299, -129.2859,
#          -126.4671],
#         ...,
#         [-111.8225,  -88.2724,  -91.9432,  ...,  -46.3235, -100.2844,
#           -90.8457],
#         [ -75.9817,  -86.4021,  -95.0082,  ...,  -24.3958,  -87.7721,
#           -82.6409],
#         [ -68.9914,  -71.3363,  -71.1620,  ...,  -80.3917,  -64.3120,
#           -69.1927]], device='cuda:0')
# labels ：
# tensor([  7, 138, 142,  29,  33,  47,  47, 144, 134, 152, 170,  56,  63,  26,
#         143, 116,  96, 107, 133,  82, 119,  76,  57,  42,  71, 131,  69,  20,
#         159, 123, 116,  35], device='cuda:0')
# loss ：
# tensor(0.5905, device='cuda:0')
# valid_data_j: 48
# Outputs :
# tensor([[ -88.1310,  -47.9382,  -57.1013,  ...,   -6.7511,  -51.9388,
#           -45.7123],
#         [ -67.0226,  -19.5031,  -11.7115,  ...,  -47.5008,  -34.8072,
#           -28.6341],
#         [ -57.9766,  -40.4413,  -34.1777,  ...,  -44.1819,  -60.5469,
#           -51.5456],
#         ...,
#         [ -57.7384, -111.0205, -111.5618,  ...,  -94.3523, -112.2283,
#          -109.2961],
#         [ -49.2615,  -38.2423,  -46.4846,  ...,  -50.6362,  -46.6837,
#           -44.5524],
#         [ -26.8759,  -73.4315,  -70.2199,  ...,  -86.7330,  -82.2142,
#           -78.0452]], device='cuda:0')
# labels ：
# tensor([169,   5,  14,  40, 156,  61,  78, 144,  89,  97, 121,  67,   9, 122,
#          32, 144,  15,  94,  47, 103,  78,  23,  59,  21,  90,  42,  62, 109,
#          45, 110,  24,  57], device='cuda:0')
# loss ：
# tensor(0.9362, device='cuda:0')
# valid_data_j: 49
# Outputs :
# tensor([[-107.9838,  -84.1671,  -86.3236,  ...,  -76.7537,  -82.0723,
#           -84.9909],
#         [ -65.7424,  -50.8810,  -57.1529,  ...,  -55.2481,  -67.7282,
#           -61.2152],
#         [ -95.1311,  -64.7334,  -67.9280,  ...,  -95.9190,  -51.9787,
#           -60.6870],
#         ...,
#         [ -80.5944,  -74.8810,  -74.3532,  ..., -106.8305,  -61.4536,
#           -69.0162],
#         [ -68.0591, -101.7481,  -99.8267,  ...,  -88.2550, -117.3739,
#          -110.8855],
#         [  -3.4697,  -61.5770,  -55.5684,  ...,  -95.3227,  -82.2592,
#           -77.7070]], device='cuda:0')
# labels ：
# tensor([ 29,  21, 100,  40,  60, 114,   6,  30, 156,  87,   9,  40, 130,  47,
#          54,  42,  66,  24,  84,   1, 167, 140, 150, 135,  38, 110, 141,  69,
#         166,  90, 131,  22], device='cuda:0')
# loss ：
# tensor(1.3198, device='cuda:0')
# valid_data_j: 50
# Outputs :
# tensor([[-120.8501,  -86.8355,  -93.9951,  ...,  -29.9631,  -91.6868,
#           -84.6871],
#         [ -68.7770,  -85.3177,  -90.3802,  ...,  -84.5180,  -99.6956,
#           -94.5238],
#         [ -85.8671,  -92.2388,  -94.9520,  ...,  -88.6202, -104.5284,
#           -97.5625],
#         ...,
#         [ -88.6668, -162.2637, -151.9162,  ..., -132.2285, -182.0572,
#          -171.8447],
#         [ -91.0841,  -38.8489,  -40.7185,  ...,  -32.7153,  -52.5706,
#           -43.5984],
#         [ -72.1982,  -88.5882,  -89.7128,  ...,  -89.3454,  -93.1563,
#           -93.7719]], device='cuda:0')
# labels ：
# tensor([121,  80,  41,  47,  50, 168, 144,  97,  50,  37, 153, 143,  79,  45,
#           7,  64, 159,  19, 156,  12,   4, 108,  16, 108,  17,  10, 159, 152,
#         130, 138,  17,  79], device='cuda:0')
# loss ：
# tensor(0.8600, device='cuda:0')
# valid_data_j: 51
# Outputs :
# tensor([[ -79.2919, -105.6880,  -99.1954,  ...,  -91.8416, -107.0552,
#          -108.6886],
#         [ -61.4872,  -76.4035,  -82.4577,  ...,  -70.7727,  -86.3235,
#           -80.6892],
#         [ -59.7566,  -37.0495,  -25.8061,  ...,  -63.4893,  -55.7137,
#           -49.8852],
#         ...,
#         [ -97.8140,  -13.7957,   -7.1129,  ...,  -48.7704,  -28.8175,
#           -21.9002],
#         [ -39.2252,  -66.7680,  -76.7324,  ...,  -66.3336,  -78.9353,
#           -71.6066],
#         [ -51.7883,  -82.0716,  -80.1563,  ..., -101.2954,  -80.1599,
#           -81.0337]], device='cuda:0')
# labels ：
# tensor([ 95,  43,   6, 132, 146,  80, 119,   6,  56, 112,  69,   6,  89,  55,
#         172,  85, 106,  79, 150, 144,  22,  76,   5,  75,   1,  13, 150, 139,
#         150,   4,  46,  63], device='cuda:0')
# loss ：
# tensor(0.7242, device='cuda:0')
# valid_data_j: 52
# Outputs :
# tensor([[-88.1310, -47.9382, -57.1013,  ...,  -6.7511, -51.9388, -45.7123],
#         [-80.8760, -65.9633, -74.6597,  ..., -72.5101, -87.7467, -79.4823],
#         [-61.7286, -43.5910, -49.5265,  ..., -25.0082, -36.0559, -36.1327],
#         ...,
#         [-39.4027, -53.3753, -51.6538,  ..., -77.3163, -61.6412, -60.1284],
#         [-63.5857, -86.0884, -80.9209,  ..., -74.1287, -87.1504, -88.4609],
#         [-45.6298, -58.8939, -48.9375,  ..., -76.6011, -69.6650, -68.9168]],
#        device='cuda:0')
# labels ：
# tensor([169,  23, 104, 158,  74, 132,  62,  51,   3, 145,  19,  91, 126,  96,
#          54,  10,  90,  87,  27, 147, 127, 165,  88, 158,   3,  80, 169, 149,
#          34,  85,  95, 151], device='cuda:0')
# loss ：
# tensor(0.6882, device='cuda:0')
# valid_data_j: 53
# Outputs :
# tensor([[ -60.2868,  -79.6335,  -78.7766,  ...,  -81.7192,  -85.9898,
#           -85.1536],
#         [-101.6187,  -67.1398,  -76.5129,  ...,  -14.8742,  -61.5255,
#           -60.1715],
#         [ -68.0591, -101.7481,  -99.8267,  ...,  -88.2550, -117.3739,
#          -110.8855],
#         ...,
#         [ -53.7196, -111.0986, -106.0297,  ..., -127.7403, -118.9190,
#          -117.0660],
#         [ -69.3231,  -71.9149,  -68.5884,  ...,  -80.9909,  -66.1419,
#           -71.8071],
#         [ -33.9786,  -89.0603,  -88.6024,  ..., -101.8250, -100.0152,
#           -94.8826]], device='cuda:0')
# labels ：
# tensor([ 76, 119, 131, 151,  90,  30, 112, 159,  59,  28, 126,  46,  42, 161,
#          10,  76, 172,  21,  40, 156,   0,   6, 169,  80,  40, 156, 100,  54,
#           1,  59,  32,  53], device='cuda:0')
# loss ：
# tensor(1.0347, device='cuda:0')
# valid_data_j: 54
# Outputs :
# tensor([[ -80.7837,  -95.8329,  -98.3082,  ...,  -88.3300, -105.5765,
#          -102.3863],
#         [ -34.4767, -112.6220,  -99.8028,  ..., -143.4749, -130.4881,
#          -126.5144],
#         [ -60.2868,  -79.6335,  -78.7766,  ...,  -81.7192,  -85.9898,
#           -85.1536],
#         ...,
#         [-118.9867,  -99.4947, -106.1961,  ...,  -60.9334,  -75.5171,
#           -85.0170],
#         [ -11.8012,  -66.6266,  -67.5253,  ...,  -81.8505,  -88.5965,
#           -82.0443],
#         [-112.7209,  -81.7591,  -87.4318,  ...,  -75.0409,  -88.2046,
#           -87.4265]], device='cuda:0')
# labels ：
# tensor([ 79, 143,  76, 170, 100,  54,  18,  23,  92,  87,  34,  84, 139, 168,
#          79,  48,  32, 126,  70,  12, 117,  60, 119, 100, 161, 128, 158,  90,
#         144,  99,  22,  27], device='cuda:0')
# loss ：
# tensor(1.1926, device='cuda:0')
# valid_data_j: 55
# Outputs :
# tensor([[ -60.6929,  -93.8652,  -89.2468,  ..., -106.2612, -104.9235,
#          -103.8387],
#         [ -62.8338,  -56.8666,  -56.6078,  ...,  -62.2447,  -55.3371,
#           -55.9775],
#         [ -79.7347, -102.4487, -107.9570,  ...,  -76.2285,  -90.7232,
#           -92.5297],
#         ...,
#         [ -68.5795, -115.2966, -124.5199,  ...,  -70.4879, -118.7515,
#          -113.7594],
#         [ -60.0517, -114.7431,  -99.2758,  ..., -122.5058, -134.2722,
#          -130.4635],
#         [  -9.8513,  -58.6595,  -58.8907,  ...,  -76.6145,  -78.1656,
#           -72.6661]], device='cuda:0')
# labels ：
# tensor([ 78,  37, 107, 101,  49, 111,  55, 157, 116,  91,  99,  56, 169,  18,
#         102, 136, 149, 168,  25,  13,  99,  29,  27, 101, 127,  79,  34,   4,
#          33, 112, 154,  22], device='cuda:0')
# loss ：
# tensor(0.3278, device='cuda:0')
# valid_data_j: 56
# Outputs :
# tensor([[ -82.1918, -101.8466, -105.1991,  ...,  -97.4107, -112.1041,
#          -106.0155],
#         [ -83.1043, -107.3231, -112.5344,  ...,  -76.8645,  -95.5575,
#           -97.5155],
# ...
# loss ：
# tensor(0.7494, device='cuda:0')
# valid_data_j: 1302
# Outputs :
# tensor([[ -29.5649,  -87.3669,  -87.7846,  ...,  -67.1686, -106.4929,
#           -98.1369],
#         [ -85.8671,  -92.2388,  -94.9520,  ...,  -88.6202, -104.5284,
#           -97.5625],
#         [-110.0464,  -74.0058,  -83.3805,  ...,  -35.4447,  -57.8598,
#           -60.5740],
#         ...,
#         [ -92.0600, -160.9117, -149.3996,  ..., -129.3197, -180.2719,
#          -170.5732],
#         [ -70.7123,  -29.1167,  -31.5295,  ...,  -42.2080,  -46.8451,
#           -37.6386],
#         [ -62.2821, -104.2250, -101.4679,  ...,  -93.8715, -119.7938,
#          -113.4757]], device='cuda:0')
# labels ：
# tensor([162,  41, 103, 162, 117, 150, 160, 164,  75, 151,  99, 163,  19, 146,
#           1, 165, 165,  92, 163,  19, 145,  96,  88,  62,  97,  84,  33,  19,
#         150, 137,  19, 131], device='cuda:0')
# loss ：
# tensor(0.5111, device='cuda:0')
# valid_data_j: 1303
# Outputs :
# tensor([[-25.2670, -54.9126, -63.3045,  ..., -56.9501, -68.3536, -61.5720],
#         [-73.6584, -91.0801, -89.8354,  ..., -83.8258, -82.4904, -87.8375],
#         [-54.4953, -56.8431, -53.2590,  ..., -67.5592, -52.6432, -57.1832],
#         ...,
#         [-84.7023, -47.4602, -56.8140,  ...,  -6.7048, -51.5612, -45.3573],
#         [-58.9194, -33.7401, -33.7768,  ..., -69.6550, -26.5026, -32.0091],
#         [-37.8488, -68.9954, -79.2486,  ..., -68.9747, -82.6292, -74.8848]],
#        device='cuda:0')
# labels ：
# tensor([ 50,  92,  36,  27, 104,  46, 107, 106, 132, 120,  61,  45, 170, 163,
#         116, 147,  82,  57,  64,  76, 130, 137, 160,  81, 142,  23,  37,  76,
#          37, 169, 100,  49], device='cuda:0')
# loss ：
# tensor(0.4766, device='cuda:0')
# valid_data_j: 1304
# Outputs :
# tensor([[-113.5460, -110.8323, -112.2923,  ...,  -61.8143, -125.5084,
#          -116.2112],
#         [ -85.8175,  -63.8030,  -69.9243,  ...,  -65.0543,  -76.4569,
#           -71.9312],
#         [ -57.7888,  -50.3926,  -40.4775,  ...,  -64.8287,  -73.2331,
#           -64.7902],
#         ...,
#         [ -69.1752,  -98.5541,  -98.6519,  ...,  -78.7602, -101.1782,
#           -97.4848],
#         [-110.9096,  -76.9450,  -84.9164,  ...,  -23.7161,  -75.0275,
#           -71.8637],
#         [ -24.3864,  -93.4133,  -93.1443,  ..., -114.1584, -112.1524,
#          -104.8182]], device='cuda:0')
# labels ：
# tensor([126,  25,  12,  66,  31,  91,  30,  33,   2,  62,  89, 144,  73, 153,
#         107, 142,  84,  91,  81, 130,  51,   3,  90,  51,  55,  39,  35, 149,
#         154, 109, 120,  53], device='cuda:0')
# loss ：
# tensor(0.5011, device='cuda:0')
# valid_data_j: 1305
# Outputs :
# tensor([[ -88.3640, -114.3408, -104.6302,  ...,  -76.4362, -128.4352,
#          -121.9006],
#         [ -68.6958,  -85.7002,  -88.9157,  ...,  -98.7864,  -76.2452,
#           -81.0311],
#         [ -74.3845,  -78.9536,  -90.4066,  ...,  -28.2158,  -85.2565,
#           -77.6796],
#         ...,
#         [ -39.2252,  -66.7680,  -76.7324,  ...,  -66.3336,  -78.9353,
#           -71.6066],
#         [  -3.4697,  -61.5770,  -55.5684,  ...,  -95.3227,  -82.2592,
#           -77.7070],
#         [ -47.7588,  -81.4037,  -78.9529,  ..., -101.9779,  -81.4790,
#           -82.3216]], device='cuda:0')
# labels ：
# tensor([159,  73, 115, 125, 162,  67, 171, 108,  55,  77,  76,  48, 128,  61,
#          65, 107, 155,  27, 118, 153,  68, 131, 145,   0,  63,  91, 153, 115,
#          86,  46,  22,  63], device='cuda:0')
# loss ：
# tensor(0.5643, device='cuda:0')
# valid_data_j: 1306
# Outputs :
# tensor([[ -19.6285,  -78.1242,  -79.5638,  ...,  -93.3064,  -94.8952,
#           -88.2519],
#         [ -89.3596,  -48.0506,  -57.2739,  ...,   -6.5546,  -51.9384,
#           -45.6828],
#         [-131.2520, -163.3001, -163.4418,  ..., -135.0128, -175.3355,
#          -168.0396],
#         ...,
#         [ -72.5387,  -99.0479, -112.2882,  ...,  -44.7140, -109.1585,
#          -100.1652],
#         [ -76.2714,  -72.2000,  -79.1375,  ...,  -45.3501,  -61.9483,
#           -61.9545],
#         [-100.2883,  -92.3576,  -92.1173,  ...,  -54.4081, -108.0811,
#           -98.8013]], device='cuda:0')
# labels ：
# tensor([ 52, 169, 132,  30,  84,  74, 142,  39, 151, 136,  38, 147, 136, 107,
#         155,  15,  56,  20, 120,  65,  96, 131,  86, 133,   3,  59,  42,  32,
#         146, 114, 106, 125], device='cuda:0')
# loss ：
# tensor(0.7447, device='cuda:0')
# valid_data_j: 1307
# Outputs :
# tensor([[ -96.2373,  -68.8793,  -76.0270,  ...,  -76.7109,  -42.4589,
#           -53.5264],
#         [ -62.8338,  -56.8666,  -56.6078,  ...,  -62.2447,  -55.3371,
#           -55.9775],
#         [ -35.1950,  -74.8529,  -61.5797,  ..., -104.1382,  -89.6864,
#           -88.7099],
#         ...,
#         [ -69.1495,  -77.6109,  -82.7359,  ...,  -46.7911,  -89.2195,
#           -82.0036],
#         [ -85.2286, -107.6582,  -95.1594,  ...,  -82.7444, -122.4125,
#          -116.8855],
#         [-110.9096,  -76.9450,  -84.9164,  ...,  -23.7161,  -75.0275,
#           -71.8637]], device='cuda:0')
# labels ：
# tensor([ 91,  37, 147,  58,  77,  93, 100, 120, 143,  51, 121,  40,  16, 124,
#         131,  62,  88,   6,  27,  41,  52,  68, 106,  51, 122, 137,  28, 137,
#          15, 129, 159, 120], device='cuda:0')
# loss ：
# tensor(0.5933, device='cuda:0')
# valid_data_j: 1308
# Outputs :
# tensor([[ -76.9083,  -83.4753,  -96.0160,  ...,  -29.9607,  -89.3022,
#           -81.6617],
#         [ -68.6840,  -43.1110,  -51.1595,  ...,  -60.1694,  -28.8085,
#           -34.9538],
#         [ -36.6699,  -73.5237,  -69.4505,  ..., -109.8553,  -82.6988,
#           -83.8331],
#         ...,
#         [  -9.5336,  -48.7370,  -55.4692,  ...,  -53.4519,  -66.5917,
#           -59.0327],
#         [ -51.5749,  -63.2679,  -64.9628,  ..., -110.4184,  -58.4768,
#           -65.4304],
#         [ -83.6377,  -59.8251,  -64.3745,  ...,  -54.8989,  -65.2554,
#           -64.0362]], device='cuda:0')
# labels ：
# tensor([115,  71,  87,   1, 131, 139,  84, 108,  29, 167, 148, 122,  97, 105,
#         108,   1,   5,  21,  37, 102,  36, 161, 144,   6,  37, 107,  71,  69,
#          74,  51,  66,  26], device='cuda:0')
# loss ：
# tensor(0.5887, device='cuda:0')
# valid_data_j: 1309
# Outputs :
# tensor([[ -53.9001,  -79.3864,  -80.7914,  ...,  -73.3542,  -76.8718,
#           -75.6977],
#         [ -13.5448,  -50.0196,  -56.0038,  ...,  -55.7375,  -61.2085,
#           -56.6444],
#         [ -51.9034, -100.3388,  -87.3594,  ..., -125.1291, -112.0929,
#          -110.3322],
#         ...,
#         [ -68.5795, -115.2966, -124.5199,  ...,  -70.4879, -118.7515,
#          -113.7594],
#         [ -37.3423,  -89.4971,  -89.6221,  ...,  -99.7599,  -99.3905,
#           -94.1992],
#         [ -80.8760,  -92.6675,  -93.3264,  ...,  -94.9414,  -96.5572,
#           -94.1814]], device='cuda:0')
# labels ：
# tensor([108,  51, 146,  65, 130, 120,  87,  80, 151,  38,  73,   2, 149,   6,
#          56,  12,   0, 128, 138,  48, 112,  91,  57, 158,  15,  95, 121,  98,
#          82, 112,  54,  40], device='cuda:0')
# loss ：
# tensor(0.7502, device='cuda:0')
# valid_data_j: 1310
# Outputs :
# tensor([[ -70.5706, -115.9765, -113.1444,  ..., -104.0501, -132.8494,
#          -125.9967],
#         [ -75.3035,  -99.6668,  -91.2613,  ...,  -67.4014, -112.2111,
#          -106.4858],
#         [ -45.7215,  -37.1733,  -46.2849,  ...,  -49.0781,  -42.9824,
#           -42.1365],
#         ...,
#         [ -42.8001,  -53.3892,  -54.6201,  ..., -100.6993,  -53.0140,
#           -58.1097],
#         [ -73.7227,  -93.7334,  -91.7617,  ...,  -84.8585,  -87.0324,
#           -91.7679],
#         [ -79.4687,   -3.6790,   -6.5027,  ...,  -26.9933,   -0.9876,
#            -0.5188]], device='cuda:0')
# labels ：
# tensor([131, 159,  24,  84, 166, 140,  56,   4,  47, 137, 103,   8,  63,  55,
#          79, 162, 114,  92,  85,  97, 101,  58,  11,  45,   6, 121,  97, 156,
#         139,  66,  94, 172], device='cuda:0')
# loss ：
# tensor(0.6518, device='cuda:0')
# valid_data_j: 1311
# Outputs :
# tensor([[ -71.9540,  -69.3362,  -53.8280,  ...,  -91.9781,  -95.8262,
#           -88.2691],
#         [ -61.4872,  -76.4035,  -82.4577,  ...,  -70.7727,  -86.3235,
#           -80.6892],
#         [ -70.9536,  -57.3273,  -69.1525,  ...,  -49.0332,  -43.2591,
#           -48.3433],
#         ...,
#         [ -82.4145,  -14.7152,  -21.4957,  ...,  -32.4211,   -2.0164,
#            -5.9844],
#         [ -49.2615,  -38.2423,  -46.4846,  ...,  -50.6362,  -46.6837,
#           -44.5524],
#         [-106.3059,  -82.7823,  -92.4057,  ...,  -43.0143,  -59.1123,
#           -67.1275]], device='cuda:0')
# labels ：
# tensor([ 10,  43,  70, 169,  76,  74,  32, 120,  13,  44,  68, 143, 150,  81,
#          44,  46, 165,  37,  82, 168, 150, 162,   5,  96, 147, 140, 141,  58,
#         121, 166,  24, 102], device='cuda:0')
# loss ：
# tensor(0.2784, device='cuda:0')
# valid_data_j: 1312
# Outputs :
# tensor([[ -36.6699,  -73.5237,  -69.4505,  ..., -109.8553,  -82.6988,
#           -83.8331],
#         [ -82.3091,  -97.9468, -100.5022,  ...,  -90.5997, -107.6080,
#          -104.5567],
#         [ -16.0578,  -61.9466,  -70.1355,  ...,  -64.6297,  -76.2235,
#           -70.1605],
#         ...,
#         [ -24.6757,  -52.7241,  -51.9019,  ...,  -71.3132,  -62.9899,
#           -61.7668],
#         [ -45.1594,  -61.0257,  -61.3743,  ...,  -55.1122,  -56.9897,
#           -58.8308],
#         [ -50.7181,  -85.8765,  -71.2357,  ..., -110.1529,  -99.7539,
#           -98.7987]], device='cuda:0')
# labels ：
# tensor([ 87,  79,  51,  36,  39,   9,  73,  13,  70, 119,  28,  69, 152,  44,
#         141, 106,  75, 114, 136, 118, 110, 128,  14, 143, 129, 154,   9, 133,
#          50,  83,  93, 147], device='cuda:0')
# loss ：
# tensor(0.7982, device='cuda:0')
# valid_data_j: 1313
# Outputs :
# tensor([[ -40.7225,  -81.2611,  -66.5675,  ..., -116.3760, -100.1006,
#           -98.5624],
#         [-102.9590,  -66.6195,  -80.1764,  ...,  -81.7232,  -36.7719,
#           -49.0501],
#         [ -54.1696,  -58.5630,  -68.5828,  ...,  -19.5933,  -67.4097,
#           -60.2566],
#         ...,
#         [ -95.8099,   -4.8513,   -1.3311,  ...,  -38.5624,  -15.5502,
#            -9.7861],
#         [ -59.2957,  -64.2367,  -72.9447,  ...,  -19.6524,  -67.4319,
#           -62.3790],
#         [ -34.9939,  -99.1763,  -88.5857,  ..., -129.1736, -113.5000,
#          -111.0824]], device='cuda:0')
# labels ：
# tensor([148,  69, 168,  50, 118, 118,  33, 136, 123,  59,  19, 141,  92,  32,
#          99,  64, 159, 139, 132, 116,  22,  94,  29, 120,  72, 129,  60,  79,
#          42,   3, 116,  60], device='cuda:0')
# loss ：
# tensor(0.6755, device='cuda:0')
# valid_data_j: 1314
# Outputs :
# tensor([[-8.9360e+01, -4.8051e+01, -5.7274e+01,  ..., -6.5546e+00,
#          -5.1938e+01, -4.5683e+01],
#         [-1.1281e+02, -7.7913e+01, -8.5441e+01,  ..., -2.4519e+01,
#          -7.8274e+01, -7.3900e+01],
#         [-9.3019e+01, -3.1963e+01, -3.3535e+01,  ..., -3.0302e+01,
#          -2.5801e+01, -2.8409e+01],
#         ...,
#         [-6.1205e+01, -2.0092e+01, -2.9394e+01,  ..., -4.0332e+01,
#          -6.6456e+00, -1.2405e+01],
#         [-9.2801e+01, -1.3734e+02, -1.3164e+02,  ..., -1.4659e+02,
#          -1.4540e+02, -1.4391e+02],
#         [-6.2282e+01, -2.6854e+01, -3.4890e+01,  ..., -2.3799e-03,
#          -2.8301e+01, -2.3336e+01]], device='cuda:0')
# labels ：
# tensor([169, 120, 133, 149,  38, 125,  95, 106, 172,  60, 152,  48, 162,  21,
#         151,   7, 101,  22,  58, 156,   2, 169,  81, 170,  43,  48,  67,  88,
#         151, 155,  75, 170], device='cuda:0')
# loss ：
# tensor(0.5111, device='cuda:0')
# valid_data_j: 1315
# Outputs :
# tensor([[ -39.2252,  -66.7680,  -76.7324,  ...,  -66.3336,  -78.9353,
#           -71.6066],
#         [ -59.2957,  -64.2367,  -72.9447,  ...,  -19.6524,  -67.4319,
#           -62.3790],
#         [-102.0423,  -85.1209,  -87.2988,  ...,  -88.5129,  -80.6599,
#           -85.5788],
#         ...,
#         [ -82.1918, -101.8466, -105.1991,  ...,  -97.4107, -112.1041,
#          -106.0155],
#         [ -54.0213,  -72.1834,  -83.4292,  ...,  -35.1903,  -70.5584,
#           -68.6021],
#         [ -43.4066,  -70.2130,  -80.0663,  ...,  -67.7846,  -80.9656,
#           -74.0605]], device='cuda:0')
# labels ：
# tensor([ 46, 116,  30, 116,  66, 124,  51,  43,   9,  25,  94, 129,  14,  46,
#         160, 140, 141,  37, 127, 168,  86,  61,  54, 110,  41, 150, 100,  36,
#          81,  42, 113,  47], device='cuda:0')
# loss ：
# tensor(0.7099, device='cuda:0')
# valid_data_j: 1316
# Outputs :
# tensor([[ -31.5031,  -61.8415,  -70.5879,  ...,  -65.6960,  -75.7640,
#           -68.6650],
#         [ -52.6818,  -53.5549,  -50.0519,  ...,  -63.0964,  -57.3456,
#           -56.8170],
#         [ -62.4422,  -84.1630,  -87.6673,  ...,  -81.9233,  -80.0693,
#           -78.8594],
#         ...,
#         [ -24.6425, -101.8424, -102.0027,  ..., -124.9681, -123.5407,
#          -115.2561],
#         [ -39.2252,  -66.7680,  -76.7324,  ...,  -66.3336,  -78.9353,
#           -71.6066],
#         [ -75.8810,   -3.5530,   -5.7803,  ...,  -27.9720,   -0.8125,
#            -0.6550]], device='cuda:0')
# labels ：
# tensor([ 49,  36, 108,  88,   3,  73, 159,  43, 100, 122,  10,  11,  26,  50,
#          77, 128,  29,   3,  10, 112, 155,  78,  93,  39, 167,  95,  54,  30,
#         169,  53,  46,   1], device='cuda:0')
# loss ：
# tensor(0.9279, device='cuda:0')
# valid_data_j: 1317
# Outputs :
# tensor([[-75.9817, -86.4021, -95.0082,  ..., -24.3958, -87.7721, -82.6409],
#         [-49.5050, -55.5800, -64.8614,  ..., -19.0737, -64.4392, -57.5552],
#         [-25.2670, -54.9126, -63.3045,  ..., -56.9501, -68.3536, -61.5720],
#         ...,
#         [-62.8338, -56.8666, -56.6078,  ..., -62.2447, -55.3371, -55.9775],
#         [-77.6492,  -8.7408, -13.4490,  ..., -32.2414,  -0.3112,  -2.3555],
#         [-79.0748, -49.4190, -58.2395,  ..., -68.9591, -33.7729, -40.5249]],
#        device='cuda:0')
# labels ：
# tensor([116, 168,  50, 157,   9, 118, 111,  38,   5,  77, 105, 123, 147,  61,
#          74,  15, 114,  24, 123,  67, 101,  11,  60,  24, 127,  65,  98,   4,
#         169,  37, 171,  71], device='cuda:0')
# loss ：
# tensor(0.4878, device='cuda:0')
# valid_data_j: 1318
# Outputs :
# tensor([[ -71.1600,  -86.8158,  -89.3989,  -95.7017,  -94.8365,  -95.7628,
#          -102.7154, -106.3690, -105.2499,  -95.2209, -102.9437,  -62.0809,
#           -84.4018,  -85.7487,  -80.0686,  -83.5859,  -91.8905,  -96.9776,
#           -94.4321,  -89.7499,  -76.6823,  -66.6411,  -50.8506,  -69.7265,
#           -68.1046,  -84.8205,  -91.6133,  -92.6720,  -69.7368, -106.0952,
#           -95.2351, -116.5914, -111.9780,  -53.2313,  -98.7269,  -90.9525,
#           -90.5442,  -73.4863,  -70.9555,  -61.1653,  -55.3972,  -61.8556,
#           -52.0143,  -54.5553,  -54.3233,  -49.5625,  -51.4703,  -50.4109,
#           -52.0237,  -54.4281,  -61.5474,  -59.9091,  -66.9354,  -70.7486,
#           -62.2486,  -49.8278,  -67.7087,  -73.2439,  -63.1260,  -48.8554,
#           -70.1688,  -58.0155,  -69.8989,  -78.5908,  -87.2272,  -90.5875,
#           -64.4714,  -98.9202,  -97.8557,  -80.3314,  -52.9040,  -57.7343,
#           -71.2657,  -61.7597,  -44.2160,  -31.3119,  -31.4386,  -67.5916,
#           -23.1523,  -33.3960,  -40.5969,  -39.2823,  -39.0742,  -60.6582,
#           -71.3286,  -68.6596,  -87.0627,  -87.6003,  -71.0753,  -83.3672,
#           -88.4136,  -87.8269,  -97.7866,  -79.8130,  -88.0400,  -87.5010,
#           -73.8824,  -96.5007,  -98.6302, -104.6404,  -85.7479, -101.5618,
#          -101.3048,  -87.0672,  -73.0283,  -39.1073,  -66.9236,  -74.4713,
#           -52.6516,  -36.3186,  -61.6086,  -89.1236,  -49.0173,  -39.8694,
#           -28.1595,  -28.1132,  -33.6856,  -49.1193,  -61.7991,  -71.8563,
#           -70.8302,  -61.7074,  -94.9612,  -48.4236,  -53.7594,  -35.8252,
#           -16.6439,  -17.3550,   -7.5566,   -1.0422,   -0.4405,   -5.7939,
#            -9.9529,  -96.2517,  -25.6630,  -36.8691,  -41.2321,  -51.4589,
#           -65.9786,  -68.0350,  -76.5081,  -78.3777,  -86.2245,  -78.9784,
#           -91.2308,  -76.4549,  -66.9194,  -68.6545,  -80.1259,  -95.3775,
#           -97.6219, -105.1781, -108.7978, -102.3137,  -87.7094,  -94.3757,
#           -78.2806,  -69.2464,  -51.9051,  -48.1585,  -24.9434,  -32.3993,
#           -30.2000,  -23.5923,  -25.0867,  -26.9102, -107.7681,  -25.7407,
#           -24.9915,  -43.2770,  -61.8251, -100.7222,  -93.6045]],
#        device='cuda:0')
# labels ：
# tensor([130], device='cuda:0')
# loss ：
# tensor(0.4405, device='cuda:0')

# %%
history.append([avg_valid_loss, avg_valid_acc])

print("Validation: Loss: {:.4f}, Accuracy: {:.4f}%".format(
    avg_valid_loss, avg_valid_acc*100
))
# Out:
# Validation: Loss: 0.6523, Accuracy: 81.3216%

# %%
torch.max(outputs)
# Out:
# tensor(-0.4405, device='cuda:0')
